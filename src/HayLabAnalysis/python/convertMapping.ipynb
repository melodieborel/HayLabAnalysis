# %% [markdown]
# This notebook helps converting mappings to a dictionnary formated to be used in 0_...

# %%
#paste here the mapping in its original form


code = """
if souris == 'jaune':
    EMG = All2[:, 21]                   #EMG (Jaune)
    A1 = All2[:, 3] - All2[:, 2]        #CA1
    A2 = All2[:, 4] - All2[:, 5]        #RSP *
    A3 = All2[:, 6] - All2[:, 7]        #Par
    A4 = All2[:, 8] #- All2[:, 9]        #PFC *
    A5 = All2[:, 10] - All2[:, 11]      #M1 *
    A6 = All2[:, 13] - All2[:, 12]      #OFC
    A7 = All2[:, 30] - All2[:, 31]      #mEC
    A8 = All2[:, 28] - All2[:, 29]      #Perirhinal
    A9 = All2[:, 17] #- All2[:, 16]      #BLA
    A10 = All2[:, 14] - All2[:, 15]     #S1 *
    label = ['EMG','CA1','RSP','Par','PFC','M1','OFC','mEC','Perirhinal','BLA','S1']
elif souris == 'violet': ## Joli et fait
    EMG = All2[:, 5]                    #EMG (violet)
    A1 = All2[:, 23] - All2[:, 22]      #RSP
    A2 = All2[:, 21] - All2[:, 20]      #Par
    A3 = All2[:, 18] - All2[:, 19]      #CA1 +
    A4 = All2[:, 24] #- All2[:, 25]      #PFC *
    A5 = All2[:, 26] - All2[:, 27]      #M1 *
    A6 = All2[:, 28] - All2[:, 29]      #OFC *
    A7 = All2[:, 30] - All2[:, 31]      #S1 *
    A8 = All2[:, 0] - All2[:, 1]        #Perirhinal
    A11 = All2[:, 16] - All2[:, 17]      #CA1
    A10 = All2[:, 14] -  All2[:, 15]     #BLA
    A9 = All2[:, 13] #- All2[:, 12]       #mEC
    label = ['EMG','RSP','Par','CA1','PFC','M1','OFC','S1','Perirhinal','BLA','mEC']
elif souris == 'vert':
    EMG = All2[:, 26]                    #EMG (vert)
    A1 = All2[:, 2] - All2[:, 3]        #Par
    A2 = All2[:, 4] - All2[:, 5]        #PFC
    A3 = All2[:, 7] - All2[:, 6]        #OFC 
    A4 = All2[:, 8] - All2[:, 9]        #S1 *
    A5 = All2[:, 10] - All2[:, 11]      #BLA
    A6 = All2[:, 12] - All2[:, 13]      #mEC +
    A7 = All2[:, 29] #- All2[:, 29]      #CA1
    A8 = All2[:, 0] - All2[:, 1]        #M1
    A9 = All2[:, 16] - All2[:, 17]      #RSP +
    A10 = All2[:, 14] - All2[:, 15]     #Perirhinal
elif souris == 'orange':
    EMG = All2[:, 25]                    #EMG (orange)
    A1 = All2[:, 6] - All2[:, 7]         #Par
    A2 = All2[:, 11] - All2[:, 10]       #PFC *
    A3 = All2[:, 8] - All2[:, 9]         #OFC *
    A4 = All2[:, 17] - All2[:, 16]       #S1 *
    A5 = All2[:, 14] - All2[:, 15]       #BLA
    A6 = All2[:, 0] - All2[:, 1]         #mEC
    A7 = All2[:, 27] - All2[:, 29]       #CA1
    A8 = All2[:, 13] - All2[:, 12]       #M1 *
    A9 = All2[:, 4] - All2[:, 3]         #RSP
    A10 = All2[:, 18] - All2[:, 19]      #Perirhinal
elif souris == 'bleu':
    EMG = All2[:, 20]                    #EMG (bleu)
    A1 = All2[:, 5] - All2[:, 4]         #Par * DS~
    A2 = All2[:, 14] - All2[:, 15]       #PFC * chan 15
    A3 = All2[:, 12] - All2[:, 13]       #OFC *
    A4 = All2[:, 9] - All2[:, 8]         #S1 * DS+
    A5 = All2[:, 10] - All2[:, 11]       #BLA
    A6 = All2[:, 2] - All2[:, 3]         #mEC +
    A7 = All2[:, 30]# - All2[:, 30]       #CA1 +
    A8 = All2[:, 16] -  All2[:, 17]       #M1 * DS+
    A9 = All2[:, 0] - All2[:, 1]         #RSP
    A10 = All2[:, 6] - All2[:, 7]        #Perirhinal +
elif souris == 'bleu2':
    EMG = All2[:, 2]                    #EMG (bleu)
    A1 = All2[:, 5] - All2[:, 4]         #Par
    A2 = All2[:, 1] - All2[:, 1]       #PFC
    A3 = All2[:, 14] - All2[:, 15]       #OFC
    A4 = All2[:, 14]# - All2[:, 8]         #S1
    A5 = All2[:, 15]# - All2[:, 11]       #BLA
    A6 = All2[:, 5] - All2[:, 4]         #mEC
    A7 = All2[:, 0]# - All2[:, 30]       #CA1
    A8 = All2[:, 6] -  All2[:, 7]       #M1
    A9 = All2[:, 1] - All2[:, 0]         #RSP
    A10 = All2[:, 6] - All2[:, 7]        #Perirhinal
elif souris == '2205':
    EMG = All2[:, 6]                    #EMG (2205)
    A1 = All2[:, 31] - All2[:, 30]      #M1
    A2 = All2[:, 21] - All2[:, 20]      #M2
    A3 = All2[:, 18] - All2[:, 19]      #CA1 +
    A4 = All2[:, 14] - All2[:, 14]      #CA12 *
    A5 = -All2[:, 2]# - All2[:, 3]      #S1 *
    A6 = All2[:, 29] - All2[:, 28]      #S1 *
    A7 = All2[:, 30] - All2[:, 30]      #S1 *
    A8 = All2[:, 0] - All2[:, 0]        #Perirhinal
    A11 = All2[:, 16] - All2[:, 16]      #CA1
    A10 = All2[:, 14] -  All2[:, 14]     #BLA
    A9 = All2[:, 13] - All2[:, 13]       #mEC
    label = ['EMG','RSP','Par','CA1','PFC','M1','OFC','S1','Perirhinal','BLA','mEC']
elif souris == 'M19': ## OPPK long stim
    EMG = All2[:, 6]                    #EMG (M19)
    A1 = All2[:, 25] - All2[:, 24]      #front
    A2 = All2[:, 21] - All2[:, 20]      #M1
    A3 = All2[:, 19] - All2[:, 18]      #M2
    A3 = All2[:, 12] - All2[:, 13]      #CA1ipsi
    A4 = All2[:, 15] - All2[:, 14]      #S1tr
    A5 = All2[:, 11] - All2[:, 10]      #S1bf
    A6 = All2[:, 26] - All2[:, 27]      #S1contra
    A7 = All2[:, 16] - All2[:, 17]      #S1fl
    A8 = All2[:, 0] - All2[:, 1]        #RSA
    A9 = All2[:, 9] - All2[:, 8]        #Aud
    A10 = All2[:, 23] -  All2[:, 22]    #M2
    A11 = All2[:, 3] - All2[:, 2]       #V1
    A12 = All2[:, 4] - All2[:, 5]       #V2
    A12 = All2[:, 30] - All2[:, 31]       #CA1contra
    label = ['EMG','RSP','Par','CA1','PFC','M1','OFC','S1','Perirhinal','BLA','mEC']
elif souris == 'alien': # à analyser
    EMG = All2[:, 7]                    #EMG (alien)
    A1 = All2[:, 28] - All2[:, 29]         #Par *
    A2 = All2[:, 1] - All2[:, 0]       #PFC *
    A3 = All2[:, 18] - All2[:, 19]       #OFC
    A4 = All2[:, 14] - All2[:, 15]         #S1 *
    A5 = All2[:, 24] - All2[:, 25]       #BLA
    A6 = All2[:, 22] #- All2[:, 23]         #mEC
    A7 = All2[:, 2] - All2[:, 3]       #CA1 +
    A8 = All2[:, 10] -  All2[:, 11]       #M1 *
    A9 = All2[:, 5] - All2[:, 4]         #RSP *
    A10 = All2[:, 7]# - All2[:, 3]        #VIDE
elif souris == 'apaiser': # A analyser 
    EMG = All2[:, 6]                    #EMG (apaiser)
    A1 = All2[:, 28] - All2[:, 27]      #Par *
    A2 = All2[:, 24] #- All2[:, 25]       #PFC *
    A3 = All2[:, 19] - All2[:, 20]       #OFC *
    A4 = All2[:, 22] - All2[:, 23]         #S1 *
    A5 = All2[:, 15] - All2[:, 16]       #BLA
    A6 = All2[:, 11] - All2[:, 12]         #mEC +
    A7 = All2[:, 0] - All2[:, 31]       #CA1 +
    A8 = All2[:, 1] #-  All2[:, 2]       #M1 *
    A9 = All2[:, 4] - All2[:, 3]         #RSP
    A10 = All2[:, 6]# - All2[:, 3]        #VIDE
elif souris == 'pervers':
    EMG = All2[:, 24]                    #EMG (pervers)
    A1 = All2[:, 17] - All2[:, 16]         #Par *
    A2 = All2[:, 12] - All2[:, 13]       #PFC
    A3 = All2[:, 8] - All2[:, 9]       #OFC
    A4 = All2[:, 3] - All2[:, 2]         #S1 *
    A5 = All2[:, 28] - All2[:, 29]       #BLA
    A6 = All2[:, 27] - All2[:, 26]         #mEC
    A7 = All2[:, 22] - All2[:, 23]       #CA1 ~+
    A8 = All2[:, 7] -  All2[:, 6]       #M1 *
    A9 = All2[:, 19] - All2[:, 18]         #RSP
    A10 = All2[:, 30] - All2[:, 31]        #Perirhinal +
elif souris == 'sleepy':
    EMG = All2[:, 7]                    #EMG (sleepy)
    A1 = All2[:, 0] - All2[:, 1]         #Par
    A2 = All2[:, 3] - All2[:, 2]       #PFC +
    A3 = All2[:, 4] - All2[:, 5]       #OFC
    A4 = All2[:, 14] #- All2[:, 15]         #S1
    A5 = All2[:, 18] - All2[:, 19]       #BLA
    A6 = All2[:, 22] - All2[:, 23]         #mEC
    A7 = All2[:, 28] - All2[:, 29]       #CA1
    A8 = All2[:, 10] #-  All2[:, 11]       #M1
    A9 = All2[:, 24] - All2[:, 25]         #RSP
    A10 = All2[:, 20] - All2[:, 21]        #Perirhinal
elif souris == 'intello':
    EMG = All2[:, 23]                    #EMG (intello)
    A1 = All2[:, 8] - All2[:, 9]         #Par
    A2 = All2[:, 5] - All2[:, 4]       #PFC
    A3 = All2[:, 6] - All2[:, 7]       #OFC
    A4 = All2[:, 18] - All2[:, 19]         #S1
    A5 = All2[:, 20] - All2[:, 21]       #BLA
    A6 = All2[:, 26] - All2[:, 27]         #mEC
    A7 = All2[:, 12] - All2[:, 13]       #CA1
    A8 = All2[:, 30] -  All2[:, 31]       #M1
    A9 = All2[:, 17] - All2[:, 16]         #RSP
    A10 = All2[:, 2] - All2[:, 3]        #Perirhinal  +  
elif souris == 'chokbar':
    EMG = All2[:, 23]                    #EMG (chokbar)
    A1 = All2[:, 16] - All2[:, 17]         #Par * ch16
    A2 = All2[:, 8] - All2[:, 9]       #PFC * ch8
    A3 = All2[:, 6] - All2[:, 7]       #OFC
    A4 = All2[:, 4] - All2[:, 5]         #S1 *
    A5 = All2[:, 2] - All2[:, 3]       #BLA
    A6 = All2[:, 26] - All2[:, 27]         #mEC
    A7 = All2[:, 20] - All2[:, 21]       #CA1
    A8 = All2[:, 12] -  All2[:, 13]       #M1
    A9 = All2[:, 18] - All2[:, 19]         #RSP
    A10 = All2[:, 30] - All2[:, 31]        #Perirhinal +  
elif souris == 'amoureux':
    EMG = All2[:, 7]                    #EMG (amoureux) À analyser pour CA1, mais vraiment rien sur les autres
    A1 = All2[:, 5] #- All2[:, 4]         #Par
    A2 = All2[:, 15] - All2[:, 14]       #PFC *
    A3 = All2[:, 0] - All2[:, 1]       #OFC
    A4 = All2[:, 3] - All2[:, 2]         #S1 *
    A5 = All2[:, 22] - All2[:, 23]       #BLA
    A6 = All2[:, 24] - All2[:, 25]         #mEC
    A7 = All2[:, 21] - All2[:, 20]       #CA1 +
    A8 = All2[:, 18] -  All2[:, 19]       #M1 *
    A9 = All2[:, 11] - All2[:, 10]         #RSP
    A10 = All2[:, 28] - All2[:, 29]        #Perirhinal 
elif souris == 'evil':
    EMG = All2[:, 7]                    #EMG (evil)
    A1 = All2[:, 3] - All2[:, 2]         #Par * moche, pas forcément crédible
    A2 = All2[:, 25] - All2[:, 24]       #PFC *
    A3 = All2[:, 22] - All2[:, 23]       #OFC *
    A4 = All2[:, 4] - All2[:, 5]         #S1 *
    A5 = All2[:, 18] - All2[:, 19]       #BLA
    A6 = All2[:, 10] - All2[:, 11]         #mEC
    A7 = All2[:, 20] - All2[:, 21]       #CA1 +
    A8 = All2[:, 28] -  All2[:, 29]       #M1 *
    A9 = All2[:, 1] - All2[:, 0]         #RSP
    A10 = All2[:, 14] - All2[:, 15]        #Perirhinal  +
elif souris == 'explode':
    EMG = All2[:, 7]                    #EMG (explode) sadly no spindles on Par, PFC, OFC and M1 even with 1 channel
    A1 = All2[:, 6] - All2[:, 5]         #Par
    A2 = All2[:, 10] - All2[:, 11]       #PFC
    A3 = All2[:, 6] - All2[:, 5]       #OFC
    A4 = All2[:, 1] - All2[:, 2]         #S1 *
    A5 = All2[:, 14] - All2[:, 15]       #BLA -> des moments de coordination avec CA1
    A6 = All2[:, 25] #- All2[:, 25]         #mEC
    A7 = All2[:, 19] - All2[:, 18]       #CA1 +
    A8 = All2[:, 4] -  All2[:, 3]       #M1 *
    A9 = All2[:, 22] - All2[:, 23]         #RSP
    A10 = All2[:, 30] - All2[:, 29]        #Perirhinal +   
elif souris == 'dead':
    EMG = All2[:, 7]                    #EMG (dead)
    A1 = All2[:, 4] - All2[:, 5]         #Par
    A2 = All2[:, 19] - All2[:, 18]       #PFC
    A3 = All2[:, 11] - All2[:, 10]       #OFC
    A4 = All2[:, 21] - All2[:, 20]         #S1
    A5 = All2[:, 22] - All2[:, 23]       #BLA
    A6 = All2[:, 24] #- All2[:, 25]         #mEC
    A7 = All2[:, 2] #- All2[:, 3]       #CA1 
    A8 = All2[:, 15] -  All2[:, 14]       #M1
    A9 = All2[:, 1] - All2[:, 0]         #RSP
    A10 = All2[:, 28] - All2[:, 29]        #Perirhinal +
"""

# %%
import re
import configparser
import os

mouseID="None"
expeConfigFN='channelMaps'
for sourisBloc in code.split('elif '):
    parser = configparser.ConfigParser()
    channelsMap = dict()
    print(sourisBloc)
    for line in sourisBloc.splitlines():
        if line.startswith('souris'):
            mouseID = line.split("'")[1]
            #print(mouseID)
            parser.read(expeConfigFN)
        else:
            structure = line.split("#")[-1]
            if structure.startswith('EMG'):
                structure = "EMG"
            print(structure)
            
            m = re.findall(r'All2\[:, (\d+)\]', line)
            print(m)
            channelsMap[structure]=[]
            nComments = len(line.split("#"))
            for i,ch in enumerate(m):
                print(ch)
                temp=dict()
                temp['canal']=ch
                if nComments>=3 and i>=1:
                    print("ignoring second channel")
                    temp['status']=0
                else:
                    temp['status']=len(m)-nComments+2-i
                print(temp)
                channelsMap[structure].append(temp)
    print(channelsMap)
    parser[mouseID] = {'channelsMap': channelsMap}

    with open(expeConfigFN, 'w') as configfile:
                parser.write(configfile)
# Out:
# if souris == 'jaune':
#     EMG = All2[:, 21]                   #EMG (Jaune)
#     A1 = All2[:, 3] - All2[:, 2]        #CA1
#     A2 = All2[:, 4] - All2[:, 5]        #RSP *
#     A3 = All2[:, 6] - All2[:, 7]        #Par
#     A4 = All2[:, 8] #- All2[:, 9]        #PFC *
#     A5 = All2[:, 10] - All2[:, 11]      #M1 *
#     A6 = All2[:, 13] - All2[:, 12]      #OFC
#     A7 = All2[:, 30] - All2[:, 31]      #mEC
#     A8 = All2[:, 28] - All2[:, 29]      #Perirhinal
#     A9 = All2[:, 17] #- All2[:, 16]      #BLA
#     A10 = All2[:, 14] - All2[:, 15]     #S1 *
#     label = ['EMG','CA1','RSP','Par','PFC','M1','OFC','mEC','Perirhinal','BLA','S1']
#
#
# []
# if souris == 'jaune':
# []
# EMG
# ['21']
# 21
# {'canal': '21', 'status': 1}
# CA1
# ['3', '2']
# 3
# {'canal': '3', 'status': 2}
# 2
# {'canal': '2', 'status': 1}
# RSP *
# ['4', '5']
# 4
# {'canal': '4', 'status': 2}
# 5
# {'canal': '5', 'status': 1}
# Par
# ['6', '7']
# 6
# {'canal': '6', 'status': 2}
# 7
# {'canal': '7', 'status': 1}
# PFC *
# ['8', '9']
# 8
# {'canal': '8', 'status': 1}
# 9
# ignoring second channel
# {'canal': '9', 'status': 0}
# M1 *
# ['10', '11']
# 10
# {'canal': '10', 'status': 2}
# 11
# {'canal': '11', 'status': 1}
# OFC
# ['13', '12']
# 13
# {'canal': '13', 'status': 2}
# 12
# {'canal': '12', 'status': 1}
# mEC
# ['30', '31']
# 30
# {'canal': '30', 'status': 2}
# 31
# {'canal': '31', 'status': 1}
# Perirhinal
# ['28', '29']
# 28
# {'canal': '28', 'status': 2}
# 29
# {'canal': '29', 'status': 1}
# BLA
# ['17', '16']
# 17
# {'canal': '17', 'status': 1}
# 16
# ignoring second channel
# {'canal': '16', 'status': 0}
# S1 *
# ['14', '15']
# 14
# {'canal': '14', 'status': 2}
# 15
# {'canal': '15', 'status': 1}
#     label = ['EMG','CA1','RSP','Par','PFC','M1','OFC','mEC','Perirhinal','BLA','S1']
# []
# {'': [], "if souris == 'jaune':": [], 'EMG': [{'canal': '21', 'status': 1}], 'CA1': [{'canal': '3', 'status': 2}, {'canal': '2', 'status': 1}], 'RSP *': [{'canal': '4', 'status': 2}, {'canal': '5', 'status': 1}], 'Par': [{'canal': '6', 'status': 2}, {'canal': '7', 'status': 1}], 'PFC *': [{'canal': '8', 'status': 1}, {'canal': '9', 'status': 0}], 'M1 *': [{'canal': '10', 'status': 2}, {'canal': '11', 'status': 1}], 'OFC': [{'canal': '13', 'status': 2}, {'canal': '12', 'status': 1}], 'mEC': [{'canal': '30', 'status': 2}, {'canal': '31', 'status': 1}], 'Perirhinal': [{'canal': '28', 'status': 2}, {'canal': '29', 'status': 1}], 'BLA': [{'canal': '17', 'status': 1}, {'canal': '16', 'status': 0}], 'S1 *': [{'canal': '14', 'status': 2}, {'canal': '15', 'status': 1}], "    label = ['EMG','CA1','RSP','Par','PFC','M1','OFC','mEC','Perirhinal','BLA','S1']": []}
# souris == 'violet': ## Joli et fait
#     EMG = All2[:, 5]                    #EMG (violet)
#     A1 = All2[:, 23] - All2[:, 22]      #RSP
#     A2 = All2[:, 21] - All2[:, 20]      #Par
#     A3 = All2[:, 18] - All2[:, 19]      #CA1 +
#     A4 = All2[:, 24] #- All2[:, 25]      #PFC *
#     A5 = All2[:, 26] - All2[:, 27]      #M1 *
#     A6 = All2[:, 28] - All2[:, 29]      #OFC *
#     A7 = All2[:, 30] - All2[:, 31]      #S1 *
#     A8 = All2[:, 0] - All2[:, 1]        #Perirhinal
#     A11 = All2[:, 16] - All2[:, 17]      #CA1
#     A10 = All2[:, 14] -  All2[:, 15]     #BLA
#     A9 = All2[:, 13] #- All2[:, 12]       #mEC
#     label = ['EMG','RSP','Par','CA1','PFC','M1','OFC','S1','Perirhinal','BLA','mEC']
#
# EMG
# ['5']
# 5
# {'canal': '5', 'status': 1}
# RSP
# ['23', '22']
# 23
# {'canal': '23', 'status': 2}
# 22
# {'canal': '22', 'status': 1}
# Par
# ['21', '20']
# 21
# {'canal': '21', 'status': 2}
# 20
# {'canal': '20', 'status': 1}
# CA1 +
# ['18', '19']
# 18
# {'canal': '18', 'status': 2}
# 19
# {'canal': '19', 'status': 1}
# PFC *
# ['24', '25']
# 24
# {'canal': '24', 'status': 1}
# 25
# ignoring second channel
# {'canal': '25', 'status': 0}
# M1 *
# ['26', '27']
# 26
# {'canal': '26', 'status': 2}
# 27
# {'canal': '27', 'status': 1}
# OFC *
# ['28', '29']
# 28
# {'canal': '28', 'status': 2}
# 29
# {'canal': '29', 'status': 1}
# S1 *
# ['30', '31']
# 30
# {'canal': '30', 'status': 2}
# 31
# {'canal': '31', 'status': 1}
# Perirhinal
# ['0', '1']
# 0
# {'canal': '0', 'status': 2}
# 1
# {'canal': '1', 'status': 1}
# CA1
# ['16', '17']
# 16
# {'canal': '16', 'status': 2}
# 17
# {'canal': '17', 'status': 1}
# BLA
# ['14', '15']
# 14
# {'canal': '14', 'status': 2}
# 15
# {'canal': '15', 'status': 1}
# mEC
# ['13', '12']
# 13
# {'canal': '13', 'status': 1}
# 12
# ignoring second channel
# {'canal': '12', 'status': 0}
#     label = ['EMG','RSP','Par','CA1','PFC','M1','OFC','S1','Perirhinal','BLA','mEC']
# []
# {'EMG': [{'canal': '5', 'status': 1}], 'RSP': [{'canal': '23', 'status': 2}, {'canal': '22', 'status': 1}], 'Par': [{'canal': '21', 'status': 2}, {'canal': '20', 'status': 1}], 'CA1 +': [{'canal': '18', 'status': 2}, {'canal': '19', 'status': 1}], 'PFC *': [{'canal': '24', 'status': 1}, {'canal': '25', 'status': 0}], 'M1 *': [{'canal': '26', 'status': 2}, {'canal': '27', 'status': 1}], 'OFC *': [{'canal': '28', 'status': 2}, {'canal': '29', 'status': 1}], 'S1 *': [{'canal': '30', 'status': 2}, {'canal': '31', 'status': 1}], 'Perirhinal': [{'canal': '0', 'status': 2}, {'canal': '1', 'status': 1}], 'CA1': [{'canal': '16', 'status': 2}, {'canal': '17', 'status': 1}], 'BLA': [{'canal': '14', 'status': 2}, {'canal': '15', 'status': 1}], 'mEC': [{'canal': '13', 'status': 1}, {'canal': '12', 'status': 0}], "    label = ['EMG','RSP','Par','CA1','PFC','M1','OFC','S1','Perirhinal','BLA','mEC']": []}
# souris == 'vert':
#     EMG = All2[:, 26]                    #EMG (vert)
#     A1 = All2[:, 2] - All2[:, 3]        #Par
#     A2 = All2[:, 4] - All2[:, 5]        #PFC
#     A3 = All2[:, 7] - All2[:, 6]        #OFC
#     A4 = All2[:, 8] - All2[:, 9]        #S1 *
#     A5 = All2[:, 10] - All2[:, 11]      #BLA
#     A6 = All2[:, 12] - All2[:, 13]      #mEC +
#     A7 = All2[:, 29] #- All2[:, 29]      #CA1
#     A8 = All2[:, 0] - All2[:, 1]        #M1
#     A9 = All2[:, 16] - All2[:, 17]      #RSP +
#     A10 = All2[:, 14] - All2[:, 15]     #Perirhinal
#
# EMG
# ['26']
# 26
# {'canal': '26', 'status': 1}
# Par
# ['2', '3']
# 2
# {'canal': '2', 'status': 2}
# 3
# {'canal': '3', 'status': 1}
# PFC
# ['4', '5']
# 4
# {'canal': '4', 'status': 2}
# 5
# {'canal': '5', 'status': 1}
# OFC
# ['7', '6']
# 7
# {'canal': '7', 'status': 2}
# 6
# {'canal': '6', 'status': 1}
# S1 *
# ['8', '9']
# 8
# {'canal': '8', 'status': 2}
# 9
# {'canal': '9', 'status': 1}
# BLA
# ['10', '11']
# 10
# {'canal': '10', 'status': 2}
# 11
# {'canal': '11', 'status': 1}
# mEC +
# ['12', '13']
# 12
# {'canal': '12', 'status': 2}
# 13
# {'canal': '13', 'status': 1}
# CA1
# ['29', '29']
# 29
# {'canal': '29', 'status': 1}
# 29
# ignoring second channel
# {'canal': '29', 'status': 0}
# M1
# ['0', '1']
# 0
# {'canal': '0', 'status': 2}
# 1
# {'canal': '1', 'status': 1}
# RSP +
# ['16', '17']
# 16
# {'canal': '16', 'status': 2}
# 17
# {'canal': '17', 'status': 1}
# Perirhinal
# ['14', '15']
# 14
# {'canal': '14', 'status': 2}
# 15
# {'canal': '15', 'status': 1}
# {'EMG': [{'canal': '26', 'status': 1}], 'Par': [{'canal': '2', 'status': 2}, {'canal': '3', 'status': 1}], 'PFC': [{'canal': '4', 'status': 2}, {'canal': '5', 'status': 1}], 'OFC ': [{'canal': '7', 'status': 2}, {'canal': '6', 'status': 1}], 'S1 *': [{'canal': '8', 'status': 2}, {'canal': '9', 'status': 1}], 'BLA': [{'canal': '10', 'status': 2}, {'canal': '11', 'status': 1}], 'mEC +': [{'canal': '12', 'status': 2}, {'canal': '13', 'status': 1}], 'CA1': [{'canal': '29', 'status': 1}, {'canal': '29', 'status': 0}], 'M1': [{'canal': '0', 'status': 2}, {'canal': '1', 'status': 1}], 'RSP +': [{'canal': '16', 'status': 2}, {'canal': '17', 'status': 1}], 'Perirhinal': [{'canal': '14', 'status': 2}, {'canal': '15', 'status': 1}]}
# souris == 'orange':
#     EMG = All2[:, 25]                    #EMG (orange)
#     A1 = All2[:, 6] - All2[:, 7]         #Par
#     A2 = All2[:, 11] - All2[:, 10]       #PFC *
#     A3 = All2[:, 8] - All2[:, 9]         #OFC *
#     A4 = All2[:, 17] - All2[:, 16]       #S1 *
#     A5 = All2[:, 14] - All2[:, 15]       #BLA
#     A6 = All2[:, 0] - All2[:, 1]         #mEC
#     A7 = All2[:, 27] - All2[:, 29]       #CA1
#     A8 = All2[:, 13] - All2[:, 12]       #M1 *
#     A9 = All2[:, 4] - All2[:, 3]         #RSP
#     A10 = All2[:, 18] - All2[:, 19]      #Perirhinal
#
# EMG
# ['25']
# 25
# {'canal': '25', 'status': 1}
# Par
# ['6', '7']
# 6
# {'canal': '6', 'status': 2}
# 7
# {'canal': '7', 'status': 1}
# PFC *
# ['11', '10']
# 11
# {'canal': '11', 'status': 2}
# 10
# {'canal': '10', 'status': 1}
# OFC *
# ['8', '9']
# 8
# {'canal': '8', 'status': 2}
# 9
# {'canal': '9', 'status': 1}
# S1 *
# ['17', '16']
# 17
# {'canal': '17', 'status': 2}
# 16
# {'canal': '16', 'status': 1}
# BLA
# ['14', '15']
# 14
# {'canal': '14', 'status': 2}
# 15
# {'canal': '15', 'status': 1}
# mEC
# ['0', '1']
# 0
# {'canal': '0', 'status': 2}
# 1
# {'canal': '1', 'status': 1}
# CA1
# ['27', '29']
# 27
# {'canal': '27', 'status': 2}
# 29
# {'canal': '29', 'status': 1}
# M1 *
# ['13', '12']
# 13
# {'canal': '13', 'status': 2}
# 12
# {'canal': '12', 'status': 1}
# RSP
# ['4', '3']
# 4
# {'canal': '4', 'status': 2}
# 3
# {'canal': '3', 'status': 1}
# Perirhinal
# ['18', '19']
# 18
# {'canal': '18', 'status': 2}
# 19
# {'canal': '19', 'status': 1}
# {'EMG': [{'canal': '25', 'status': 1}], 'Par': [{'canal': '6', 'status': 2}, {'canal': '7', 'status': 1}], 'PFC *': [{'canal': '11', 'status': 2}, {'canal': '10', 'status': 1}], 'OFC *': [{'canal': '8', 'status': 2}, {'canal': '9', 'status': 1}], 'S1 *': [{'canal': '17', 'status': 2}, {'canal': '16', 'status': 1}], 'BLA': [{'canal': '14', 'status': 2}, {'canal': '15', 'status': 1}], 'mEC': [{'canal': '0', 'status': 2}, {'canal': '1', 'status': 1}], 'CA1': [{'canal': '27', 'status': 2}, {'canal': '29', 'status': 1}], 'M1 *': [{'canal': '13', 'status': 2}, {'canal': '12', 'status': 1}], 'RSP': [{'canal': '4', 'status': 2}, {'canal': '3', 'status': 1}], 'Perirhinal': [{'canal': '18', 'status': 2}, {'canal': '19', 'status': 1}]}
# souris == 'bleu':
#     EMG = All2[:, 20]                    #EMG (bleu)
#     A1 = All2[:, 5] - All2[:, 4]         #Par * DS~
#     A2 = All2[:, 14] - All2[:, 15]       #PFC * chan 15
#     A3 = All2[:, 12] - All2[:, 13]       #OFC *
#     A4 = All2[:, 9] - All2[:, 8]         #S1 * DS+
#     A5 = All2[:, 10] - All2[:, 11]       #BLA
#     A6 = All2[:, 2] - All2[:, 3]         #mEC +
#     A7 = All2[:, 30]# - All2[:, 30]       #CA1 +
#     A8 = All2[:, 16] -  All2[:, 17]       #M1 * DS+
#     A9 = All2[:, 0] - All2[:, 1]         #RSP
#     A10 = All2[:, 6] - All2[:, 7]        #Perirhinal +
#
# EMG
# ['20']
# 20
# {'canal': '20', 'status': 1}
# Par * DS~
# ['5', '4']
# 5
# {'canal': '5', 'status': 2}
# 4
# {'canal': '4', 'status': 1}
# PFC * chan 15
# ['14', '15']
# 14
# {'canal': '14', 'status': 2}
# 15
# {'canal': '15', 'status': 1}
# OFC *
# ['12', '13']
# 12
# {'canal': '12', 'status': 2}
# 13
# {'canal': '13', 'status': 1}
# S1 * DS+
# ['9', '8']
# 9
# {'canal': '9', 'status': 2}
# 8
# {'canal': '8', 'status': 1}
# BLA
# ['10', '11']
# 10
# {'canal': '10', 'status': 2}
# 11
# {'canal': '11', 'status': 1}
# mEC +
# ['2', '3']
# 2
# {'canal': '2', 'status': 2}
# 3
# {'canal': '3', 'status': 1}
# CA1 +
# ['30', '30']
# 30
# {'canal': '30', 'status': 1}
# 30
# ignoring second channel
# {'canal': '30', 'status': 0}
# M1 * DS+
# ['16', '17']
# 16
# {'canal': '16', 'status': 2}
# 17
# {'canal': '17', 'status': 1}
# RSP
# ['0', '1']
# 0
# {'canal': '0', 'status': 2}
# 1
# {'canal': '1', 'status': 1}
# Perirhinal +
# ['6', '7']
# 6
# {'canal': '6', 'status': 2}
# 7
# {'canal': '7', 'status': 1}
# {'EMG': [{'canal': '20', 'status': 1}], 'Par * DS~': [{'canal': '5', 'status': 2}, {'canal': '4', 'status': 1}], 'PFC * chan 15': [{'canal': '14', 'status': 2}, {'canal': '15', 'status': 1}], 'OFC *': [{'canal': '12', 'status': 2}, {'canal': '13', 'status': 1}], 'S1 * DS+': [{'canal': '9', 'status': 2}, {'canal': '8', 'status': 1}], 'BLA': [{'canal': '10', 'status': 2}, {'canal': '11', 'status': 1}], 'mEC +': [{'canal': '2', 'status': 2}, {'canal': '3', 'status': 1}], 'CA1 +': [{'canal': '30', 'status': 1}, {'canal': '30', 'status': 0}], 'M1 * DS+': [{'canal': '16', 'status': 2}, {'canal': '17', 'status': 1}], 'RSP': [{'canal': '0', 'status': 2}, {'canal': '1', 'status': 1}], 'Perirhinal +': [{'canal': '6', 'status': 2}, {'canal': '7', 'status': 1}]}
# souris == 'bleu2':
#     EMG = All2[:, 2]                    #EMG (bleu)
#     A1 = All2[:, 5] - All2[:, 4]         #Par
#     A2 = All2[:, 1] - All2[:, 1]       #PFC
#     A3 = All2[:, 14] - All2[:, 15]       #OFC
#     A4 = All2[:, 14]# - All2[:, 8]         #S1
#     A5 = All2[:, 15]# - All2[:, 11]       #BLA
#     A6 = All2[:, 5] - All2[:, 4]         #mEC
#     A7 = All2[:, 0]# - All2[:, 30]       #CA1
#     A8 = All2[:, 6] -  All2[:, 7]       #M1
#     A9 = All2[:, 1] - All2[:, 0]         #RSP
#     A10 = All2[:, 6] - All2[:, 7]        #Perirhinal
#
# EMG
# ['2']
# 2
# {'canal': '2', 'status': 1}
# Par
# ['5', '4']
# 5
# {'canal': '5', 'status': 2}
# 4
# {'canal': '4', 'status': 1}
# PFC
# ['1', '1']
# 1
# {'canal': '1', 'status': 2}
# 1
# {'canal': '1', 'status': 1}
# OFC
# ['14', '15']
# 14
# {'canal': '14', 'status': 2}
# 15
# {'canal': '15', 'status': 1}
# S1
# ['14', '8']
# 14
# {'canal': '14', 'status': 1}
# 8
# ignoring second channel
# {'canal': '8', 'status': 0}
# BLA
# ['15', '11']
# 15
# {'canal': '15', 'status': 1}
# 11
# ignoring second channel
# {'canal': '11', 'status': 0}
# mEC
# ['5', '4']
# 5
# {'canal': '5', 'status': 2}
# 4
# {'canal': '4', 'status': 1}
# CA1
# ['0', '30']
# 0
# {'canal': '0', 'status': 1}
# 30
# ignoring second channel
# {'canal': '30', 'status': 0}
# M1
# ['6', '7']
# 6
# {'canal': '6', 'status': 2}
# 7
# {'canal': '7', 'status': 1}
# RSP
# ['1', '0']
# 1
# {'canal': '1', 'status': 2}
# 0
# {'canal': '0', 'status': 1}
# Perirhinal
# ['6', '7']
# 6
# {'canal': '6', 'status': 2}
# 7
# {'canal': '7', 'status': 1}
# {'EMG': [{'canal': '2', 'status': 1}], 'Par': [{'canal': '5', 'status': 2}, {'canal': '4', 'status': 1}], 'PFC': [{'canal': '1', 'status': 2}, {'canal': '1', 'status': 1}], 'OFC': [{'canal': '14', 'status': 2}, {'canal': '15', 'status': 1}], 'S1': [{'canal': '14', 'status': 1}, {'canal': '8', 'status': 0}], 'BLA': [{'canal': '15', 'status': 1}, {'canal': '11', 'status': 0}], 'mEC': [{'canal': '5', 'status': 2}, {'canal': '4', 'status': 1}], 'CA1': [{'canal': '0', 'status': 1}, {'canal': '30', 'status': 0}], 'M1': [{'canal': '6', 'status': 2}, {'canal': '7', 'status': 1}], 'RSP': [{'canal': '1', 'status': 2}, {'canal': '0', 'status': 1}], 'Perirhinal': [{'canal': '6', 'status': 2}, {'canal': '7', 'status': 1}]}
# souris == '2205':
#     EMG = All2[:, 6]                    #EMG (2205)
#     A1 = All2[:, 31] - All2[:, 30]      #M1
#     A2 = All2[:, 21] - All2[:, 20]      #M2
#     A3 = All2[:, 18] - All2[:, 19]      #CA1 +
#     A4 = All2[:, 14] - All2[:, 14]      #CA12 *
#     A5 = -All2[:, 2]# - All2[:, 3]      #S1 *
#     A6 = All2[:, 29] - All2[:, 28]      #S1 *
#     A7 = All2[:, 30] - All2[:, 30]      #S1 *
#     A8 = All2[:, 0] - All2[:, 0]        #Perirhinal
#     A11 = All2[:, 16] - All2[:, 16]      #CA1
#     A10 = All2[:, 14] -  All2[:, 14]     #BLA
#     A9 = All2[:, 13] - All2[:, 13]       #mEC
#     label = ['EMG','RSP','Par','CA1','PFC','M1','OFC','S1','Perirhinal','BLA','mEC']
#
# EMG
# ['6']
# 6
# {'canal': '6', 'status': 1}
# M1
# ['31', '30']
# 31
# {'canal': '31', 'status': 2}
# 30
# {'canal': '30', 'status': 1}
# M2
# ['21', '20']
# 21
# {'canal': '21', 'status': 2}
# 20
# {'canal': '20', 'status': 1}
# CA1 +
# ['18', '19']
# 18
# {'canal': '18', 'status': 2}
# 19
# {'canal': '19', 'status': 1}
# CA12 *
# ['14', '14']
# 14
# {'canal': '14', 'status': 2}
# 14
# {'canal': '14', 'status': 1}
# S1 *
# ['2', '3']
# 2
# {'canal': '2', 'status': 1}
# 3
# ignoring second channel
# {'canal': '3', 'status': 0}
# S1 *
# ['29', '28']
# 29
# {'canal': '29', 'status': 2}
# 28
# {'canal': '28', 'status': 1}
# S1 *
# ['30', '30']
# 30
# {'canal': '30', 'status': 2}
# 30
# {'canal': '30', 'status': 1}
# Perirhinal
# ['0', '0']
# 0
# {'canal': '0', 'status': 2}
# 0
# {'canal': '0', 'status': 1}
# CA1
# ['16', '16']
# 16
# {'canal': '16', 'status': 2}
# 16
# {'canal': '16', 'status': 1}
# BLA
# ['14', '14']
# 14
# {'canal': '14', 'status': 2}
# 14
# {'canal': '14', 'status': 1}
# mEC
# ['13', '13']
# 13
# {'canal': '13', 'status': 2}
# 13
# {'canal': '13', 'status': 1}
#     label = ['EMG','RSP','Par','CA1','PFC','M1','OFC','S1','Perirhinal','BLA','mEC']
# []
# {'EMG': [{'canal': '6', 'status': 1}], 'M1': [{'canal': '31', 'status': 2}, {'canal': '30', 'status': 1}], 'M2': [{'canal': '21', 'status': 2}, {'canal': '20', 'status': 1}], 'CA1 +': [{'canal': '18', 'status': 2}, {'canal': '19', 'status': 1}], 'CA12 *': [{'canal': '14', 'status': 2}, {'canal': '14', 'status': 1}], 'S1 *': [{'canal': '30', 'status': 2}, {'canal': '30', 'status': 1}], 'Perirhinal': [{'canal': '0', 'status': 2}, {'canal': '0', 'status': 1}], 'CA1': [{'canal': '16', 'status': 2}, {'canal': '16', 'status': 1}], 'BLA': [{'canal': '14', 'status': 2}, {'canal': '14', 'status': 1}], 'mEC': [{'canal': '13', 'status': 2}, {'canal': '13', 'status': 1}], "    label = ['EMG','RSP','Par','CA1','PFC','M1','OFC','S1','Perirhinal','BLA','mEC']": []}
# souris == 'M19': ## OPPK long stim
#     EMG = All2[:, 6]                    #EMG (M19)
#     A1 = All2[:, 25] - All2[:, 24]      #front
#     A2 = All2[:, 21] - All2[:, 20]      #M1
#     A3 = All2[:, 19] - All2[:, 18]      #M2
#     A3 = All2[:, 12] - All2[:, 13]      #CA1ipsi
#     A4 = All2[:, 15] - All2[:, 14]      #S1tr
#     A5 = All2[:, 11] - All2[:, 10]      #S1bf
#     A6 = All2[:, 26] - All2[:, 27]      #S1contra
#     A7 = All2[:, 16] - All2[:, 17]      #S1fl
#     A8 = All2[:, 0] - All2[:, 1]        #RSA
#     A9 = All2[:, 9] - All2[:, 8]        #Aud
#     A10 = All2[:, 23] -  All2[:, 22]    #M2
#     A11 = All2[:, 3] - All2[:, 2]       #V1
#     A12 = All2[:, 4] - All2[:, 5]       #V2
#     A12 = All2[:, 30] - All2[:, 31]       #CA1contra
#     label = ['EMG','RSP','Par','CA1','PFC','M1','OFC','S1','Perirhinal','BLA','mEC']
#
# EMG
# ['6']
# 6
# {'canal': '6', 'status': 1}
# front
# ['25', '24']
# 25
# {'canal': '25', 'status': 2}
# 24
# {'canal': '24', 'status': 1}
# M1
# ['21', '20']
# 21
# {'canal': '21', 'status': 2}
# 20
# {'canal': '20', 'status': 1}
# M2
# ['19', '18']
# 19
# {'canal': '19', 'status': 2}
# 18
# {'canal': '18', 'status': 1}
# CA1ipsi
# ['12', '13']
# 12
# {'canal': '12', 'status': 2}
# 13
# {'canal': '13', 'status': 1}
# S1tr
# ['15', '14']
# 15
# {'canal': '15', 'status': 2}
# 14
# {'canal': '14', 'status': 1}
# S1bf
# ['11', '10']
# 11
# {'canal': '11', 'status': 2}
# 10
# {'canal': '10', 'status': 1}
# S1contra
# ['26', '27']
# 26
# {'canal': '26', 'status': 2}
# 27
# {'canal': '27', 'status': 1}
# S1fl
# ['16', '17']
# 16
# {'canal': '16', 'status': 2}
# 17
# {'canal': '17', 'status': 1}
# RSA
# ['0', '1']
# 0
# {'canal': '0', 'status': 2}
# 1
# {'canal': '1', 'status': 1}
# Aud
# ['9', '8']
# 9
# {'canal': '9', 'status': 2}
# 8
# {'canal': '8', 'status': 1}
# M2
# ['23', '22']
# 23
# {'canal': '23', 'status': 2}
# 22
# {'canal': '22', 'status': 1}
# V1
# ['3', '2']
# 3
# {'canal': '3', 'status': 2}
# 2
# {'canal': '2', 'status': 1}
# V2
# ['4', '5']
# 4
# {'canal': '4', 'status': 2}
# 5
# {'canal': '5', 'status': 1}
# CA1contra
# ['30', '31']
# 30
# {'canal': '30', 'status': 2}
# 31
# {'canal': '31', 'status': 1}
#     label = ['EMG','RSP','Par','CA1','PFC','M1','OFC','S1','Perirhinal','BLA','mEC']
# []
# {'EMG': [{'canal': '6', 'status': 1}], 'front': [{'canal': '25', 'status': 2}, {'canal': '24', 'status': 1}], 'M1': [{'canal': '21', 'status': 2}, {'canal': '20', 'status': 1}], 'M2': [{'canal': '23', 'status': 2}, {'canal': '22', 'status': 1}], 'CA1ipsi': [{'canal': '12', 'status': 2}, {'canal': '13', 'status': 1}], 'S1tr': [{'canal': '15', 'status': 2}, {'canal': '14', 'status': 1}], 'S1bf': [{'canal': '11', 'status': 2}, {'canal': '10', 'status': 1}], 'S1contra': [{'canal': '26', 'status': 2}, {'canal': '27', 'status': 1}], 'S1fl': [{'canal': '16', 'status': 2}, {'canal': '17', 'status': 1}], 'RSA': [{'canal': '0', 'status': 2}, {'canal': '1', 'status': 1}], 'Aud': [{'canal': '9', 'status': 2}, {'canal': '8', 'status': 1}], 'V1': [{'canal': '3', 'status': 2}, {'canal': '2', 'status': 1}], 'V2': [{'canal': '4', 'status': 2}, {'canal': '5', 'status': 1}], 'CA1contra': [{'canal': '30', 'status': 2}, {'canal': '31', 'status': 1}], "    label = ['EMG','RSP','Par','CA1','PFC','M1','OFC','S1','Perirhinal','BLA','mEC']": []}
# souris == 'alien': # à analyser
#     EMG = All2[:, 7]                    #EMG (alien)
#     A1 = All2[:, 28] - All2[:, 29]         #Par *
#     A2 = All2[:, 1] - All2[:, 0]       #PFC *
#     A3 = All2[:, 18] - All2[:, 19]       #OFC
#     A4 = All2[:, 14] - All2[:, 15]         #S1 *
#     A5 = All2[:, 24] - All2[:, 25]       #BLA
#     A6 = All2[:, 22] #- All2[:, 23]         #mEC
#     A7 = All2[:, 2] - All2[:, 3]       #CA1 +
#     A8 = All2[:, 10] -  All2[:, 11]       #M1 *
#     A9 = All2[:, 5] - All2[:, 4]         #RSP *
#     A10 = All2[:, 7]# - All2[:, 3]        #VIDE
#
# EMG
# ['7']
# 7
# {'canal': '7', 'status': 1}
# Par *
# ['28', '29']
# 28
# {'canal': '28', 'status': 2}
# 29
# {'canal': '29', 'status': 1}
# PFC *
# ['1', '0']
# 1
# {'canal': '1', 'status': 2}
# 0
# {'canal': '0', 'status': 1}
# OFC
# ['18', '19']
# 18
# {'canal': '18', 'status': 2}
# 19
# {'canal': '19', 'status': 1}
# S1 *
# ['14', '15']
# 14
# {'canal': '14', 'status': 2}
# 15
# {'canal': '15', 'status': 1}
# BLA
# ['24', '25']
# 24
# {'canal': '24', 'status': 2}
# 25
# {'canal': '25', 'status': 1}
# mEC
# ['22', '23']
# 22
# {'canal': '22', 'status': 1}
# 23
# ignoring second channel
# {'canal': '23', 'status': 0}
# CA1 +
# ['2', '3']
# 2
# {'canal': '2', 'status': 2}
# 3
# {'canal': '3', 'status': 1}
# M1 *
# ['10', '11']
# 10
# {'canal': '10', 'status': 2}
# 11
# {'canal': '11', 'status': 1}
# RSP *
# ['5', '4']
# 5
# {'canal': '5', 'status': 2}
# 4
# {'canal': '4', 'status': 1}
# VIDE
# ['7', '3']
# 7
# {'canal': '7', 'status': 1}
# 3
# ignoring second channel
# {'canal': '3', 'status': 0}
# {'EMG': [{'canal': '7', 'status': 1}], 'Par *': [{'canal': '28', 'status': 2}, {'canal': '29', 'status': 1}], 'PFC *': [{'canal': '1', 'status': 2}, {'canal': '0', 'status': 1}], 'OFC': [{'canal': '18', 'status': 2}, {'canal': '19', 'status': 1}], 'S1 *': [{'canal': '14', 'status': 2}, {'canal': '15', 'status': 1}], 'BLA': [{'canal': '24', 'status': 2}, {'canal': '25', 'status': 1}], 'mEC': [{'canal': '22', 'status': 1}, {'canal': '23', 'status': 0}], 'CA1 +': [{'canal': '2', 'status': 2}, {'canal': '3', 'status': 1}], 'M1 *': [{'canal': '10', 'status': 2}, {'canal': '11', 'status': 1}], 'RSP *': [{'canal': '5', 'status': 2}, {'canal': '4', 'status': 1}], 'VIDE': [{'canal': '7', 'status': 1}, {'canal': '3', 'status': 0}]}
# souris == 'apaiser': # A analyser
#     EMG = All2[:, 6]                    #EMG (apaiser)
#     A1 = All2[:, 28] - All2[:, 27]      #Par *
#     A2 = All2[:, 24] #- All2[:, 25]       #PFC *
#     A3 = All2[:, 19] - All2[:, 20]       #OFC *
#     A4 = All2[:, 22] - All2[:, 23]         #S1 *
#     A5 = All2[:, 15] - All2[:, 16]       #BLA
#     A6 = All2[:, 11] - All2[:, 12]         #mEC +
#     A7 = All2[:, 0] - All2[:, 31]       #CA1 +
#     A8 = All2[:, 1] #-  All2[:, 2]       #M1 *
#     A9 = All2[:, 4] - All2[:, 3]         #RSP
#     A10 = All2[:, 6]# - All2[:, 3]        #VIDE
#
# EMG
# ['6']
# 6
# {'canal': '6', 'status': 1}
# Par *
# ['28', '27']
# 28
# {'canal': '28', 'status': 2}
# 27
# {'canal': '27', 'status': 1}
# PFC *
# ['24', '25']
# 24
# {'canal': '24', 'status': 1}
# 25
# ignoring second channel
# {'canal': '25', 'status': 0}
# OFC *
# ['19', '20']
# 19
# {'canal': '19', 'status': 2}
# 20
# {'canal': '20', 'status': 1}
# S1 *
# ['22', '23']
# 22
# {'canal': '22', 'status': 2}
# 23
# {'canal': '23', 'status': 1}
# BLA
# ['15', '16']
# 15
# {'canal': '15', 'status': 2}
# 16
# {'canal': '16', 'status': 1}
# mEC +
# ['11', '12']
# 11
# {'canal': '11', 'status': 2}
# 12
# {'canal': '12', 'status': 1}
# CA1 +
# ['0', '31']
# 0
# {'canal': '0', 'status': 2}
# 31
# {'canal': '31', 'status': 1}
# M1 *
# ['1', '2']
# 1
# {'canal': '1', 'status': 1}
# 2
# ignoring second channel
# {'canal': '2', 'status': 0}
# RSP
# ['4', '3']
# 4
# {'canal': '4', 'status': 2}
# 3
# {'canal': '3', 'status': 1}
# VIDE
# ['6', '3']
# 6
# {'canal': '6', 'status': 1}
# 3
# ignoring second channel
# {'canal': '3', 'status': 0}
# {'EMG': [{'canal': '6', 'status': 1}], 'Par *': [{'canal': '28', 'status': 2}, {'canal': '27', 'status': 1}], 'PFC *': [{'canal': '24', 'status': 1}, {'canal': '25', 'status': 0}], 'OFC *': [{'canal': '19', 'status': 2}, {'canal': '20', 'status': 1}], 'S1 *': [{'canal': '22', 'status': 2}, {'canal': '23', 'status': 1}], 'BLA': [{'canal': '15', 'status': 2}, {'canal': '16', 'status': 1}], 'mEC +': [{'canal': '11', 'status': 2}, {'canal': '12', 'status': 1}], 'CA1 +': [{'canal': '0', 'status': 2}, {'canal': '31', 'status': 1}], 'M1 *': [{'canal': '1', 'status': 1}, {'canal': '2', 'status': 0}], 'RSP': [{'canal': '4', 'status': 2}, {'canal': '3', 'status': 1}], 'VIDE': [{'canal': '6', 'status': 1}, {'canal': '3', 'status': 0}]}
# souris == 'pervers':
#     EMG = All2[:, 24]                    #EMG (pervers)
#     A1 = All2[:, 17] - All2[:, 16]         #Par *
#     A2 = All2[:, 12] - All2[:, 13]       #PFC
#     A3 = All2[:, 8] - All2[:, 9]       #OFC
#     A4 = All2[:, 3] - All2[:, 2]         #S1 *
#     A5 = All2[:, 28] - All2[:, 29]       #BLA
#     A6 = All2[:, 27] - All2[:, 26]         #mEC
#     A7 = All2[:, 22] - All2[:, 23]       #CA1 ~+
#     A8 = All2[:, 7] -  All2[:, 6]       #M1 *
#     A9 = All2[:, 19] - All2[:, 18]         #RSP
#     A10 = All2[:, 30] - All2[:, 31]        #Perirhinal +
#
# EMG
# ['24']
# 24
# {'canal': '24', 'status': 1}
# Par *
# ['17', '16']
# 17
# {'canal': '17', 'status': 2}
# 16
# {'canal': '16', 'status': 1}
# PFC
# ['12', '13']
# 12
# {'canal': '12', 'status': 2}
# 13
# {'canal': '13', 'status': 1}
# OFC
# ['8', '9']
# 8
# {'canal': '8', 'status': 2}
# 9
# {'canal': '9', 'status': 1}
# S1 *
# ['3', '2']
# 3
# {'canal': '3', 'status': 2}
# 2
# {'canal': '2', 'status': 1}
# BLA
# ['28', '29']
# 28
# {'canal': '28', 'status': 2}
# 29
# {'canal': '29', 'status': 1}
# mEC
# ['27', '26']
# 27
# {'canal': '27', 'status': 2}
# 26
# {'canal': '26', 'status': 1}
# CA1 ~+
# ['22', '23']
# 22
# {'canal': '22', 'status': 2}
# 23
# {'canal': '23', 'status': 1}
# M1 *
# ['7', '6']
# 7
# {'canal': '7', 'status': 2}
# 6
# {'canal': '6', 'status': 1}
# RSP
# ['19', '18']
# 19
# {'canal': '19', 'status': 2}
# 18
# {'canal': '18', 'status': 1}
# Perirhinal +
# ['30', '31']
# 30
# {'canal': '30', 'status': 2}
# 31
# {'canal': '31', 'status': 1}
# {'EMG': [{'canal': '24', 'status': 1}], 'Par *': [{'canal': '17', 'status': 2}, {'canal': '16', 'status': 1}], 'PFC': [{'canal': '12', 'status': 2}, {'canal': '13', 'status': 1}], 'OFC': [{'canal': '8', 'status': 2}, {'canal': '9', 'status': 1}], 'S1 *': [{'canal': '3', 'status': 2}, {'canal': '2', 'status': 1}], 'BLA': [{'canal': '28', 'status': 2}, {'canal': '29', 'status': 1}], 'mEC': [{'canal': '27', 'status': 2}, {'canal': '26', 'status': 1}], 'CA1 ~+': [{'canal': '22', 'status': 2}, {'canal': '23', 'status': 1}], 'M1 *': [{'canal': '7', 'status': 2}, {'canal': '6', 'status': 1}], 'RSP': [{'canal': '19', 'status': 2}, {'canal': '18', 'status': 1}], 'Perirhinal +': [{'canal': '30', 'status': 2}, {'canal': '31', 'status': 1}]}
# souris == 'sleepy':
#     EMG = All2[:, 7]                    #EMG (sleepy)
#     A1 = All2[:, 0] - All2[:, 1]         #Par
#     A2 = All2[:, 3] - All2[:, 2]       #PFC +
#     A3 = All2[:, 4] - All2[:, 5]       #OFC
#     A4 = All2[:, 14] #- All2[:, 15]         #S1
#     A5 = All2[:, 18] - All2[:, 19]       #BLA
#     A6 = All2[:, 22] - All2[:, 23]         #mEC
#     A7 = All2[:, 28] - All2[:, 29]       #CA1
#     A8 = All2[:, 10] #-  All2[:, 11]       #M1
#     A9 = All2[:, 24] - All2[:, 25]         #RSP
#     A10 = All2[:, 20] - All2[:, 21]        #Perirhinal
#
# EMG
# ['7']
# 7
# {'canal': '7', 'status': 1}
# Par
# ['0', '1']
# 0
# {'canal': '0', 'status': 2}
# 1
# {'canal': '1', 'status': 1}
# PFC +
# ['3', '2']
# 3
# {'canal': '3', 'status': 2}
# 2
# {'canal': '2', 'status': 1}
# OFC
# ['4', '5']
# 4
# {'canal': '4', 'status': 2}
# 5
# {'canal': '5', 'status': 1}
# S1
# ['14', '15']
# 14
# {'canal': '14', 'status': 1}
# 15
# ignoring second channel
# {'canal': '15', 'status': 0}
# BLA
# ['18', '19']
# 18
# {'canal': '18', 'status': 2}
# 19
# {'canal': '19', 'status': 1}
# mEC
# ['22', '23']
# 22
# {'canal': '22', 'status': 2}
# 23
# {'canal': '23', 'status': 1}
# CA1
# ['28', '29']
# 28
# {'canal': '28', 'status': 2}
# 29
# {'canal': '29', 'status': 1}
# M1
# ['10', '11']
# 10
# {'canal': '10', 'status': 1}
# 11
# ignoring second channel
# {'canal': '11', 'status': 0}
# RSP
# ['24', '25']
# 24
# {'canal': '24', 'status': 2}
# 25
# {'canal': '25', 'status': 1}
# Perirhinal
# ['20', '21']
# 20
# {'canal': '20', 'status': 2}
# 21
# {'canal': '21', 'status': 1}
# {'EMG': [{'canal': '7', 'status': 1}], 'Par': [{'canal': '0', 'status': 2}, {'canal': '1', 'status': 1}], 'PFC +': [{'canal': '3', 'status': 2}, {'canal': '2', 'status': 1}], 'OFC': [{'canal': '4', 'status': 2}, {'canal': '5', 'status': 1}], 'S1': [{'canal': '14', 'status': 1}, {'canal': '15', 'status': 0}], 'BLA': [{'canal': '18', 'status': 2}, {'canal': '19', 'status': 1}], 'mEC': [{'canal': '22', 'status': 2}, {'canal': '23', 'status': 1}], 'CA1': [{'canal': '28', 'status': 2}, {'canal': '29', 'status': 1}], 'M1': [{'canal': '10', 'status': 1}, {'canal': '11', 'status': 0}], 'RSP': [{'canal': '24', 'status': 2}, {'canal': '25', 'status': 1}], 'Perirhinal': [{'canal': '20', 'status': 2}, {'canal': '21', 'status': 1}]}
# souris == 'intello':
#     EMG = All2[:, 23]                    #EMG (intello)
#     A1 = All2[:, 8] - All2[:, 9]         #Par
#     A2 = All2[:, 5] - All2[:, 4]       #PFC
#     A3 = All2[:, 6] - All2[:, 7]       #OFC
#     A4 = All2[:, 18] - All2[:, 19]         #S1
#     A5 = All2[:, 20] - All2[:, 21]       #BLA
#     A6 = All2[:, 26] - All2[:, 27]         #mEC
#     A7 = All2[:, 12] - All2[:, 13]       #CA1
#     A8 = All2[:, 30] -  All2[:, 31]       #M1
#     A9 = All2[:, 17] - All2[:, 16]         #RSP
#     A10 = All2[:, 2] - All2[:, 3]        #Perirhinal  +
#
# EMG
# ['23']
# 23
# {'canal': '23', 'status': 1}
# Par
# ['8', '9']
# 8
# {'canal': '8', 'status': 2}
# 9
# {'canal': '9', 'status': 1}
# PFC
# ['5', '4']
# 5
# {'canal': '5', 'status': 2}
# 4
# {'canal': '4', 'status': 1}
# OFC
# ['6', '7']
# 6
# {'canal': '6', 'status': 2}
# 7
# {'canal': '7', 'status': 1}
# S1
# ['18', '19']
# 18
# {'canal': '18', 'status': 2}
# 19
# {'canal': '19', 'status': 1}
# BLA
# ['20', '21']
# 20
# {'canal': '20', 'status': 2}
# 21
# {'canal': '21', 'status': 1}
# mEC
# ['26', '27']
# 26
# {'canal': '26', 'status': 2}
# 27
# {'canal': '27', 'status': 1}
# CA1
# ['12', '13']
# 12
# {'canal': '12', 'status': 2}
# 13
# {'canal': '13', 'status': 1}
# M1
# ['30', '31']
# 30
# {'canal': '30', 'status': 2}
# 31
# {'canal': '31', 'status': 1}
# RSP
# ['17', '16']
# 17
# {'canal': '17', 'status': 2}
# 16
# {'canal': '16', 'status': 1}
# Perirhinal  +
# ['2', '3']
# 2
# {'canal': '2', 'status': 2}
# 3
# {'canal': '3', 'status': 1}
# {'EMG': [{'canal': '23', 'status': 1}], 'Par': [{'canal': '8', 'status': 2}, {'canal': '9', 'status': 1}], 'PFC': [{'canal': '5', 'status': 2}, {'canal': '4', 'status': 1}], 'OFC': [{'canal': '6', 'status': 2}, {'canal': '7', 'status': 1}], 'S1': [{'canal': '18', 'status': 2}, {'canal': '19', 'status': 1}], 'BLA': [{'canal': '20', 'status': 2}, {'canal': '21', 'status': 1}], 'mEC': [{'canal': '26', 'status': 2}, {'canal': '27', 'status': 1}], 'CA1': [{'canal': '12', 'status': 2}, {'canal': '13', 'status': 1}], 'M1': [{'canal': '30', 'status': 2}, {'canal': '31', 'status': 1}], 'RSP': [{'canal': '17', 'status': 2}, {'canal': '16', 'status': 1}], 'Perirhinal  +  ': [{'canal': '2', 'status': 2}, {'canal': '3', 'status': 1}]}
# souris == 'chokbar':
#     EMG = All2[:, 23]                    #EMG (chokbar)
#     A1 = All2[:, 16] - All2[:, 17]         #Par * ch16
#     A2 = All2[:, 8] - All2[:, 9]       #PFC * ch8
#     A3 = All2[:, 6] - All2[:, 7]       #OFC
#     A4 = All2[:, 4] - All2[:, 5]         #S1 *
#     A5 = All2[:, 2] - All2[:, 3]       #BLA
#     A6 = All2[:, 26] - All2[:, 27]         #mEC
#     A7 = All2[:, 20] - All2[:, 21]       #CA1
#     A8 = All2[:, 12] -  All2[:, 13]       #M1
#     A9 = All2[:, 18] - All2[:, 19]         #RSP
#     A10 = All2[:, 30] - All2[:, 31]        #Perirhinal +
#
# EMG
# ['23']
# 23
# {'canal': '23', 'status': 1}
# Par * ch16
# ['16', '17']
# 16
# {'canal': '16', 'status': 2}
# 17
# {'canal': '17', 'status': 1}
# PFC * ch8
# ['8', '9']
# 8
# {'canal': '8', 'status': 2}
# 9
# {'canal': '9', 'status': 1}
# OFC
# ['6', '7']
# 6
# {'canal': '6', 'status': 2}
# 7
# {'canal': '7', 'status': 1}
# S1 *
# ['4', '5']
# 4
# {'canal': '4', 'status': 2}
# 5
# {'canal': '5', 'status': 1}
# BLA
# ['2', '3']
# 2
# {'canal': '2', 'status': 2}
# 3
# {'canal': '3', 'status': 1}
# mEC
# ['26', '27']
# 26
# {'canal': '26', 'status': 2}
# 27
# {'canal': '27', 'status': 1}
# CA1
# ['20', '21']
# 20
# {'canal': '20', 'status': 2}
# 21
# {'canal': '21', 'status': 1}
# M1
# ['12', '13']
# 12
# {'canal': '12', 'status': 2}
# 13
# {'canal': '13', 'status': 1}
# RSP
# ['18', '19']
# 18
# {'canal': '18', 'status': 2}
# 19
# {'canal': '19', 'status': 1}
# Perirhinal +
# ['30', '31']
# 30
# {'canal': '30', 'status': 2}
# 31
# {'canal': '31', 'status': 1}
# {'EMG': [{'canal': '23', 'status': 1}], 'Par * ch16': [{'canal': '16', 'status': 2}, {'canal': '17', 'status': 1}], 'PFC * ch8': [{'canal': '8', 'status': 2}, {'canal': '9', 'status': 1}], 'OFC': [{'canal': '6', 'status': 2}, {'canal': '7', 'status': 1}], 'S1 *': [{'canal': '4', 'status': 2}, {'canal': '5', 'status': 1}], 'BLA': [{'canal': '2', 'status': 2}, {'canal': '3', 'status': 1}], 'mEC': [{'canal': '26', 'status': 2}, {'canal': '27', 'status': 1}], 'CA1': [{'canal': '20', 'status': 2}, {'canal': '21', 'status': 1}], 'M1': [{'canal': '12', 'status': 2}, {'canal': '13', 'status': 1}], 'RSP': [{'canal': '18', 'status': 2}, {'canal': '19', 'status': 1}], 'Perirhinal +  ': [{'canal': '30', 'status': 2}, {'canal': '31', 'status': 1}]}
# souris == 'amoureux':
#     EMG = All2[:, 7]                    #EMG (amoureux) À analyser pour CA1, mais vraiment rien sur les autres
#     A1 = All2[:, 5] #- All2[:, 4]         #Par
#     A2 = All2[:, 15] - All2[:, 14]       #PFC *
#     A3 = All2[:, 0] - All2[:, 1]       #OFC
#     A4 = All2[:, 3] - All2[:, 2]         #S1 *
#     A5 = All2[:, 22] - All2[:, 23]       #BLA
#     A6 = All2[:, 24] - All2[:, 25]         #mEC
#     A7 = All2[:, 21] - All2[:, 20]       #CA1 +
#     A8 = All2[:, 18] -  All2[:, 19]       #M1 *
#     A9 = All2[:, 11] - All2[:, 10]         #RSP
#     A10 = All2[:, 28] - All2[:, 29]        #Perirhinal
#
# EMG
# ['7']
# 7
# {'canal': '7', 'status': 1}
# Par
# ['5', '4']
# 5
# {'canal': '5', 'status': 1}
# 4
# ignoring second channel
# {'canal': '4', 'status': 0}
# PFC *
# ['15', '14']
# 15
# {'canal': '15', 'status': 2}
# 14
# {'canal': '14', 'status': 1}
# OFC
# ['0', '1']
# 0
# {'canal': '0', 'status': 2}
# 1
# {'canal': '1', 'status': 1}
# S1 *
# ['3', '2']
# 3
# {'canal': '3', 'status': 2}
# 2
# {'canal': '2', 'status': 1}
# BLA
# ['22', '23']
# 22
# {'canal': '22', 'status': 2}
# 23
# {'canal': '23', 'status': 1}
# mEC
# ['24', '25']
# 24
# {'canal': '24', 'status': 2}
# 25
# {'canal': '25', 'status': 1}
# CA1 +
# ['21', '20']
# 21
# {'canal': '21', 'status': 2}
# 20
# {'canal': '20', 'status': 1}
# M1 *
# ['18', '19']
# 18
# {'canal': '18', 'status': 2}
# 19
# {'canal': '19', 'status': 1}
# RSP
# ['11', '10']
# 11
# {'canal': '11', 'status': 2}
# 10
# {'canal': '10', 'status': 1}
# Perirhinal
# ['28', '29']
# 28
# {'canal': '28', 'status': 2}
# 29
# {'canal': '29', 'status': 1}
# {'EMG': [{'canal': '7', 'status': 1}], 'Par': [{'canal': '5', 'status': 1}, {'canal': '4', 'status': 0}], 'PFC *': [{'canal': '15', 'status': 2}, {'canal': '14', 'status': 1}], 'OFC': [{'canal': '0', 'status': 2}, {'canal': '1', 'status': 1}], 'S1 *': [{'canal': '3', 'status': 2}, {'canal': '2', 'status': 1}], 'BLA': [{'canal': '22', 'status': 2}, {'canal': '23', 'status': 1}], 'mEC': [{'canal': '24', 'status': 2}, {'canal': '25', 'status': 1}], 'CA1 +': [{'canal': '21', 'status': 2}, {'canal': '20', 'status': 1}], 'M1 *': [{'canal': '18', 'status': 2}, {'canal': '19', 'status': 1}], 'RSP': [{'canal': '11', 'status': 2}, {'canal': '10', 'status': 1}], 'Perirhinal ': [{'canal': '28', 'status': 2}, {'canal': '29', 'status': 1}]}
# souris == 'evil':
#     EMG = All2[:, 7]                    #EMG (evil)
#     A1 = All2[:, 3] - All2[:, 2]         #Par * moche, pas forcément crédible
#     A2 = All2[:, 25] - All2[:, 24]       #PFC *
#     A3 = All2[:, 22] - All2[:, 23]       #OFC *
#     A4 = All2[:, 4] - All2[:, 5]         #S1 *
#     A5 = All2[:, 18] - All2[:, 19]       #BLA
#     A6 = All2[:, 10] - All2[:, 11]         #mEC
#     A7 = All2[:, 20] - All2[:, 21]       #CA1 +
#     A8 = All2[:, 28] -  All2[:, 29]       #M1 *
#     A9 = All2[:, 1] - All2[:, 0]         #RSP
#     A10 = All2[:, 14] - All2[:, 15]        #Perirhinal  +
#
# EMG
# ['7']
# 7
# {'canal': '7', 'status': 1}
# Par * moche, pas forcément crédible
# ['3', '2']
# 3
# {'canal': '3', 'status': 2}
# 2
# {'canal': '2', 'status': 1}
# PFC *
# ['25', '24']
# 25
# {'canal': '25', 'status': 2}
# 24
# {'canal': '24', 'status': 1}
# OFC *
# ['22', '23']
# 22
# {'canal': '22', 'status': 2}
# 23
# {'canal': '23', 'status': 1}
# S1 *
# ['4', '5']
# 4
# {'canal': '4', 'status': 2}
# 5
# {'canal': '5', 'status': 1}
# BLA
# ['18', '19']
# 18
# {'canal': '18', 'status': 2}
# 19
# {'canal': '19', 'status': 1}
# mEC
# ['10', '11']
# 10
# {'canal': '10', 'status': 2}
# 11
# {'canal': '11', 'status': 1}
# CA1 +
# ['20', '21']
# 20
# {'canal': '20', 'status': 2}
# 21
# {'canal': '21', 'status': 1}
# M1 *
# ['28', '29']
# 28
# {'canal': '28', 'status': 2}
# 29
# {'canal': '29', 'status': 1}
# RSP
# ['1', '0']
# 1
# {'canal': '1', 'status': 2}
# 0
# {'canal': '0', 'status': 1}
# Perirhinal  +
# ['14', '15']
# 14
# {'canal': '14', 'status': 2}
# 15
# {'canal': '15', 'status': 1}
# {'EMG': [{'canal': '7', 'status': 1}], 'Par * moche, pas forcément crédible': [{'canal': '3', 'status': 2}, {'canal': '2', 'status': 1}], 'PFC *': [{'canal': '25', 'status': 2}, {'canal': '24', 'status': 1}], 'OFC *': [{'canal': '22', 'status': 2}, {'canal': '23', 'status': 1}], 'S1 *': [{'canal': '4', 'status': 2}, {'canal': '5', 'status': 1}], 'BLA': [{'canal': '18', 'status': 2}, {'canal': '19', 'status': 1}], 'mEC': [{'canal': '10', 'status': 2}, {'canal': '11', 'status': 1}], 'CA1 +': [{'canal': '20', 'status': 2}, {'canal': '21', 'status': 1}], 'M1 *': [{'canal': '28', 'status': 2}, {'canal': '29', 'status': 1}], 'RSP': [{'canal': '1', 'status': 2}, {'canal': '0', 'status': 1}], 'Perirhinal  +': [{'canal': '14', 'status': 2}, {'canal': '15', 'status': 1}]}
# souris == 'explode':
#     EMG = All2[:, 7]                    #EMG (explode) sadly no spindles on Par, PFC, OFC and M1 even with 1 channel
#     A1 = All2[:, 6] - All2[:, 5]         #Par
#     A2 = All2[:, 10] - All2[:, 11]       #PFC
#     A3 = All2[:, 6] - All2[:, 5]       #OFC
#     A4 = All2[:, 1] - All2[:, 2]         #S1 *
#     A5 = All2[:, 14] - All2[:, 15]       #BLA -> des moments de coordination avec CA1
#     A6 = All2[:, 25] #- All2[:, 25]         #mEC
#     A7 = All2[:, 19] - All2[:, 18]       #CA1 +
#     A8 = All2[:, 4] -  All2[:, 3]       #M1 *
#     A9 = All2[:, 22] - All2[:, 23]         #RSP
#     A10 = All2[:, 30] - All2[:, 29]        #Perirhinal +
#
# EMG
# ['7']
# 7
# {'canal': '7', 'status': 1}
# Par
# ['6', '5']
# 6
# {'canal': '6', 'status': 2}
# 5
# {'canal': '5', 'status': 1}
# PFC
# ['10', '11']
# 10
# {'canal': '10', 'status': 2}
# 11
# {'canal': '11', 'status': 1}
# OFC
# ['6', '5']
# 6
# {'canal': '6', 'status': 2}
# 5
# {'canal': '5', 'status': 1}
# S1 *
# ['1', '2']
# 1
# {'canal': '1', 'status': 2}
# 2
# {'canal': '2', 'status': 1}
# BLA -> des moments de coordination avec CA1
# ['14', '15']
# 14
# {'canal': '14', 'status': 2}
# 15
# {'canal': '15', 'status': 1}
# mEC
# ['25', '25']
# 25
# {'canal': '25', 'status': 1}
# 25
# ignoring second channel
# {'canal': '25', 'status': 0}
# CA1 +
# ['19', '18']
# 19
# {'canal': '19', 'status': 2}
# 18
# {'canal': '18', 'status': 1}
# M1 *
# ['4', '3']
# 4
# {'canal': '4', 'status': 2}
# 3
# {'canal': '3', 'status': 1}
# RSP
# ['22', '23']
# 22
# {'canal': '22', 'status': 2}
# 23
# {'canal': '23', 'status': 1}
# Perirhinal +
# ['30', '29']
# 30
# {'canal': '30', 'status': 2}
# 29
# {'canal': '29', 'status': 1}
# {'EMG': [{'canal': '7', 'status': 1}], 'Par': [{'canal': '6', 'status': 2}, {'canal': '5', 'status': 1}], 'PFC': [{'canal': '10', 'status': 2}, {'canal': '11', 'status': 1}], 'OFC': [{'canal': '6', 'status': 2}, {'canal': '5', 'status': 1}], 'S1 *': [{'canal': '1', 'status': 2}, {'canal': '2', 'status': 1}], 'BLA -> des moments de coordination avec CA1': [{'canal': '14', 'status': 2}, {'canal': '15', 'status': 1}], 'mEC': [{'canal': '25', 'status': 1}, {'canal': '25', 'status': 0}], 'CA1 +': [{'canal': '19', 'status': 2}, {'canal': '18', 'status': 1}], 'M1 *': [{'canal': '4', 'status': 2}, {'canal': '3', 'status': 1}], 'RSP': [{'canal': '22', 'status': 2}, {'canal': '23', 'status': 1}], 'Perirhinal +   ': [{'canal': '30', 'status': 2}, {'canal': '29', 'status': 1}]}
# souris == 'dead':
#     EMG = All2[:, 7]                    #EMG (dead)
#     A1 = All2[:, 4] - All2[:, 5]         #Par
#     A2 = All2[:, 19] - All2[:, 18]       #PFC
#     A3 = All2[:, 11] - All2[:, 10]       #OFC
#     A4 = All2[:, 21] - All2[:, 20]         #S1
#     A5 = All2[:, 22] - All2[:, 23]       #BLA
#     A6 = All2[:, 24] #- All2[:, 25]         #mEC
#     A7 = All2[:, 2] #- All2[:, 3]       #CA1
#     A8 = All2[:, 15] -  All2[:, 14]       #M1
#     A9 = All2[:, 1] - All2[:, 0]         #RSP
#     A10 = All2[:, 28] - All2[:, 29]        #Perirhinal +
#
# EMG
# ['7']
# 7
# {'canal': '7', 'status': 1}
# Par
# ['4', '5']
# 4
# {'canal': '4', 'status': 2}
# 5
# {'canal': '5', 'status': 1}
# PFC
# ['19', '18']
# 19
# {'canal': '19', 'status': 2}
# 18
# {'canal': '18', 'status': 1}
# OFC
# ['11', '10']
# 11
# {'canal': '11', 'status': 2}
# 10
# {'canal': '10', 'status': 1}
# S1
# ['21', '20']
# 21
# {'canal': '21', 'status': 2}
# 20
# {'canal': '20', 'status': 1}
# BLA
# ['22', '23']
# 22
# {'canal': '22', 'status': 2}
# 23
# {'canal': '23', 'status': 1}
# mEC
# ['24', '25']
# 24
# {'canal': '24', 'status': 1}
# 25
# ignoring second channel
# {'canal': '25', 'status': 0}
# CA1
# ['2', '3']
# 2
# {'canal': '2', 'status': 1}
# 3
# ignoring second channel
# {'canal': '3', 'status': 0}
# M1
# ['15', '14']
# 15
# {'canal': '15', 'status': 2}
# 14
# {'canal': '14', 'status': 1}
# RSP
# ['1', '0']
# 1
# {'canal': '1', 'status': 2}
# 0
# {'canal': '0', 'status': 1}
# Perirhinal +
# ['28', '29']
# 28
# {'canal': '28', 'status': 2}
# 29
# {'canal': '29', 'status': 1}
# {'EMG': [{'canal': '7', 'status': 1}], 'Par': [{'canal': '4', 'status': 2}, {'canal': '5', 'status': 1}], 'PFC': [{'canal': '19', 'status': 2}, {'canal': '18', 'status': 1}], 'OFC': [{'canal': '11', 'status': 2}, {'canal': '10', 'status': 1}], 'S1': [{'canal': '21', 'status': 2}, {'canal': '20', 'status': 1}], 'BLA': [{'canal': '22', 'status': 2}, {'canal': '23', 'status': 1}], 'mEC': [{'canal': '24', 'status': 1}, {'canal': '25', 'status': 0}], 'CA1 ': [{'canal': '2', 'status': 1}, {'canal': '3', 'status': 0}], 'M1': [{'canal': '15', 'status': 2}, {'canal': '14', 'status': 1}], 'RSP': [{'canal': '1', 'status': 2}, {'canal': '0', 'status': 1}], 'Perirhinal +': [{'canal': '28', 'status': 2}, {'canal': '29', 'status': 1}]}
