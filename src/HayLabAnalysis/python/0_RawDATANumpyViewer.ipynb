# %% [markdown]
# # This is just a notebook to visualise 1kHz filtered raw data

# %% [markdown]
# ## Setup everything

# %% [markdown]
# ### Import packages

# %%
# %load_ext autoreload
# %autoreload 2
# %reload_ext autoreload
import os
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd

from ephyviewer import mkQApp, MainViewer, TraceViewer, TimeFreqViewer, InMemoryAnalogSignalSource, EventList, VideoViewer
from ephyviewer import AnalogSignalSourceWithScatter, SpikeInterfaceRecordingSource, InMemoryEventSource, MultiVideoFileSource, FrameGrabber

import HayLabAnalysis as hla
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 13
#      10 from ephyviewer import mkQApp, MainViewer, TraceViewer, TimeFreqViewer, InMemoryAnalogSignalSource, EventList, VideoViewer
#      11 from ephyviewer import AnalogSignalSourceWithScatter, SpikeInterfaceRecordingSource, InMemoryEventSource, MultiVideoFileSource, FrameGrabber
# ---> 13 import HayLabAnalysis as hla
#
# ModuleNotFoundError: No module named 'HayLabAnalysis'

# %% [markdown]
# ## Choose experiment
# Select the folder of the experiment to display. If the experiment was already analyzed, you can select the iterimAnalysis folder. Otherwise select the raw data recording folder.

# %%
theExpe = hla.experiment()
# Out:
# Local config file loaded from localConfig.ini
# reseting vars
# current folder C:\Users\Manip7\Documents\data\Bonsai_data\Users\Manip7\Documents\data\Bonsai_data\Lou\interimAnalysis\TestGcamp8\2025_01_10\Homecage_10_01_22 contains a config file
# C:\Users\Manip7\Documents\data\Bonsai_data\Users\Manip7\Documents\data\Bonsai_data\Lou\interimAnalysis\TestGcamp8\2025_01_10\Homecage_10_01_22\expeConfig1.ini saved
# FileChooser(path='C:\Users\Manip7\Documents\data\Bonsai_data\Users\Manip7\Documents\data\Bonsai_data\Lou\inter…

# %% [markdown]
# ## Load Data

# %% [markdown]
# ### Map the whole data into memory

# %%
theExpe.analyseExpe_findData(fullSampling=False)
#theExpe.setnum_lfp_channels(32)
# Out:
# could not load channel map. Please make sure the animalID TestGcamp8 is mapped in the file C:\Users\Manip7\Documents\data\Bonsai_data\Users\Manip7\Documents\data\Bonsai_data\Lou\interimAnalysis\2025_01_10\TestGcamp8\channelMaps.ini
# ********found recording start timestamp********
# recording started on 2025-01-10 10:01:22.198592+01:00
# ********found some .bin files********
# [WindowsPath('C:/Users/Manip7/Documents/data/Bonsai_data/Lou/TestGcamp8/2025_01_10/Homecage_10_01_22/Lou_OE_data_1_2025-01-10T10_02_20.bin')]
# data recorded with Bonsai
# importing C:\Users\Manip7\Documents\data\Bonsai_data\Lou\TestGcamp8\2025_01_10\Homecage_10_01_22\Lou_OE_data_1_2025-01-10T10_02_20.bin
# applying offset
# converting to int16
# IntanLFP file loaded, with 32 channels and 9564416 datapoint
# the mapping: None
# the offset:  0
# the sampling rate:  1000
# timestamps basename in file name is TS
# the calculated sampling rate is 999.8712246966139 Hz
# the recording took 57.8552976 s to start
# ********found some OE TTL in files********
# ********found some Miniscope files********
# miniscope realigned
# ********found some webcam files********
# webcam realigned

# %% [markdown]
# ### Extract submatrix of interest

# %%
#initiate combined and channelLabels
combined =  {}
channelLabels = {}
sample_rates = {}
t_start = {}

# %%
#LFP
if 'OE_LFP' in theExpe.data:
    sample_rates['LFP'] = theExpe.data['OE_LFP'].sampling_rate #20000
    t_start['LFP'] = theExpe.data['OE_LFP'].start
    combined['LFP'] = theExpe.data['OE_LFP'].combineStructures(None)#['M1'])
    channelLabels['LFP'] = theExpe.data['OE_LFP'].channelLabels[:]
    print("LFP data combined")
else:
    print("no LFP data to combine")
print()
# Out:
# LFP data combined

# %%
#LFP
if 'LFP_DS' in theExpe.data:
    theExpe.data['LFP_DS'].sampling_rate=1000
    theExpe.data['LFP_DS'].start=0
    print(theExpe.data['LFP_DS'].sampling_rate)

    sample_rates['LFP_DS'] = theExpe.data['LFP_DS'].sampling_rate #20000
    t_start['LFP_DS'] = theExpe.data['LFP_DS'].start
    combined['LFP_DS'] = theExpe.data['LFP_DS'].combineStructures("All")#['M1'])
    channelLabels['LFP_DS'] = theExpe.data['LFP_DS'].channelLabels[:]
    print("LFP data combined")
else:
    print("no LFP data to combine")
# Out:
# no LFP data to combine

# %%
#NPX
if 'NPX' in theExpe.data:
    sample_rates['NPX'] = theExpe.data['NPX'].sampling_rate #30000
    t_start['NPX'] = theExpe.data['NPX'].start
    combined['NPX'] = theExpe.data['NPX'].signal['spike']
    channelLabels['NPX'] = theExpe.data['NPX'].channelLabels
    print("NPX data combined")
else:
    print("no NPX data to combine")
# Out:
# no NPX data to combine

# %%
if 'Spindles' in theExpe.data:
    structure = 'M1'
    All_Spindle = theExpe.data['Spindles'][structure]
    print(All_Spindle)

# %%
#this cell can be used to plot very precisely time of interest. Beware that it conflicts with ephyviewer however. It might be possible to have 2 notebooks open simultanéeously...
if False:
    # %matplotlib widget
    #you can confiure a y-offset and some scaling, have a look at the help of superCleanPlot
    hla.tools.superCleanPlot(theExpe.data['OE_LFP'], theExpe.data['NPX'], structureLFP='All', canauxNPX=np.arange(240,260), time=2577.8, offset=50, pre=0.5, post=0.5) #canauxLFP=16, 
    picFN = theExpe.expe_path / 'NPX3-2577H.svg'
    plt.savefig(picFN, format="svg")

# %% [markdown]
# ## Display

# %%
# %gui qt
app = mkQApp()

#Create the main window that can contain several viewers
win = MainViewer(debug=True)

if 'LFP' in combined:
    print(np.round(sample_rates['LFP']))
    source = InMemoryAnalogSignalSource(combined['LFP'], np.round(sample_rates['LFP']), t_start['LFP'], channel_names=channelLabels['LFP'])
    view1 = TraceViewer(source=source, name = 'LFP')

    #Parameters can be set in script
    view1.params['display_labels'] = True
    view1.params['scale_mode'] = 'same_for_all'
    view1.auto_scale()

    cmap = matplotlib.colormaps["hsv"]#Wistia"]
    nCh = len(view1.by_channel_params.children())
    for ch in range(nCh):
        #view1.by_channel_params[f'ch{ch}', 'gain'] = 0.00002
        #view1.by_channel_params[f'ch{ch}', 'offset'] = 0.1
        view1.by_channel_params[f'ch{ch}', 'color'] = matplotlib.colors.to_hex(cmap(ch/nCh), keep_alpha=False)
        pass

    #create a time freq viewer conencted to the same source
    view2 = TimeFreqViewer(source=source, name='tfr')
    view2.params['show_axis'] = False
    view2.params['timefreq', 'deltafreq'] = 1
    #view2.by_channel_params['ch3', 'visible'] = False
    view2.auto_scale()

    win.add_view(view1)
    win.add_view(view2)

if 'LFP_DS' in combined:

    if All_Spindle is not None:
        #Create one data source with 3 event channel
        all_events = []
        conditions = ['All','Good','Bad']
        for c,cond in enumerate(conditions):
            match cond:
                case 'All':
                    selection = "All_Spindle['toKeep'] | ~All_Spindle['toKeep']"
                case 'Good':
                    selection = "All_Spindle['toKeep']"
                case 'Bad':
                    selection = "~All_Spindle['toKeep']"
            ev_times = hla.convertTheoricIndex2realTime(All_Spindle.loc[pd.eval(selection),'peak time'].values, realFreq=sample_rates['LFP_DS'], offset=t_start['LFP_DS'])
            ev_labels = [f'spindle {i}'for i in All_Spindle[pd.eval(selection)].index]
            all_events.append({ 'time':ev_times, 'label':ev_labels, 'name': conditions[c] })
        source_ev = InMemoryEventSource(all_events=all_events)

        Spindle_peak = All_Spindle['peak time'].astype(int)
        Spindle_start = All_Spindle['start time'].astype(int)
        Spindle_end = All_Spindle['end time'].astype(int)

        #create 2 familly scatters from theses 2 indexes
        scatter_indexes = {0: Spindle_peak, 1: Spindle_start, 2: Spindle_end}
        #and asign them to some channels each
        scatter_channels = {0: [0], 1: [0], 2: [0]}
        source = AnalogSignalSourceWithScatter(combined['LFP_DS'], sample_rates['LFP_DS'], t_start['LFP_DS'], scatter_indexes, scatter_channels, channel_names=channelLabels['LFP_DS'])
        view_Events = EventList(source=source_ev, name='event')
        
    else:
        source = InMemoryAnalogSignalSource(combined['LFP_DS'], sample_rates['LFP_DS'], t_start['LFP_DS'], channel_names=channelLabels['LFP_DS'])
        view_Events = None
    view_DS = TraceViewer(source=source, name = 'LFP_DS')

    #Parameters can be set in script
    view_DS.params['display_labels'] = True
    view_DS.params['scale_mode'] = 'same_for_all'
    view_DS.auto_scale()

    cmap = matplotlib.colormaps["hsv"]#Wistia"]
    nCh = len(view_DS.by_channel_params.children())
    for ch in range(nCh):
        #view_DS.by_channel_params[f'ch{ch}', 'gain'] = 0.00002
        #view_DS.by_channel_params[f'ch{ch}', 'offset'] = 0.1
        view_DS.by_channel_params[f'ch{ch}', 'color'] = matplotlib.colors.to_hex(cmap(ch/nCh), keep_alpha=False)
        pass

    #create a time freq viewer conencted to the same source
    viewTFR_DS = TimeFreqViewer(source=source, name='tfr')
    viewTFR_DS.params['show_axis'] = False
    viewTFR_DS.params['timefreq', 'deltafreq'] = 1
    #viewTFR_DS.by_channel_params['ch3', 'visible'] = False
    viewTFR_DS.auto_scale()

    win.add_view(view_DS)
    win.add_view(viewTFR_DS)

    
else:
    view_Events=None


if 'NPX' in combined:
    sig_source = SpikeInterfaceRecordingSource(recording=combined['NPX'], high_precision=False)
    view3 = TraceViewer(source=sig_source, name='NPX')
    win.add_view(view3)

    #Parameters can be set in script
    view3.params['display_labels'] = True
    view3.params['scale_mode'] = 'same_for_all'
    view3.auto_scale()

    cmap = matplotlib.colormaps["hsv"]#Wistia"]
    nCh = len(view3.by_channel_params.children())
    for ch in range(nCh):
        #view3.by_channel_params[f'ch{ch}', 'gain'] = 0.00002
        #view3.by_channel_params[f'ch{ch}', 'offset'] = 0.1
        view3.by_channel_params[f'ch{ch}', 'color'] = matplotlib.colors.to_hex(cmap(ch/nCh), keep_alpha=False)
        pass

if 'miniscope' in theExpe.data:
    vtM=theExpe.data['ttl'].getTTLTimes(theExpe.data['OE_LFP'].sampling_rate)
    #vtM=theExpe.data['miniscope'].times[:]
    print(vtM)
    video_source = MultiVideoFileSource(video_filenames=theExpe.data['miniscope'].files_list, video_times=vtM)
    print(video_source.nb_frames)
    print([x.shape for x in vtM])
    viewMiniscope = VideoViewer(source=video_source, name='miniscope')
    win.add_view(viewMiniscope)

if 'webcam' in theExpe.data:
    vt=theExpe.data['webcam'].times
    print(vt)
    video_source_WC = MultiVideoFileSource(video_filenames=theExpe.data['webcam'].files_list, video_times=vt)
    #video_source.t_starts=starts
    print(video_source_WC.nb_frames)
    viewWebcam = VideoViewer(source=video_source_WC, name='webcam')
    win.add_view(viewWebcam)

if view_Events is not None:
    win.add_view(view_Events)


#Run
win.show()
# Out:
# debug True
# QT_MODE PySide6
# 1000
# auto_scale same_for_all
# compute_auto_clim
# [ True False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False]
# refresh duration for LFP 0.0 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.001489400863647461 s
# [array([ 30.790104 ,  30.829464 ,  30.8665584, ..., 329.9586416,
#        329.9920368, 330.0256496]), array([1230.798744 , 1230.8424944, 1230.8752496, ..., 1530.1229424,
#        1530.1600112, 1530.1919216]), array([2430.9315312, 2430.9627504, 2430.9919216, ..., 2730.2893808,
#        2730.324632 , 2730.3565808]), array([3631.1097712, 3631.1414896, 3631.1718512, ..., 3930.4589296,
#        3930.4899312, 3930.530136 ]), array([4831.295896 , 4831.3274096, 4831.356888 , ..., 5130.6211696,
#        5130.6529776, 5130.6855408])]
# [8908, 8911, 8914, 8914, 8916]
# [(8909,), (8912,), (8915,), (8915,), (8917,)]
# refresh duration for LFP 0.00099945068359375 s
# refresh duration for tfr 0.0020012855529785156 s
# refresh duration for miniscope 0.0009996891021728516 s
# [array([115.75815117, 115.78697023, 115.81806761, ..., 477.4712967 ,
#        477.50378663, 477.5358072 ]), array([1315.95994396, 1315.98882509, 1316.01993227, ..., 1668.37771765,
#        1668.42326601, 1668.45211447]), array([2516.49203842, 2516.52426919, 2516.55768236, ..., 2873.80959905,
#        2873.84025751, 2873.8711762 ]), array([3716.86033663, 3716.89342824, 3716.92553649, ..., 4096.34987915,
#        4096.38936465, 4096.42777412]), array([4917.1750044 , 4917.20905424, 4917.25688216, ..., 5276.05100209,
#        5276.08271747, 5276.11444547])]
# [10802, 10802, 10801, 10802, 10801, 10800, 10801, 10801]
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.003000020980834961 s
# refresh duration for miniscope 0.0 s
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File c:\Users\Manip7\Documents\GitRepo\HayLabAnalysis\.venv\Lib\site-packages\ephyviewer\mainviewer.py:161, in MainViewer.on_time_changed(self, t)
#     159 if viewer['widget'] != self.sender():
#     160     t0 = time.time()
# --> 161     viewer['widget'].seek(t)
#     163     if self.debug:
#     164         t1 = time.time()
#
# File c:\Users\Manip7\Documents\GitRepo\HayLabAnalysis\.venv\Lib\site-packages\ephyviewer\base.py:30, in ViewerBase.seek(self, t)
#      28 def seek(self, t):
#      29     self.t = t
# ---> 30     self.refresh()
#
# File c:\Users\Manip7\Documents\GitRepo\HayLabAnalysis\.venv\Lib\site-packages\ephyviewer\videoviewer.py:199, in VideoViewer.refresh(self)
#     197 for c in range(self.source.nb_channel):
#     198     if visible_channels[c]:
# --> 199         frame_index = self.source.time_to_frame_index(c, self.t)
#     200         #~ print( 'c', c, 'frame_index', frame_index, 'self.qframe_grabbers[c].last_frame', self.qframe_grabbers[c].last_frame)
#     201
#     202         #~ if self.qframe_grabbers[c].active_frame != frame_index:
#     203         #~ print('self.qframe_grabbers[c].last_frame != frame_index', self.qframe_grabbers[c].last_frame != frame_index)
#     204         if self.qframe_grabbers[c].last_frame != frame_index:
#     205
#     206             #~ self.qframe_grabbers[c].active_frame = frame_index
#    (...)
#     209             #~ self.qframe_grabbers[c].queue_request_frame(frame_index)
#     210             #~ print('enque frame', threading.get_ident(), 'frame_index', frame_index)
#
# File c:\Users\Manip7\Documents\GitRepo\HayLabAnalysis\.venv\Lib\site-packages\ephyviewer\datasource\video.py:356, in MultiVideoFileSource.time_to_frame_index(self, i, t)
#     354     frame_index = int((t-self.t_starts[i])*self.rates[i])
#     355 else:
# --> 356     frame_index = np.searchsorted(self.video_times[i], t, side='right') - 1
#     358 return frame_index
#
# IndexError: list index out of range
# refresh duration for LFP 0.0010023117065429688 s
# refresh duration for tfr 0.006325483322143555 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.0030007362365722656 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.002997159957885742 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0009996891021728516 s
# refresh duration for tfr 0.0020008087158203125 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.0019996166229248047 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.003000020980834961 s
# refresh duration for miniscope 0.0010001659393310547 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.0030002593994140625 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.001001596450805664 s
# refresh duration for tfr 0.004003047943115234 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.0030002593994140625 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0009996891021728516 s
# refresh duration for tfr 0.0020003318786621094 s
# refresh duration for miniscope 0.0009996891021728516 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.002999544143676758 s
# refresh duration for miniscope 0.0009992122650146484 s
# refresh duration for LFP 0.0015027523040771484 s
# refresh duration for tfr 0.0020034313201904297 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.00099945068359375 s
# refresh duration for tfr 0.002001047134399414 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0010001659393310547 s
# refresh duration for tfr 0.0029993057250976562 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.0030012130737304688 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.0029985904693603516 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.002000570297241211 s
# refresh duration for miniscope 0.0010001659393310547 s
# refresh duration for LFP 0.0010008811950683594 s
# refresh duration for tfr 0.006184101104736328 s
# refresh duration for miniscope 0.0010008811950683594 s
# refresh duration for LFP 0.0010044574737548828 s
# refresh duration for tfr 0.0010004043579101562 s
# refresh duration for miniscope 0.0014240741729736328 s
# refresh duration for LFP 0.000993490219116211 s
# refresh duration for tfr 0.0029990673065185547 s
# refresh duration for miniscope 0.0009999275207519531 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.003000020980834961 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0010044574737548828 s
# refresh duration for tfr 0.006989479064941406 s
# refresh duration for miniscope 0.0010006427764892578 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.002999544143676758 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.001001596450805664 s
# refresh duration for tfr 0.004994392395019531 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.004999876022338867 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0010039806365966797 s
# refresh duration for tfr 0.005994558334350586 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0010042190551757812 s
# refresh duration for tfr 0.008521795272827148 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0009272098541259766 s
# refresh duration for tfr 0.006990194320678711 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0010018348693847656 s
# refresh duration for tfr 0.010486841201782227 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0010027885437011719 s
# refresh duration for tfr 0.009227514266967773 s
# refresh duration for miniscope 0.0015053749084472656 s
# refresh duration for LFP 0.0009992122650146484 s
# refresh duration for tfr 0.0029997825622558594 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0010020732879638672 s
# refresh duration for tfr 0.003995180130004883 s
# refresh duration for miniscope 0.0009996891021728516 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.002000570297241211 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.0029997825622558594 s
# refresh duration for miniscope 0.0010001659393310547 s
# refresh duration for LFP 0.0010004043579101562 s
# refresh duration for tfr 0.001999378204345703 s
# refresh duration for miniscope 0.0009996891021728516 s
# refresh duration for LFP 0.0010004043579101562 s
# refresh duration for tfr 0.003000497817993164 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0010001659393310547 s
# refresh duration for tfr 0.002000570297241211 s
# refresh duration for miniscope 0.0010006427764892578 s
# refresh duration for LFP 0.0010006427764892578 s
# refresh duration for tfr 0.0019991397857666016 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0009992122650146484 s
# refresh duration for tfr 0.002002716064453125 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.0019991397857666016 s
# refresh duration for miniscope 0.0010006427764892578 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.0033028125762939453 s
# refresh duration for miniscope 0.0010061264038085938 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.00400090217590332 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.003999948501586914 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0010056495666503906 s
# refresh duration for tfr 0.005993366241455078 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.003134489059448242 s
# refresh duration for miniscope 0.0009996891021728516 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.0029981136322021484 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.0030002593994140625 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.00099945068359375 s
# refresh duration for tfr 0.003014087677001953 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.001999378204345703 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.0019998550415039062 s
# refresh duration for miniscope 0.0010008811950683594 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.0029959678649902344 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.0019996166229248047 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.002000570297241211 s
# refresh duration for miniscope 0.0010008811950683594 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.0019998550415039062 s
# refresh duration for miniscope 0.0009999275207519531 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.0019996166229248047 s
# refresh duration for miniscope 0.0009999275207519531 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.001998424530029297 s
# refresh duration for miniscope 0.0010008811950683594 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.0030002593994140625 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.0020117759704589844 s
# refresh duration for miniscope 0.0009982585906982422 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.0029985904693603516 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.003003358840942383 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0010008811950683594 s
# refresh duration for tfr 0.001999378204345703 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.001999378204345703 s
# refresh duration for miniscope 0.0010004043579101562 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.0019989013671875 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0009996891021728516 s
# refresh duration for tfr 0.0030002593994140625 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.001999378204345703 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.001998424530029297 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0009989738464355469 s
# refresh duration for tfr 0.0020008087158203125 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.0019989013671875 s
# refresh duration for miniscope 0.0009996891021728516 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.004000425338745117 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.0019991397857666016 s
# refresh duration for miniscope 0.0009992122650146484 s
# refresh duration for LFP 0.0010001659393310547 s
# refresh duration for tfr 0.002000570297241211 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0009987354278564453 s
# refresh duration for tfr 0.005994558334350586 s
# refresh duration for miniscope 0.0010006427764892578 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.004000663757324219 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0010001659393310547 s
# refresh duration for tfr 0.0019998550415039062 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.0030040740966796875 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.003000497817993164 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.002000570297241211 s
# refresh duration for miniscope 0.0009999275207519531 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.002991199493408203 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0009953975677490234 s
# refresh duration for tfr 0.003000497817993164 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.003000497817993164 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.002992391586303711 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.006442546844482422 s
# refresh duration for miniscope 0.0009999275207519531 s
# refresh duration for LFP 0.0009982585906982422 s
# refresh duration for tfr 0.0020012855529785156 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0010001659393310547 s
# refresh duration for tfr 0.006000041961669922 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0010020732879638672 s
# refresh duration for tfr 0.007996320724487305 s
# refresh duration for miniscope 0.0009989738464355469 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.0020003318786621094 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.0019931793212890625 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.002000570297241211 s
# refresh duration for miniscope 0.00099945068359375 s
# refresh duration for LFP 0.001001119613647461 s
# refresh duration for tfr 0.002001523971557617 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.0019919872283935547 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.0029954910278320312 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0010008811950683594 s
# refresh duration for tfr 0.0019998550415039062 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.0020003318786621094 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.0029969215393066406 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.003001689910888672 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.0020072460174560547 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.0049932003021240234 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.0019919872283935547 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.0029914379119873047 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.0019919872283935547 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.0019996166229248047 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.002997875213623047 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0010030269622802734 s
# refresh duration for tfr 0.002004384994506836 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.001003265380859375 s
# refresh duration for tfr 0.001992940902709961 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.0019998550415039062 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.0029993057250976562 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0010209083557128906 s
# refresh duration for tfr 0.001997709274291992 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.002003908157348633 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.003002643585205078 s
# refresh duration for miniscope 0.00099945068359375 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.0030035972595214844 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.001994609832763672 s
# refresh duration for miniscope 0.0009996891021728516 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.001997232437133789 s
# refresh duration for miniscope 0.0009996891021728516 s
# refresh duration for LFP 0.0010013580322265625 s
# refresh duration for tfr 0.002003192901611328 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.0020117759704589844 s
# refresh duration for miniscope 0.0009965896606445312 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.0030100345611572266 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.0019998550415039062 s
# refresh duration for miniscope 0.0010001659393310547 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.0030150413513183594 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0010023117065429688 s
# refresh duration for tfr 0.001999378204345703 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.002999544143676758 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.002994060516357422 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.0019936561584472656 s
# refresh duration for miniscope 0.0010020732879638672 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.0019965171813964844 s
# refresh duration for miniscope 0.0009984970092773438 s
# refresh duration for LFP 0.0009989738464355469 s
# refresh duration for tfr 0.004450321197509766 s
# refresh duration for miniscope 0.0010066032409667969 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.001995563507080078 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.003000020980834961 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.0020079612731933594 s
# refresh duration for miniscope 0.0009946823120117188 s
# refresh duration for LFP 0.0009992122650146484 s
# refresh duration for tfr 0.002000570297241211 s
# refresh duration for miniscope 0.0010004043579101562 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.0032083988189697266 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.00099945068359375 s
# refresh duration for tfr 0.0020003318786621094 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.001999378204345703 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.0020151138305664062 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0009915828704833984 s
# refresh duration for tfr 0.0029993057250976562 s
# refresh duration for miniscope 0.0012295246124267578 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.002000570297241211 s
# refresh duration for miniscope 0.000997781753540039 s
# refresh duration for LFP 0.0009996891021728516 s
# refresh duration for tfr 0.0020055770874023438 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.0044100284576416016 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0010030269622802734 s
# refresh duration for tfr 0.005991697311401367 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.002344369888305664 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.00099945068359375 s
# refresh duration for tfr 0.002386808395385742 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.003000497817993164 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0010030269622802734 s
# refresh duration for tfr 0.002000093460083008 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0009992122650146484 s
# refresh duration for tfr 0.0019996166229248047 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0009999275207519531 s
# refresh duration for tfr 0.002000093460083008 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.001001119613647461 s
# refresh duration for tfr 0.004998207092285156 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.002998828887939453 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.003000020980834961 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0009992122650146484 s
# refresh duration for tfr 0.0020036697387695312 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.0030002593994140625 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.0019919872283935547 s
# refresh duration for miniscope 0.0010001659393310547 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.002000093460083008 s
# refresh duration for miniscope 0.0010006427764892578 s
# refresh duration for LFP 0.0009999275207519531 s
# refresh duration for tfr 0.001992464065551758 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.0019998550415039062 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.0020008087158203125 s
# refresh duration for miniscope 0.0009996891021728516 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.002999544143676758 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.004002809524536133 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.0019922256469726562 s
# refresh duration for miniscope 0.0010001659393310547 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.0029997825622558594 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.00099945068359375 s
# refresh duration for tfr 0.003000020980834961 s
# refresh duration for miniscope 0.0010001659393310547 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.0030028820037841797 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.0019996166229248047 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.0023806095123291016 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.00299835205078125 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.0050008296966552734 s
# refresh duration for miniscope 0.0009999275207519531 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.0020003318786621094 s
# refresh duration for miniscope 0.00099945068359375 s
# refresh duration for LFP 0.0010077953338623047 s
# refresh duration for tfr 0.0019910335540771484 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.003000020980834961 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.001008749008178711 s
# refresh duration for tfr 0.0019927024841308594 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.0010001659393310547 s
# refresh duration for miniscope 0.00099945068359375 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.003147602081298828 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.001991748809814453 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.0020003318786621094 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0010132789611816406 s
# refresh duration for tfr 0.0019903182983398438 s
# refresh duration for miniscope 0.0009996891021728516 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.0019969940185546875 s
# refresh duration for miniscope 0.0009999275207519531 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.002000570297241211 s
# refresh duration for miniscope 0.00099945068359375 s
# refresh duration for LFP 0.0009915828704833984 s
# refresh duration for tfr 0.0020012855529785156 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.002992391586303711 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.0019991397857666016 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.0029921531677246094 s
# refresh duration for miniscope 0.00099945068359375 s
# refresh duration for LFP 0.0009999275207519531 s
# refresh duration for tfr 0.003000974655151367 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0009999275207519531 s
# refresh duration for tfr 0.002000570297241211 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.002001047134399414 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.003997802734375 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.0022170543670654297 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0009999275207519531 s
# refresh duration for tfr 0.003000974655151367 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.0029926300048828125 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.001999378204345703 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.002000570297241211 s
# refresh duration for miniscope 0.0010006427764892578 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.004997968673706055 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0010056495666503906 s
# refresh duration for tfr 0.002003192901611328 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0010004043579101562 s
# refresh duration for tfr 0.0020003318786621094 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.0020008087158203125 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.00099945068359375 s
# refresh duration for tfr 0.001993417739868164 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.0029954910278320312 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0010075569152832031 s
# refresh duration for tfr 0.001992464065551758 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.001001119613647461 s
# refresh duration for tfr 0.0029993057250976562 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0010061264038085938 s
# refresh duration for tfr 0.0024971961975097656 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.0030014514923095703 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.0020003318786621094 s
# refresh duration for miniscope 0.0009920597076416016 s
# refresh duration for LFP 0.0010077953338623047 s
# refresh duration for tfr 0.0019931793212890625 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.002991914749145508 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0009996891021728516 s
# refresh duration for tfr 0.003000497817993164 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.0019931793212890625 s
# refresh duration for miniscope 0.0009987354278564453 s
# refresh duration for LFP 0.0009996891021728516 s
# refresh duration for tfr 0.0029997825622558594 s
# refresh duration for miniscope 0.0010008811950683594 s
# refresh duration for LFP 0.0010001659393310547 s
# refresh duration for tfr 0.0019969940185546875 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.0030012130737304688 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.002000570297241211 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.0020084381103515625 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.0020012855529785156 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.0050013065338134766 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.0030007362365722656 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0009999275207519531 s
# refresh duration for tfr 0.0020008087158203125 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0010037422180175781 s
# refresh duration for tfr 0.00199127197265625 s
# refresh duration for miniscope 0.0010001659393310547 s
# refresh duration for LFP 0.0010018348693847656 s
# refresh duration for tfr 0.0019974708557128906 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0010001659393310547 s
# refresh duration for tfr 0.001992464065551758 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.003000020980834961 s
# refresh duration for miniscope 0.0010001659393310547 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.004000425338745117 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0010004043579101562 s
# refresh duration for tfr 0.0020017623901367188 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.002002716064453125 s
# refresh duration for miniscope 0.0009996891021728516 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.005000591278076172 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0009996891021728516 s
# refresh duration for tfr 0.002001523971557617 s
# refresh duration for miniscope 0.0010013580322265625 s
# refresh duration for LFP 0.0009903907775878906 s
# refresh duration for tfr 0.004000186920166016 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.00099945068359375 s
# refresh duration for tfr 0.001995086669921875 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.003000020980834961 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.002000570297241211 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.0019989013671875 s
# refresh duration for miniscope 0.0009996891021728516 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.0020012855529785156 s
# refresh duration for miniscope 0.0009987354278564453 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.0030040740966796875 s
# refresh duration for miniscope 0.001001119613647461 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.002001523971557617 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.004999637603759766 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.0029990673065185547 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.0020012855529785156 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0010001659393310547 s
# refresh duration for tfr 0.002000570297241211 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0010001659393310547 s
# refresh duration for tfr 0.003254413604736328 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.0030028820037841797 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.0019998550415039062 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.0070493221282958984 s
# refresh duration for miniscope 0.0010044574737548828 s
# refresh duration for LFP 0.000997781753540039 s
# refresh duration for tfr 0.006993293762207031 s
# refresh duration for miniscope 0.00099945068359375 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.002999544143676758 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.003000020980834961 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.006000041961669922 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.001992464065551758 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.002000570297241211 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.0019922256469726562 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.004998922348022461 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0010020732879638672 s
# refresh duration for tfr 0.007004976272583008 s
# refresh duration for miniscope 0.0010001659393310547 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.001999378204345703 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0010004043579101562 s
# refresh duration for tfr 0.002999544143676758 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.0020017623901367188 s
# refresh duration for miniscope 0.0010008811950683594 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.001999378204345703 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0009996891021728516 s
# refresh duration for tfr 0.0029997825622558594 s
# refresh duration for miniscope 0.0010006427764892578 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.0019996166229248047 s
# refresh duration for miniscope 0.0010004043579101562 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.002000093460083008 s
# refresh duration for miniscope 0.0010004043579101562 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.003077268600463867 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.0019998550415039062 s
# refresh duration for miniscope 0.001001119613647461 s
# refresh duration for LFP 0.0009958744049072266 s
# refresh duration for tfr 0.002999544143676758 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0010008811950683594 s
# refresh duration for tfr 0.0019998550415039062 s
# refresh duration for miniscope 0.0010190010070800781 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.002000093460083008 s
# refresh duration for miniscope 0.0009999275207519531 s
# refresh duration for LFP 0.0010466575622558594 s
# refresh duration for tfr 0.0030007362365722656 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0009920597076416016 s
# refresh duration for tfr 0.002000093460083008 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.0019986629486083984 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.004000186920166016 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.0020003318786621094 s
# refresh duration for miniscope 0.0009999275207519531 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.0019996166229248047 s
# refresh duration for miniscope 0.0010006427764892578 s
# refresh duration for LFP 0.0009996891021728516 s
# refresh duration for tfr 0.0019931793212890625 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0010008811950683594 s
# refresh duration for tfr 0.0019986629486083984 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.0019989013671875 s
# refresh duration for miniscope 0.001001119613647461 s
# refresh duration for LFP 0.0010001659393310547 s
# refresh duration for tfr 0.008992195129394531 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0010318756103515625 s
# refresh duration for tfr 0.003998756408691406 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.0020020008087158203 s
# refresh duration for miniscope 0.0010006427764892578 s
# refresh duration for LFP 0.0010001659393310547 s
# refresh duration for tfr 0.0030007362365722656 s
# refresh duration for miniscope 0.0009992122650146484 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.001991748809814453 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.0040013790130615234 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0009987354278564453 s
# refresh duration for tfr 0.00999760627746582 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0009999275207519531 s
# refresh duration for tfr 0.003000497817993164 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.0019860267639160156 s
# refresh duration for miniscope 0.0009992122650146484 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.0029997825622558594 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.00099945068359375 s
# refresh duration for tfr 0.009533405303955078 s
# refresh duration for miniscope 0.0009987354278564453 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.0020003318786621094 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0009980201721191406 s
# refresh duration for tfr 0.005995035171508789 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.004999637603759766 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0009922981262207031 s
# refresh duration for tfr 0.002003192901611328 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.001999378204345703 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0009992122650146484 s
# refresh duration for tfr 0.003998279571533203 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.004999637603759766 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0009982585906982422 s
# refresh duration for tfr 0.008005380630493164 s
# refresh duration for miniscope 0.0010023117065429688 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.003998994827270508 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0009999275207519531 s
# refresh duration for tfr 0.003999948501586914 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0010037422180175781 s
# refresh duration for tfr 0.0060007572174072266 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0010025501251220703 s
# refresh duration for tfr 0.007001638412475586 s
# refresh duration for miniscope 0.0 s
# save_all_settings

# %%
starts=theExpe.data['ttl'].getOnsets()/theExpe.data['OE_LFP'].sampling_rate
print(starts)
# Out:
# [  30.795 1230.71  2430.317 3630.329 4830.344]
# refresh duration for LFP 0.000997781753540039 s
# refresh duration for tfr 0.006996870040893555 s
# refresh duration for miniscope 0.0010008811950683594 s
# refresh duration for LFP 0.0009965896606445312 s
# refresh duration for tfr 0.00799703598022461 s
# refresh duration for miniscope 0.0010006427764892578 s
# refresh duration for LFP 0.0009131431579589844 s
# refresh duration for tfr 0.006997823715209961 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.0019998550415039062 s
# refresh duration for miniscope 0.0010013580322265625 s
# refresh duration for LFP 0.001013040542602539 s
# refresh duration for tfr 0.008995532989501953 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.000997781753540039 s
# refresh duration for tfr 0.009010791778564453 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.003208160400390625 s
# refresh duration for miniscope 0.0010008811950683594 s
# refresh duration for LFP 0.0009951591491699219 s
# refresh duration for tfr 0.00573277473449707 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0010173320770263672 s
# refresh duration for tfr 0.009294509887695312 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.00499415397644043 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.006994009017944336 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0009036064147949219 s
# refresh duration for tfr 0.008995532989501953 s
# refresh duration for miniscope 0.0010006427764892578 s
# refresh duration for LFP 0.0009996891021728516 s
# refresh duration for tfr 0.006086111068725586 s
# refresh duration for miniscope 0.0010004043579101562 s
# refresh duration for LFP 0.0015108585357666016 s
# refresh duration for tfr 0.00699615478515625 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.001001119613647461 s
# refresh duration for tfr 0.011204957962036133 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0010006427764892578 s
# refresh duration for tfr 0.007998228073120117 s
# refresh duration for miniscope 0.0010001659393310547 s
# refresh duration for LFP 0.00099945068359375 s
# refresh duration for tfr 0.008151769638061523 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0010008811950683594 s
# refresh duration for tfr 0.00799560546875 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0009982585906982422 s
# refresh duration for tfr 0.004993915557861328 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0009996891021728516 s
# refresh duration for tfr 0.007992029190063477 s
# refresh duration for miniscope 0.0010006427764892578 s
# refresh duration for LFP 0.000997304916381836 s
# refresh duration for tfr 0.009499549865722656 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.007995128631591797 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0010018348693847656 s
# refresh duration for tfr 0.006378650665283203 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0005037784576416016 s
# refresh duration for tfr 0.006002664566040039 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.002999544143676758 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0010008811950683594 s
# refresh duration for tfr 0.003999471664428711 s
# refresh duration for miniscope 0.001001119613647461 s
# refresh duration for LFP 0.0010881423950195312 s
# refresh duration for tfr 0.006958961486816406 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.000997781753540039 s
# refresh duration for tfr 0.010004997253417969 s
# refresh duration for miniscope 0.0009984970092773438 s
# refresh duration for LFP 0.0010118484497070312 s
# refresh duration for tfr 0.007986068725585938 s
# refresh duration for miniscope 0.0 s
# refresh duration for LFP 0.0 s
# refresh duration for tfr 0.006076335906982422 s
# refresh duration for miniscope 0.0009963512420654297 s
# refresh duration for LFP 0.001001596450805664 s
# refresh duration for tfr 0.007993936538696289 s
# refresh duration for miniscope 0.0 s

# %%
# %matplotlib widget



o = theExpe.data['ttl'].getOnsets()
print(theExpe.data['ttl'].ttlIndexes[0]/theExpe.data['OE_LFP'].sampling_rate)
print(theExpe.data['miniscope'].TS_times[0])

print(theExpe.data['ttl'].ttlIndexes[0].shape)
print(theExpe.data['miniscope'].TS_times[0].shape)

if True:
    plt.close()
    plt.plot(theExpe.data['ttl'].times[0])
    plt.plot(theExpe.data['miniscope'].TS_times[0])
    plt.show()
# Out:
# [ 41.925  41.959  41.994 ... 101.651 101.684 101.719]
# [ 79.9758336  80.0075136  80.0401408 ... 139.517184  139.5574272
#  139.5862912]
# (1782,)
# (1768,)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# %matplotlib widget

plt.close()

theExpe.data['webcam'].alignWebcamWithMiniscope()

# %%
# %matplotlib widget

plt.close()


df=theExpe.data['OE_LFP'].loadTimeStampsBoard()
print(df)

if True:
    plt.close()
    #plt.plot(theExpe.data['ttl'].ttlIndexes[0]/theExpe.data['OE_LFP'].sampling_rate+theExpe.data['OE_LFP'].start)
    plt.plot(df)
    plt.show()
# Out:
#              ts
# 0     484970416
# 1     484185040
# 2     485397744
# 3     484970416
# 4     484185040
# ...         ...
# 1957  575482176
# 1958  575485488
# 1959  575481072
# 1960  575484384
# 1961  575483280
#
# [1962 rows x 1 columns]
# c:\Users\Manip7\Documents\GitRepo\HayLabAnalysis\python\mbTools\ePhy\LFP.py:110: FutureWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   df = pd.read_csv(fTS, dtype=np.int32, parse_dates=True, infer_datetime_format=True, header=None, sep=',', names=['ts'])
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# No such comm: 97fb4dee740a491eb27c0b4ae2fc78a8
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# No such comm: 56cd108fd42d4afda552fd117df4ca97
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# No such comm: 8aea770a62bc4d41b2aa32351e3ad95c
# No such comm: e8382d39b93a409c9f0f230dce775e0f
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
hla.tools.find_nearest(theExpe.data['webcam'].times[4],4831.2967)
# Out:
# 942

# %%
print(theExpe.data['webcam'].times[4][918])
# Out:
# 4830.3406758732735
# save_all_settings

# %%
theExpe.data['webcam'].alignWebcamWithMiniscope()
# Out:
# new array is [  3.40404553   3.43176098   3.46028455 ... 359.26218888 359.29350495
#  359.32436862]
# first miniscope image ts : 88.6454016
# corresponding real time based on ttls 30.795
# miniscope onset at webcam image number:  924
# realigned times aroud that frame are [30.72385041 30.75231707 30.78109106 30.80925041]
# new array is [1207.58335284 1207.60617671 1207.63040053 ... 1562.71988367 1562.7746791
#  1562.80938428]
# first miniscope image ts : 1288.6540416
# corresponding real time based on ttls 1230.71
# miniscope onset at webcam image number:  919
# realigned times aroud that frame are [1230.64735986 1230.67155471 1230.70791457 1230.73244734]
# new array is [2396.97666134 2397.01159533 2397.04761665 ... 2760.63488582 2760.66759495
#  2760.70058173]
# first miniscope image ts : 2488.7868288
# corresponding real time based on ttls 2430.317
# miniscope onset at webcam image number:  918
# realigned times aroud that frame are [2430.24536162 2430.28078352 2430.31456048 2430.3494387 ]
# new array is [3596.51624576 3596.55174011 3596.58727684 ... 3954.27317574 3954.29977746
#  3954.32565425]
# first miniscope image ts : 3688.9650688
# corresponding real time based on ttls 3630.329
# miniscope onset at webcam image number:  919
# realigned times aroud that frame are [3630.25976271 3630.29511582 3630.33134463 3630.36572513]
# new array is [4798.26868359 4798.30179082 4798.35214866 ... 5160.1790625  5160.21163443
#  5160.24421934]
# first miniscope image ts : 4889.1511936
# corresponding real time based on ttls 4830.344
# miniscope onset at webcam image number:  918
# realigned times aroud that frame are [4830.27356336 4830.30759545 4830.34067587 4830.374145  ]
# webcam realigned

# %%
hla.tools.find_nearest(theExpe.data['webcam'].TS_times[4],4889.1511936)
# Out:
# 918
