# %% [markdown]
# ## Minian reduced
#
# # Load packages

# %%
# %%capture
# %load_ext autoreload
# %autoreload 2
import itertools as itt
import os
import sys

import holoviews as hv
import numpy as np
import xarray as xr
from dask.distributed import Client, LocalCluster
from holoviews.operation.datashader import datashade, regrid
from holoviews.util import Dynamic
from IPython.core.display import display

# %% [markdown]
# # Initial parameters

# %%
# Set up Initial Basic Parameters#
minian_path = "."
dpath = "/Users/ahay/Documents/DATA/L1imaging/Gaelle/Baseline_recording/BlackLinesOK/test/V4_Miniscope/"
minian_ds_path = os.path.join(dpath, "minian")
intpath = "/Users/ahay/Documents/DATA/L1imaging/Gaelle/Baseline_recording/BlackLinesOK/test/V4_Miniscope/minian_intermediate"
subset = dict(frame=slice(0, None))
subset_mc = None
interactive = True
output_size = 100
n_workers = int(os.getenv("MINIAN_NWORKERS", 4))
param_save_minian = {
    "dpath": minian_ds_path,
    "meta_dict": dict(session=-1, animal=-2),
    "overwrite": True,
}

# Pre-processing Parameters#
param_load_videos = {
    "pattern": "[0-9]+\.avi$",
    "dtype": np.uint8,
    "downsample": dict(frame=1, height=1, width=1),
    "downsample_strategy": "subset",
}
param_denoise = {"method": "median", "ksize": 5}
param_background_removal = {"method": "tophat", "wnd": 15}

# Motion Correction Parameters#
subset_mc = None
param_estimate_motion = {"dim": "frame"}

# Initialization Parameters#
param_seeds_init = {
    "wnd_size": 100,
    "method": "rolling",
    "stp_size": 50,
    "max_wnd": 20,#generally 10 updated here to 20 to account for L1 wide dendritic trees
    "diff_thres": 3,
}
param_pnr_refine = {"noise_freq": 0.06, "thres": 1}
param_ks_refine = {"sig": 0.05}
param_seeds_merge = {"thres_dist": 10, "thres_corr": 0.8, "noise_freq": 0.06}
param_initialize = {"thres_corr": 0.8, "wnd": 10, "noise_freq": 0.06} 
param_init_merge = {"thres_corr": 0.8}

# CNMF Parameters# 0.025 for threecolordots
param_get_noise = {"noise_range": (0.06, 0.5)}
param_first_spatial = {
    "dl_wnd": 15,
    "sparse_penal": 0.012,
    "size_thres": (25, None),
}
param_first_temporal = {
    "noise_freq": 0.06,
    "sparse_penal": 1,
    "p": 1,
    "add_lag": 20,
    "jac_thres": 0.2,
}
param_first_merge = {"thres_corr": 0.8}
param_second_spatial = {
    "dl_wnd": 10,
    "sparse_penal": 0.005,
    "size_thres": (25, None),
}
param_second_temporal = {
    "noise_freq": 0.06,
    "sparse_penal": 1,
    "p": 1,
    "add_lag": 20,
    "jac_thres": 0.4,
}

os.environ["OMP_NUM_THREADS"] = "1"
os.environ["MKL_NUM_THREADS"] = "1"
os.environ["OPENBLAS_NUM_THREADS"] = "1"
os.environ["MINIAN_INTERMEDIATE"] = intpath

# %% [markdown]
# # start cluster

# %%
# %%capture

sys.path.append(minian_path)
from minian.cnmf import (
    compute_AtC,
    compute_trace,
    get_noise_fft,
    smooth_sig,
    unit_merge,
    update_spatial,
    update_temporal,
    update_background,
)
from minian.initialization import (
    gmm_refine,
    initA,
    initC,
    intensity_refine,
    ks_refine,
    pnr_refine,
    seeds_init,
    seeds_merge,
)
from minian.motion_correction import apply_transform, estimate_motion
from minian.preprocessing import denoise, remove_background
from minian.utilities import (
    TaskAnnotation,
    get_optimal_chk,
    load_videos,
    open_minian,
    save_minian,
)
from minian.visualization import (
    CNMFViewer,
    VArrayViewer,
    generate_videos,
    visualize_gmm_fit,
    visualize_motion,
    visualize_preprocess,
    visualize_seeds,
    visualize_spatial_update,
    visualize_temporal_update,
    write_video,
)

dpath = os.path.abspath(dpath)
hv.notebook_extension("bokeh", width=100)

cluster = LocalCluster(
    n_workers=n_workers,
    memory_limit="2GB",
    resources={"MEM": 1},
    threads_per_worker=2,
    dashboard_address=":8787",
)
annt_plugin = TaskAnnotation()
cluster.scheduler.add_plugin(annt_plugin)
client = Client(cluster)

# %% [markdown]
# # Pre-processing

# %%
varr = load_videos(dpath, **param_load_videos)
chk, _ = get_optimal_chk(varr, dtype=float)


varr = save_minian(
    varr.chunk({"frame": chk["frame"], "height": -1, "width": -1}).rename("varr"),
    intpath,
    overwrite=True,
)

varr_ref = varr.sel(height=slice(0, 600), width=slice(0, 600))
# Out:
# loading 11 videos in folder /Users/ahay/Documents/DATA/L1imaging/Gaelle/Baseline_recording/BlackLinesOK/test/V4_Miniscope
# ffmpeg version 4.2.3 Copyright (c) 2000-2020 the FFmpeg developers
#   built with clang version 9.0.1
#   configuration: --prefix=/opt/anaconda3/envs/minian --cc=x86_64-apple-darwin13.4.0-clang --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
# ffmpeg version 4.2.3  libavresample   4.  0.  0 /  4.  0.  0
#  Copyright (c) 2000-2020 the FFmpeg developers
#   built with clang version 9.0.1
#   configuration: --prefix=/opt/anaconda3/envs/minian --cc=x86_64-apple-darwin13.4.0-clang --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# ffmpeg version 4.2.3 Copyright (c) 2000-2020 the FFmpeg developers
#   built with clang version 9.0.1
#   configuration: --prefix=/opt/anaconda3/envs/minian --cc=x86_64-apple-darwin13.4.0-clang --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame
# ffmpeg version 4.2.3  libavutil      56. 31.100 / 56. 31.100
#  Copyright (c) 2000-2020 the FFmpeg developers
#   libavcodec     58. 54.100 / 58. 54.100
#   built with clang version 9.0.1
#   libavformat    58. 29.100 / 58. 29.100
#   configuration: --prefix=/opt/anaconda3/envs/minian --cc=x86_64-apple-darwin13.4.0-clang --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, avi, from '/Users/ahay/Documents/DATA/L1imaging/Gaelle/Baseline_recording/BlackLinesOK/test/V4_Miniscope/10.avi':
#   Metadata:
#     encoder         : Lavf58.29.100
#   Duration: 00:00:16.67, start: 0.000000, bitrate: 5983 kb/s
#     Stream #0:0: Video: mjpeg (Baseline) (MJPG / 0x47504A4D), yuvj420p(pc, bt470bg/unknown/unknown), 600x600, 5972 kb/s, 60 fps, 60 tbr, 60 tbn, 60 tbc
# Input #0, avi, from '/Users/ahay/Documents/DATA/L1imaging/Gaelle/Baseline_recording/BlackLinesOK/test/V4_Miniscope/2.avi':
# Input #0, avi, from '/Users/ahay/Documents/DATA/L1imaging/Gaelle/Baseline_recording/BlackLinesOK/test/V4_Miniscope/0.avi':
#   Metadata:
#     encoder         :   Metadata:
# Lavf58.29.100    encoder         :
# Lavf58.29.100  Duration:
#   Duration: 00:00:16.67, start: 00:00:16.670.000000, start: , bitrate: 0.0000006062 kb/s, bitrate:
# 5662 kb/s
#     Stream #0:0    Stream #0:0: Video: mjpeg (Baseline) (MJPG / 0x47504A4D), yuvj420p(pc, bt470bg/unknown/unknown), 600x600, 5651 kb/s: Video: mjpeg (Baseline) (MJPG / 0x47504A4D), yuvj420p(pc, bt470bg/unknown/unknown), 600x600, 6050 kb/s, , 60 fps, 60 tbr, 60 tbn, 60 tbc
# 60 fps, 60 tbr, 60 tbn, 60 tbc
# Input #0, avi, from '/Users/ahay/Documents/DATA/L1imaging/Gaelle/Baseline_recording/BlackLinesOK/test/V4_Miniscope/1.avi':
#   Metadata:
#     encoder         : Lavf58.29.100
#   Duration: 00:00:16.67, start: 0.000000, bitrate: 5885 kb/s
#     Stream #0:0: Video: mjpeg (Baseline) (MJPG / 0x47504A4D), yuvj420p(pc, bt470bg/unknown/unknown), 600x600, 5874 kb/s, 60 fps, 60 tbr, 60 tbn, 60 tbc
# Stream mapping:
# Stream mapping:
#   Stream #0:0 -> #0:0  Stream #0:0 -> #0:0 (mjpeg (native) -> rawvideo (native))
#  (mjpeg (native) -> rawvideo (native))
# Press [q] to stop, [?] for help
# Stream mapping:
#   Stream #0:0 -> #0:0Stream mapping:
#  (mjpeg (native) -> rawvideo (native))
#   Stream #0:0 -> #0:0 (mjpeg (native) -> rawvideo (native))Press [q] to stop, [?] for help
#
# Press [q] to stop, [?] for help
# Press [q] to stop, [?] for help
# [swscaler @ 0x7feac8008000] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x7f95f0008000] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x7fe340008000] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x7fb6e0098000] deprecated pixel format used, make sure you did set range correctly
# Output #0, rawvideo, to 'pipe:':
# Output #0, rawvideo, to 'pipe:':
#   Metadata:
#     encoder         : Lavf58.29.100
# Output #0, rawvideo, to 'pipe:':
#   Metadata:
#     encoder         : Lavf58.29.100
# Output #0, rawvideo, to 'pipe:':
#   Metadata:
#     encoder         : Lavf58.29.100
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: rawvideo (Y800 / 0x30303859), gray, 600x600, q=2-31, 172800 kb/s, 60 fps, 60 tbn, 60 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 rawvideo
#     Stream #0:0: Video: rawvideo (Y800 / 0x30303859), gray, 600x600, q=2-31, 172800 kb/s, 60 fps, 60 tbn, 60 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 rawvideo
#     Stream #0:0: Video: rawvideo (Y800 / 0x30303859), gray, 600x600, q=2-31, 172800 kb/s, 60 fps, 60 tbn, 60 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 rawvideo
#     Stream #0:0: Video: rawvideo (Y800 / 0x30303859), gray, 600x600, q=2-31, 172800 kb/s, 60 fps, 60 tbn, 60 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 rawvideo
# frame= 1000 fps=892 q=-0.0 Lsize=  351562kB time=00:00:16.66 bitrate=172800.0kbits/s speed=14.9x
# video:351562kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.000000%
# frame= 1000 fps=889 q=-0.0 Lsize=  351562kB time=00:00:16.66 bitrate=172800.0kbits/s speed=14.8x
# video:351562kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.000000%
# frame= 1000 fps=888 q=-0.0 Lsize=  351562kB time=00:00:16.66 bitrate=172800.0kbits/s speed=14.8x
# video:351562kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.000000%
# frame= 1000 fps=884 q=-0.0 Lsize=  351562kB time=00:00:16.66 bitrate=172800.0kbits/s speed=14.7x
# video:351562kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.000000%
# ffmpeg version 4.2.3 Copyright (c) 2000-2020 the FFmpeg developers
#   built with clang version 9.0.1
#   configuration: --prefix=/opt/anaconda3/envs/minian --cc=x86_64-apple-darwin13.4.0-clang --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame
# ffmpeg version 4.2.3 Copyright (c) 2000-2020 the FFmpeg developers
#   built with clang version 9.0.1
#   configuration: --prefix=/opt/anaconda3/envs/minian --cc=x86_64-apple-darwin13.4.0-clang --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, avi, from '/Users/ahay/Documents/DATA/L1imaging/Gaelle/Baseline_recording/BlackLinesOK/test/V4_Miniscope/4.avi':
#   Metadata:
#     encoder         : Lavf58.29.100
#   Duration: 00:00:16.67, start: 0.000000, bitrate: 6518 kb/s
#     Stream #0:0: Video: mjpeg (Baseline) (MJPG / 0x47504A4D), yuvj420p(pc, bt470bg/unknown/unknown), 600x600, 6507 kb/s, 60 fps, 60 tbr, 60 tbn, 60 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> rawvideo (native))
# Press [q] to stop, [?] for help
# ffmpeg version 4.2.3 Copyright (c) 2000-2020 the FFmpeg developers
#   built with clang version 9.0.1
#   configuration: --prefix=/opt/anaconda3/envs/minian --cc=x86_64-apple-darwin13.4.0-clang --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, avi, from '/Users/ahay/Documents/DATA/L1imaging/Gaelle/Baseline_recording/BlackLinesOK/test/V4_Miniscope/3.avi':
#   Metadata:
#     encoder         : Lavf58.29.100
#   Duration: 00:00:16.67, start: 0.000000, bitrate: 6390 kb/s
#     Stream #0:0: Video: mjpeg (Baseline) (MJPG / 0x47504A4D), yuvj420p(pc, bt470bg/unknown/unknown), 600x600, 6379 kb/s, 60 fps, 60 tbr, 60 tbn, 60 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> rawvideo (native))
# Press [q] to stop, [?] for help
# Input #0, avi, from '/Users/ahay/Documents/DATA/L1imaging/Gaelle/Baseline_recording/BlackLinesOK/test/V4_Miniscope/5.avi':
#   Metadata:
#     encoder         : Lavf58.29.100
#   Duration: 00:00:16.67, start: 0.000000, bitrate: 6484 kb/s
#     Stream #0:0: Video: mjpeg (Baseline) (MJPG / 0x47504A4D), yuvj420p(pc, bt470bg/unknown/unknown), 600x600, 6474 kb/s, 60 fps, 60 tbr, 60 tbn, 60 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> rawvideo (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x7fc548008000] deprecated pixel format used, make sure you did set range correctly
# Output #0, rawvideo, to 'pipe:':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: rawvideo (Y800 / 0x30303859), gray, 600x600, q=2-31, 172800 kb/s, 60 fps, 60 tbn, 60 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 rawvideo
# [swscaler @ 0x7fe9e8098000] deprecated pixel format used, make sure you did set range correctly
# Output #0, rawvideo, to 'pipe:':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: rawvideo (Y800 / 0x30303859), gray, 600x600, q=2-31, 172800 kb/s, 60 fps, 60 tbn, 60 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 rawvideo
# [swscaler @ 0x7fa708008000] deprecated pixel format used, make sure you did set range correctly
# Output #0, rawvideo, to 'pipe:':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: rawvideo (Y800 / 0x30303859), gray, 600x600, q=2-31, 172800 kb/s, 60 fps, 60 tbn, 60 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 rawvideo
# ffmpeg version 4.2.3 Copyright (c) 2000-2020 the FFmpeg developers
#   built with clang version 9.0.1
#   configuration: --prefix=/opt/anaconda3/envs/minian --cc=x86_64-apple-darwin13.4.0-clang --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, avi, from '/Users/ahay/Documents/DATA/L1imaging/Gaelle/Baseline_recording/BlackLinesOK/test/V4_Miniscope/6.avi':
#   Metadata:
#     encoder         : Lavf58.29.100
#   Duration: 00:00:16.67, start: 0.000000, bitrate: 6430 kb/s
#     Stream #0:0: Video: mjpeg (Baseline) (MJPG / 0x47504A4D), yuvj420p(pc, bt470bg/unknown/unknown), 600x600, 6419 kb/s, 60 fps, 60 tbr, 60 tbn, 60 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> rawvideo (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x7fa658008000] deprecated pixel format used, make sure you did set range correctly
# Output #0, rawvideo, to 'pipe:':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: rawvideo (Y800 / 0x30303859), gray, 600x600, q=2-31, 172800 kb/s, 60 fps, 60 tbn, 60 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 rawvideo
# frame= 1000 fps=494 q=-0.0 Lsize=  351562kB time=00:00:16.66 bitrate=172800.0kbits/s speed=8.24x
# 0.000000%562kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: frame=  969 fps=480 q=-0.0 size=  340664kB time=00:00:16.15 bitrate=172800.0kbits/s speed=   8x
# frame= 1000 fps=488 q=-0.0 Lsize=  351562kB time=00:00:16.66 bitrate=172800.0kbits/s speed=8.13x
# video:351562kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.000000%
# ffmpeg version 4.2.3 Copyright (c) 2000-2020 the FFmpeg developers
#   built with clang version 9.0.1
#   configuration: --prefix=/opt/anaconda3/envs/minian --cc=x86_64-apple-darwin13.4.0-clang --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, avi, from '/Users/ahay/Documents/DATA/L1imaging/Gaelle/Baseline_recording/BlackLinesOK/test/V4_Miniscope/8.avi':
#   Metadata:
#     encoder         : Lavf58.29.100
#   Duration: 00:00:16.67, start: 0.000000, bitrate: 5868 kb/s
#     Stream #0:0: Video: mjpeg (Baseline) (MJPG / 0x47504A4D), yuvj420p(pc, bt470bg/unknown/unknown), 600x600, 5857 kb/s, 60 fps, 60 tbr, 60 tbn, 60 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> rawvideo (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x7fee90008000] deprecated pixel format used, make sure you did set range correctly
# Output #0, rawvideo, to 'pipe:':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: rawvideo (Y800 / 0x30303859), gray, 600x600, q=2-31, 172800 kb/s, 60 fps, 60 tbn, 60 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 rawvideo
# frame= 1000 fps=484 q=-0.0 Lsize=  351562kB time=00:00:16.66 bitrate=172800.0kbits/s speed=8.07x
# video:351562kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.000000%
# ffmpeg version 4.2.3 Copyright (c) 2000-2020 the FFmpeg developers
#   built with clang version 9.0.1
#   configuration: --prefix=/opt/anaconda3/envs/minian --cc=x86_64-apple-darwin13.4.0-clang --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, avi, from '/Users/ahay/Documents/DATA/L1imaging/Gaelle/Baseline_recording/BlackLinesOK/test/V4_Miniscope/7.avi':
#   Metadata:
#     encoder         : Lavf58.29.100
#   Duration: 00:00:16.67, start: 0.000000, bitrate: 6223 kb/s
#     Stream #0:0: Video: mjpeg (Baseline) (MJPG / 0x47504A4D), yuvj420p(pc, bt470bg/unknown/unknown), 600x600, 6212 kb/s, 60 fps, 60 tbr, 60 tbn, 60 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> rawvideo (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x7fc630098000] deprecated pixel format used, make sure you did set range correctly
# Output #0, rawvideo, to 'pipe:':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: rawvideo (Y800 / 0x30303859), gray, 600x600, q=2-31, 172800 kb/s, 60 fps, 60 tbn, 60 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 rawvideo
# ffmpeg version 4.2.3 Copyright (c) 2000-2020 the FFmpeg developers
#   built with clang version 9.0.1
#   configuration: --prefix=/opt/anaconda3/envs/minian --cc=x86_64-apple-darwin13.4.0-clang --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, avi, from '/Users/ahay/Documents/DATA/L1imaging/Gaelle/Baseline_recording/BlackLinesOK/test/V4_Miniscope/9.avi':
#   Metadata:
#     encoder         : Lavf58.29.100
#   Duration: 00:00:16.67, start: 0.000000, bitrate: 5833 kb/s
#     Stream #0:0: Video: mjpeg (Baseline) (MJPG / 0x47504A4D), yuvj420p(pc, bt470bg/unknown/unknown), 600x600, 5822 kb/s, 60 fps, 60 tbr, 60 tbn, 60 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> rawvideo (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x7fa1f0008000] deprecated pixel format used, make sure you did set range correctly
# Output #0, rawvideo, to 'pipe:':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: rawvideo (Y800 / 0x30303859), gray, 600x600, q=2-31, 172800 kb/s, 60 fps, 60 tbn, 60 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 rawvideo
# frame= 1000 fps=459 q=-0.0 Lsize=  351562kB time=00:00:16.66 bitrate=172800.0kbits/s speed=7.65x
# video:351562kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.000000%
# frame= 1000 fps=631 q=-0.0 Lsize=  351562kB time=00:00:16.66 bitrate=172800.0kbits/s speed=10.5x
# video:351562kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.000000%
# frame= 1000 fps=642 q=-0.0 Lsize=  351562kB time=00:00:16.66 bitrate=172800.0kbits/s speed=10.7x
# video:351562kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.000000%
# frame= 1000 fps=656 q=-0.0 Lsize=  351562kB time=00:00:16.66 bitrate=172800.0kbits/s speed=10.9x
# video:351562kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.000000%

# %% [markdown]
# # Clean up

# %%
# Glow removal

varr_min = varr_ref.min("frame").compute()
varr_ref = varr_ref - varr_min

# Denoise
varr_ref = denoise(varr_ref, **param_denoise)

# Background removal
varr_ref = remove_background(varr_ref, **param_background_removal)

# Save results
# %%time
varr_ref = save_minian(varr_ref.rename("varr_ref"), dpath=intpath, overwrite=True)
# Out:
# UsageError: Line magic function `%%time` not found.

# %% [markdown]
# # Motion correction

# %%
# Estimation motion

motion = estimate_motion(varr_ref.sel(subset_mc), **param_estimate_motion)

# Save motion

motion = save_minian(
    motion.rename("motion").chunk({"frame": chk["frame"]}), **param_save_minian
)

# %% [markdown]
# # Apply transform

# %%
Y = apply_transform(varr_ref, motion, fill=0)


Y_fm_chk = save_minian(Y.astype(float).rename("Y_fm_chk"), intpath, overwrite=True)
Y_hw_chk = save_minian(
    Y_fm_chk.rename("Y_hw_chk"),
    intpath,
    overwrite=True,
    chunks={"frame": -1, "height": chk["height"], "width": chk["width"]},
)


vid_arr = xr.concat([varr_ref, Y_fm_chk], "width").chunk({"width": -1})
write_video(Y_fm_chk, "minian_mc.mp4", dpath)
# Out:
# ffmpeg version 4.2.3 Copyright (c) 2000-2020 the FFmpeg developers
#   built with clang version 9.0.1
#   configuration: --prefix=/opt/anaconda3/envs/minian --cc=x86_64-apple-darwin13.4.0-clang --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, rawvideo, from 'pipe:':
#   Duration: N/A, start: 0.000000, bitrate: 72000 kb/s
#     Stream #0:0: Video: rawvideo (Y800 / 0x30303859), gray, 600x600, 72000 kb/s, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 (rawvideo) -> pad
#   pad -> Stream #0:0 (libx264)
# [libx264 @ 0x7f890a00e200] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2
# [libx264 @ 0x7f890a00e200] profile Constrained Baseline, level 3.1
# [libx264 @ 0x7f890a00e200] 264 - core 152 - H.264/MPEG-4 AVC codec - Copyleft 2003-2017 - http://www.videolan.org/x264.html - options: cabac=0 ref=1 deblock=0:0:0 analyse=0:0 me=dia subme=0 psy=1 psy_rd=1.00:0.00 mixed_ref=0 me_range=16 chroma_me=1 trellis=0 8x8dct=0 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=0 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=0 weightp=0 keyint=250 keyint_min=25 scenecut=0 intra_refresh=0 rc=crf mbtree=0 crf=18.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=0
# Output #0, mp4, to '/Users/ahay/Documents/DATA/L1imaging/Gaelle/Baseline_recording/BlackLinesOK/test/V4_Miniscope/minian_mc.mp4':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 600x600, q=-1--1, 30 fps, 15360 tbn, 30 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# More than 1000 frames duplicated   99328kB time=00:03:17.60 bitrate=4117.9kbits/s dup=990 drop=0 speed=10.8x
# frame=13200 fps=327 q=-1.0 Lsize=  220763kB time=00:07:19.96 bitrate=4110.5kbits/s dup=2200 drop=0 speed=10.9x
# video:220708kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.024891%
# [libx264 @ 0x7f890a00e200] frame I:53    Avg QP:15.53  size: 32608
# [libx264 @ 0x7f890a00e200] frame P:13147 Avg QP:18.48  size: 17059
# [libx264 @ 0x7f890a00e200] mb I  I16..4: 100.0%  0.0%  0.0%
# [libx264 @ 0x7f890a00e200] mb P  I16..4: 44.1%  0.0%  0.0%  P16..4: 48.9%  0.0%  0.0%  0.0%  0.0%    skip: 7.0%
# [libx264 @ 0x7f890a00e200] coded y,uvDC,uvAC intra: 97.8% 0.0% 0.0% inter: 64.4% 0.0% 0.0%
# [libx264 @ 0x7f890a00e200] i16 v,h,dc,p: 23% 23% 44% 10%
# [libx264 @ 0x7f890a00e200] i8c dc,h,v,p: 100%  0%  0%  0%
# [libx264 @ 0x7f890a00e200] kb/s:4109.17
# '/Users/ahay/Documents/DATA/L1imaging/Gaelle/Baseline_recording/BlackLinesOK/test/V4_Miniscope/minian_mc.mp4'

# %% [markdown]
# # Initialisation

# %%
# Compute maximal projection
max_proj = save_minian(
    Y_fm_chk.max("frame").rename("max_proj"), **param_save_minian
).compute()

# Generating seeds

seeds = seeds_init(Y_fm_chk, **param_seeds_init)

# Noise refined 
    # here there is possibility to visualise to refine param_pnr_refine but noise_freq = 0.06 is generally fine

seeds, pnr, gmm = pnr_refine(Y_hw_chk, seeds, **param_pnr_refine)

# Refine using KS test to look at bimodal distribution
seeds = ks_refine(Y_hw_chk, seeds, **param_ks_refine)

# Merge seeds
seeds_final = seeds[seeds["mask_ks"] & seeds["mask_pnr"]].reset_index(drop=True)
seeds_final = seeds_merge(Y_hw_chk, max_proj, seeds_final, **param_seeds_merge)

# Initialise spatial matrix

A_init = initA(Y_hw_chk, seeds_final[seeds_final["mask_mrg"]], **param_initialize)
A_init = save_minian(A_init.rename("A_init"), intpath, overwrite=True)

# Initialise temporal matrix
C_init = initC(Y_fm_chk, A_init)
C_init = save_minian(
    C_init.rename("C_init"), intpath, overwrite=True, chunks={"unit_id": 1, "frame": -1}
)

# Merge unit
A, C = unit_merge(A_init, C_init, **param_init_merge)
A = save_minian(A.rename("A"), intpath, overwrite=True)
C = save_minian(C.rename("C"), intpath, overwrite=True)
C_chk = save_minian(
    C.rename("C_chk"),
    intpath,
    overwrite=True,
    chunks={"unit_id": -1, "frame": chk["frame"]},
)

# Initialise background terms
b, f = update_background(Y_fm_chk, A, C_chk)
f = save_minian(f.rename("f"), intpath, overwrite=True)
b = save_minian(b.rename("b"), intpath, overwrite=True)
# Out:
# constructing chunks
# computing max projections
# calculating local maximum
# selecting seeds
# computing peak-noise ratio
# selecting seeds
# performing KS test
# computing distance
# computing correlations
# pixel recompute ratio: 1.0018437427978797
# computing correlations
# merging seeds
# optimizing computation graph
# pixel recompute ratio: 1.150920150920151
# computing correlations
# building spatial matrix
# computing spatial overlap
# computing temporal correlation
# pixel recompute ratio: 0.2619047619047619
# computing correlations
# labeling units to be merged
# merging units

# %% [markdown]
# # CNMF

# %%
# Estimate spatial noise
sn_spatial = get_noise_fft(Y_hw_chk, **param_get_noise)
sn_spatial = save_minian(sn_spatial.rename("sn_spatial"), intpath, overwrite=True)

if interactive:
    units = np.random.choice(A.coords["unit_id"], 10, replace=False)
    units.sort()
    A_sub = A.sel(unit_id=units).persist()
    C_sub = C.sel(unit_id=units).persist()


# First spatial update
    # Here is the only interactive mandatory step to adjust sparse penalty [generally set between 0.01 and 0.02]
if interactive:
    sprs_ls = [0.01, 0.012, 0.014, 0.016]
    A_dict = dict()
    C_dict = dict()
    for cur_sprs in sprs_ls:
        cur_A, cur_mask, cur_norm = update_spatial(
            Y_hw_chk,
            A_sub,
            C_sub,
            sn_spatial,
            in_memory=True,
            dl_wnd=param_first_spatial["dl_wnd"],
            sparse_penal=cur_sprs,
        )
        if cur_A.sizes["unit_id"]:
            A_dict[cur_sprs] = cur_A.compute()
            C_dict[cur_sprs] = C_sub.sel(unit_id=cur_mask).compute()
    hv_res = visualize_spatial_update(A_dict, C_dict, kdims=["sparse penalty"])
# Out:
# estimating penalty parameter
# computing subsetting matrix
# fitting spatial matrix
# 3 out of 10 units dropped
# estimating penalty parameter
# computing subsetting matrix
# fitting spatial matrix
# 9 out of 10 units dropped
# estimating penalty parameter
# computing subsetting matrix
# fitting spatial matrix
# 10 out of 10 units dropped
# estimating penalty parameter
# computing subsetting matrix
# fitting spatial matrix
# 10 out of 10 units dropped

# %%
# Spatial updates
A_new, mask, norm_fac = update_spatial(
    Y_hw_chk, A, C, sn_spatial, **param_first_spatial
)
C_new = save_minian(
    (C.sel(unit_id=mask) * norm_fac).rename("C_new"), intpath, overwrite=True
)
C_chk_new = save_minian(
    (C_chk.sel(unit_id=mask) * norm_fac).rename("C_chk_new"), intpath, overwrite=True
)

# Background updates
b_new, f_new = update_background(Y_fm_chk, A_new, C_chk_new)

# Save results first spatial update
A = save_minian(
    A_new.rename("A"),
    intpath,
    overwrite=True,
    chunks={"unit_id": 1, "height": -1, "width": -1},
)
b = save_minian(b_new.rename("b"), intpath, overwrite=True)
f = save_minian(
    f_new.chunk({"frame": chk["frame"]}).rename("f"), intpath, overwrite=True
)
C = save_minian(C_new.rename("C"), intpath, overwrite=True)
C_chk = save_minian(C_chk_new.rename("C_chk"), intpath, overwrite=True)
print(A)

# First temporal update
YrA = save_minian(
    compute_trace(Y_fm_chk, A, b, C_chk, f).rename("YrA"),
    intpath,
    overwrite=True,
    chunks={"unit_id": 1, "frame": -1},
)

# Spike extraction
C_new, S_new, b0_new, c0_new, g, mask = update_temporal(
    A, C, YrA=YrA, **param_first_temporal
)

# Save results
C = save_minian(
    C_new.rename("C").chunk({"unit_id": 1, "frame": -1}), intpath, overwrite=True
)
C_chk = save_minian(
    C.rename("C_chk"),
    intpath,
    overwrite=True,
    chunks={"unit_id": -1, "frame": chk["frame"]},
)
S = save_minian(
    S_new.rename("S").chunk({"unit_id": 1, "frame": -1}), intpath, overwrite=True
)
b0 = save_minian(
    b0_new.rename("b0").chunk({"unit_id": 1, "frame": -1}), intpath, overwrite=True
)
c0 = save_minian(
    c0_new.rename("c0").chunk({"unit_id": 1, "frame": -1}), intpath, overwrite=True
)
A = A.sel(unit_id=C.coords["unit_id"].values)

# Merge units
A_mrg, C_mrg, [sig_mrg] = unit_merge(A, C, [C + b0 + c0], **param_first_merge)

# Save merged units
A = save_minian(A_mrg.rename("A_mrg"), intpath, overwrite=True)
C = save_minian(C_mrg.rename("C_mrg"), intpath, overwrite=True)
C_chk = save_minian(
    C.rename("C_mrg_chk"),
    intpath,
    overwrite=True,
    chunks={"unit_id": -1, "frame": chk["frame"]},
)
sig = save_minian(sig_mrg.rename("sig_mrg"), intpath, overwrite=True)

# %% [markdown]
# # Second spatial and temporal updates

# %%
# Spatial update, generally not much happens at that stage.
A_new, mask, norm_fac = update_spatial(
    Y_hw_chk, A, C, sn_spatial, **param_second_spatial
)
C_new = save_minian(
    (C.sel(unit_id=mask) * norm_fac).rename("C_new"), intpath, overwrite=True
)
C_chk_new = save_minian(
    (C_chk.sel(unit_id=mask) * norm_fac).rename("C_chk_new"), intpath, overwrite=True
)

# Update background
b_new, f_new = update_background(Y_fm_chk, A_new, C_chk_new)

# Save spatial update
A = save_minian(
    A_new.rename("A"),
    intpath,
    overwrite=True,
    chunks={"unit_id": 1, "height": -1, "width": -1},
)
b = save_minian(b_new.rename("b"), intpath, overwrite=True)
f = save_minian(
    f_new.chunk({"frame": chk["frame"]}).rename("f"), intpath, overwrite=True
)
C = save_minian(C_new.rename("C"), intpath, overwrite=True)
C_chk = save_minian(C_chk_new.rename("C_chk"), intpath, overwrite=True)

# Second temporal update
YrA = save_minian(
    compute_trace(Y_fm_chk, A, b, C_chk, f).rename("YrA"),
    intpath,
    overwrite=True,
    chunks={"unit_id": 1, "frame": -1},
)

C_new, S_new, b0_new, c0_new, g, mask = update_temporal(
    A, C, YrA=YrA, **param_second_temporal
)

# Save all
C = save_minian(
    C_new.rename("C").chunk({"unit_id": 1, "frame": -1}), intpath, overwrite=True
)
C_chk = save_minian(
    C.rename("C_chk"),
    intpath,
    overwrite=True,
    chunks={"unit_id": -1, "frame": chk["frame"]},
)
S = save_minian(
    S_new.rename("S").chunk({"unit_id": 1, "frame": -1}), intpath, overwrite=True
)
b0 = save_minian(
    b0_new.rename("b0").chunk({"unit_id": 1, "frame": -1}), intpath, overwrite=True
)
c0 = save_minian(
    c0_new.rename("c0").chunk({"unit_id": 1, "frame": -1}), intpath, overwrite=True
)
A = A.sel(unit_id=C.coords["unit_id"].values)

# %% [markdown]
# # Generate videos and close
#
# !!!!! Only if cnmfviewer has been used

# %%
# Generate video
varr = varr_ref

generate_videos(varr.sel(subset), Y_fm_chk, A=A, C=C_chk, vpath=dpath)

# Generate labels
if interactive:
    A = A.assign_coords(unit_labels=("unit_id", cnmfviewer.unit_labels))
    C = C.assign_coords(unit_labels=("unit_id", cnmfviewer.unit_labels))
    S = S.assign_coords(unit_labels=("unit_id", cnmfviewer.unit_labels))
    c0 = c0.assign_coords(unit_labels=("unit_id", cnmfviewer.unit_labels))
    b0 = b0.assign_coords(unit_labels=("unit_id", cnmfviewer.unit_labels))

# Save final
A = save_minian(A.rename("A"), **param_save_minian)
C = save_minian(C.rename("C"), **param_save_minian)
S = save_minian(S.rename("S"), **param_save_minian)
c0 = save_minian(c0.rename("c0"), **param_save_minian)
b0 = save_minian(b0.rename("b0"), **param_save_minian)
b = save_minian(b.rename("b"), **param_save_minian)
f = save_minian(f.rename("f"), **param_save_minian)

# Close cluster
client.close()
cluster.close()
