# %%
import numpy as np
import csv
from pathlib import Path
import xarray as xr
import pandas as pd
from pandas import concat
import matplotlib.pyplot as plt
import itertools as itt
import os
import sys
import json
from scipy import signal
from scipy.signal import find_peaks
from scipy.signal import chirp, find_peaks, peak_widths

import holoviews as hv
import panel as pn
import param
from dask.distributed import Client, LocalCluster
from holoviews.operation.datashader import datashade, regrid
from holoviews.util import Dynamic
from holoviews import opts
from holoviews import Store
from holoviews.operation.datashader import shade
hv.extension('bokeh', 'matplotlib')
#from IPython.core.display import display
from IPython.display import display
from ipyfilechooser import FileChooser


import warnings
warnings.filterwarnings("ignore")
#%reset
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1002'>
#   <div id="ae1228a4-4b0d-476d-8ef8-9b662222411b" data-root-id="p1002" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
file_path = 'C:/Users/Manip2/Documents/Ghasemlou/ClasseurTF-Targets.xlsx'

# Load the Excel file into a pandas DataFrame
excel_data = pd.read_excel(file_path)

# Display the first few rows of the DataFrame
print(excel_data)
# Out:
#      Name.TF.Clcn2 Name.Target.Nr1d2 Name.Target.Per1
# 0             Zic2              Gja1          Bhlhe40
# 1             Tbr1             Myo9b           Scnn1a
# 2          Bhlhe41              Gli1             Egr1
# 3            Phf5a             Tex30          Slc12a3
# 4            Olig2              Chuk            Fxyd5
# ...            ...               ...              ...
# 8810           NaN           Dnttip1              NaN
# 8811           NaN            Znf496              NaN
# 8812           NaN              Nol7              NaN
# 8813           NaN           Gramd1a              NaN
# 8814           NaN            Polr2b              NaN
#
# [8815 rows x 3 columns]

# %%
excel_data['Name.TF.Clcn2'].dropna()
# Out:
# 0         Zic2
# 1         Tbr1
# 2      Bhlhe41
# 3        Phf5a
# 4        Olig2
#         ...
# 367      Smc1a
# 368       Epop
# 369      Runx3
# 370      Tbx19
# 371      Ptf1a
# Name: Name.TF.Clcn2, Length: 372, dtype: object

# %%
common_names = excel_data['Name.Target.Per1'][excel_data['Name.Target.Per1'].isin(excel_data['Name.Target.Per1'])]
common_names_cleaned = common_names.dropna()
print(common_names_cleaned)
# Out:
# 0    Bhlhe40
# 1     Scnn1a
# 2       Egr1
# 3    Slc12a3
# 4      Fxyd5
# 5       Cry2
# 6       Crem
# 7      Arntl
# 8      Clock
# Name: Name.Target.Per1, dtype: object

# %%
# %matplotlib inline
# %matplotlib widget

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib_venn import venn3
plt.close()

set_column1 = set(excel_data['Name.TF.Clcn2'])
set_column2 = set(excel_data['Name.Target.Per1'])
set_column3 = set(excel_data['Name.Target.Nr1d2'])

venn3(subsets=(len(set_column1 - set_column2 - set_column3),  # Only in Column1
              len(set_column2 - set_column1 - set_column3),  # Only in Column2
              len(set_column1 & set_column2 - set_column3),  # In Column1 and Column2
              len(set_column3 - set_column1 - set_column2),  # Only in Column3
              len(set_column1 & set_column3 - set_column2),  # In Column1 and Column3
              len(set_column2 & set_column3 - set_column1),  # In Column2 and Column3
              len(set_column1 & set_column2 & set_column3)), # In all three columns
     set_labels=('Clcn2', 'Per1', 'Nr1d2'))
# Display the plot
plt.title("Venn Diagram of Common Names")
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.close()
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib_venn import venn3

set_column1 = set(excel_data['Name.TF.Clcn2'])
set_column2 = set(excel_data['Name.Target.Per1'])
set_column3 = set(excel_data['Name.Target.Nr1d2'])

venn3(subsets=(3,  # Only in Column1
              4,  # Only in Column2
              4,  # In Column1 and Column2
              8447,  # Only in Column3
              368,  # In Column1 and Column3
              0,  # In Column2 and Column3
              4), # In all three columns
     set_labels=('Clcn2 TFs', 'Per1 targeted genes', 'Nr1d2 targeted genes'))
# Display the plot
plt.title("Venn Diagram of Common Names")
plt.savefig(f'C:/Users/Manip2/Documents/VennDiagram.svg', format='svg', bbox_inches='tight', pad_inches=0, transparent=True)

plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
