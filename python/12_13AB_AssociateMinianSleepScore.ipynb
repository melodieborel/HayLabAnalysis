# %% [markdown]
# # Associate Ca2+ signal with sleep stages for each session & subsessions using crossregistration
#
# Load packages

# %%
cd "C:/Users/Manip2/SCRIPTS/Code python audrey/code python aurelie/interfaceJupyter/minian"
# Out:
# C:\Users\Manip2\SCRIPTS\Code python audrey\code python aurelie\interfaceJupyter\minian

# %%
import quantities as pq
import numpy as np
import math 
import neo
import json
from pathlib import Path
import xarray as xr
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.widgets import Slider, Button, Cursor
import pickle
import os
# %matplotlib widget

from itertools import groupby
from ephyviewer import mkQApp, MainViewer, TraceViewer
from IPython.display import display
from ipyfilechooser import FileChooser


from minian.utilities import (
    TaskAnnotation,
    get_optimal_chk,
    load_videos,
    open_minian,
    save_minian,
)

# %% [markdown]
# Load sleep score and Ca2+ time series numpy arrays

# %%
dpath = "//10.69.168.1/crnldata/waking/audrey_hay/L1imaging/AnalysedMarch2023/Gaelle/Baseline_recording"
try:
    # %store -r dpath
except:
    print("data not in strore")
    #dpath = "/Users/mb/Documents/Syntuitio/AudreyHay/PlanB/ExampleRedLines/2022_08_06/13_30_01/My_V4_Miniscope/"
    dpath ="//10.69.168.1/crnldata/waking/audrey_hay/L1imaging/AnalysedMarch2023/Gaelle/Baseline_recording"

# Set up Initial Basic Parameters#
minian_path = "."

fc1 = FileChooser(dpath,select_default=True, show_only_dirs = True, title = "<b>Folder with videos</b>")
display(fc1)

# Sample callback function
def update_my_folder(chooser):
    global dpath
    dpath = chooser.selected
    # %store dpath
    return 

# Register callback function
fc1.register_callback(update_my_folder)
# Out:
# FileChooser(path='\\10.69.168.1\crnldata\waking\audrey_hay\L1imaging\AnalysedMarch2023\Gaelle\Baseline_recordi…
# Stored 'dpath' (str)

# %%
folder_base = Path(dpath)

nb_sessions = sum(1 for p in folder_base.iterdir() if p.is_dir() and p.name.startswith("session"))
try:
    mfile = open(folder_base / f'mappingsAB.pkl', 'rb')
    mapping = pickle.load(mfile)
except:
    mfile = open(folder_base / f'mappings.pkl', 'rb')
    mapping = pickle.load(mfile)

sessions = []
subsessions = []
nb_minian_total=0
dict_Calcium = {}
dict_Spike = {}
dict_Scoring = {}
dict_Stamps = {}
dict_TodropFile = {}

for y in range(1, nb_sessions+1):
    session= 'session' + str(y)
    print(session)
    sessions.append(session)
    folder_mini = folder_base / f'session{y}/V4_Miniscope'
    nb_subsessions = sum(1 for p in folder_mini.iterdir() if p.is_dir() and p.name.startswith("session"))
    ScoringFile = folder_base / f'session{y}/OpenEphys/ScoredSleep.npy'
    StampsFile = folder_base / f'session{y}/SynchroFile.xlsx'

    if nb_subsessions!=0:
        for x in range(1, nb_subsessions+1):            
            subsession= "session"  + str(y) + str(x)
            subsessions.append(subsession)    
            minian_ds = open_minian(folder_mini / subsession / f'minian')      # OR minianAB
            dict_Calcium[subsession] = minian_ds['C'] # calcium traces 
            dict_Spike[subsession] = minian_ds['S'] # estimated spikes
            dict_Scoring[subsession]  = np.load(ScoringFile)
            dict_Stamps[subsession]  = pd.read_excel(StampsFile)
            try:
                TodropFile = folder_mini / subsession / f'minian/TodropFileAB.json'
                with open(TodropFile, 'r') as f:
                    unit_to_drop = json.load(f)
                    dict_TodropFile[subsession]  = unit_to_drop
            except:
                TodropFile = folder_mini / subsession / f'minian/TodropFile.json'
                with open(TodropFile, 'r') as f:
                    unit_to_drop = json.load(f)
                    dict_TodropFile[subsession]  = unit_to_drop
            nb_minian_total+=1
            print(nb_minian_total)
    else:
        minian_ds = open_minian(folder_mini / f'minian')            # OR minianAB
        dict_Calcium[session] = minian_ds['C'] # calcium traces 
        dict_Spike[session] = minian_ds['S'] # estimated spikes
        dict_Scoring[session]  = np.load(ScoringFile) 
        dict_Stamps[session]  = pd.read_excel(StampsFile)
        try:
            TodropFile = folder_mini / f'minian/TodropFileAB.json'
            with open(TodropFile, 'r') as f:
                unit_to_drop = json.load(f)
                dict_TodropFile[session]  = unit_to_drop
        except:
            TodropFile = folder_mini / f'minian/TodropFile.json'
            with open(TodropFile, 'r') as f:
                unit_to_drop = json.load(f)
                dict_TodropFile[session]  = unit_to_drop
        nb_minian_total+=1  
        print(nb_minian_total)
# Out:
# session1
# C:\Users\Manip2\SCRIPTS\Code python audrey\code python aurelie\interfaceJupyter\minian\minian\utilities.py:342: RuntimeWarning: Failed to open Zarr store with consolidated metadata, but successfully read with non-consolidated metadata. This is typically much slower for opening a dataset. To silence this warning, consider:
# 1. Consolidating metadata in this existing store with zarr.consolidate_metadata().
# 2. Explicitly setting consolidated=False, to avoid trying to read consolidate metadata, or
# 3. Explicitly setting consolidated=True, to raise an error in this case instead of falling back to try reading non-consolidated metadata.
#   arr = list(xr.open_zarr(arr_path).values())[0]
# C:\Users\Manip2\SCRIPTS\Code python audrey\code python aurelie\interfaceJupyter\minian\minian\utilities.py:342: RuntimeWarning: Failed to open Zarr store with consolidated metadata, but successfully read with non-consolidated metadata. This is typically much slower for opening a dataset. To silence this warning, consider:
# 1. Consolidating metadata in this existing store with zarr.consolidate_metadata().
# 2. Explicitly setting consolidated=False, to avoid trying to read consolidate metadata, or
# 3. Explicitly setting consolidated=True, to raise an error in this case instead of falling back to try reading non-consolidated metadata.
#   arr = list(xr.open_zarr(arr_path).values())[0]
# 1
# C:\Users\Manip2\SCRIPTS\Code python audrey\code python aurelie\interfaceJupyter\minian\minian\utilities.py:342: RuntimeWarning: Failed to open Zarr store with consolidated metadata, but successfully read with non-consolidated metadata. This is typically much slower for opening a dataset. To silence this warning, consider:
# 1. Consolidating metadata in this existing store with zarr.consolidate_metadata().
# 2. Explicitly setting consolidated=False, to avoid trying to read consolidate metadata, or
# 3. Explicitly setting consolidated=True, to raise an error in this case instead of falling back to try reading non-consolidated metadata.
#   arr = list(xr.open_zarr(arr_path).values())[0]
# C:\Users\Manip2\SCRIPTS\Code python audrey\code python aurelie\interfaceJupyter\minian\minian\utilities.py:342: RuntimeWarning: Failed to open Zarr store with consolidated metadata, but successfully read with non-consolidated metadata. This is typically much slower for opening a dataset. To silence this warning, consider:
# 1. Consolidating metadata in this existing store with zarr.consolidate_metadata().
# 2. Explicitly setting consolidated=False, to avoid trying to read consolidate metadata, or
# 3. Explicitly setting consolidated=True, to raise an error in this case instead of falling back to try reading non-consolidated metadata.
#   arr = list(xr.open_zarr(arr_path).values())[0]
# 2
# C:\Users\Manip2\SCRIPTS\Code python audrey\code python aurelie\interfaceJupyter\minian\minian\utilities.py:342: RuntimeWarning: Failed to open Zarr store with consolidated metadata, but successfully read with non-consolidated metadata. This is typically much slower for opening a dataset. To silence this warning, consider:
# 1. Consolidating metadata in this existing store with zarr.consolidate_metadata().
# 2. Explicitly setting consolidated=False, to avoid trying to read consolidate metadata, or
# 3. Explicitly setting consolidated=True, to raise an error in this case instead of falling back to try reading non-consolidated metadata.
#   arr = list(xr.open_zarr(arr_path).values())[0]
# C:\Users\Manip2\SCRIPTS\Code python audrey\code python aurelie\interfaceJupyter\minian\minian\utilities.py:342: RuntimeWarning: Failed to open Zarr store with consolidated metadata, but successfully read with non-consolidated metadata. This is typically much slower for opening a dataset. To silence this warning, consider:
# 1. Consolidating metadata in this existing store with zarr.consolidate_metadata().
# 2. Explicitly setting consolidated=False, to avoid trying to read consolidate metadata, or
# 3. Explicitly setting consolidated=True, to raise an error in this case instead of falling back to try reading non-consolidated metadata.
#   arr = list(xr.open_zarr(arr_path).values())[0]
# 3
# session2
# C:\Users\Manip2\SCRIPTS\Code python audrey\code python aurelie\interfaceJupyter\minian\minian\utilities.py:342: RuntimeWarning: Failed to open Zarr store with consolidated metadata, but successfully read with non-consolidated metadata. This is typically much slower for opening a dataset. To silence this warning, consider:
# 1. Consolidating metadata in this existing store with zarr.consolidate_metadata().
# 2. Explicitly setting consolidated=False, to avoid trying to read consolidate metadata, or
# 3. Explicitly setting consolidated=True, to raise an error in this case instead of falling back to try reading non-consolidated metadata.
#   arr = list(xr.open_zarr(arr_path).values())[0]
# C:\Users\Manip2\SCRIPTS\Code python audrey\code python aurelie\interfaceJupyter\minian\minian\utilities.py:342: RuntimeWarning: Failed to open Zarr store with consolidated metadata, but successfully read with non-consolidated metadata. This is typically much slower for opening a dataset. To silence this warning, consider:
# 1. Consolidating metadata in this existing store with zarr.consolidate_metadata().
# 2. Explicitly setting consolidated=False, to avoid trying to read consolidate metadata, or
# 3. Explicitly setting consolidated=True, to raise an error in this case instead of falling back to try reading non-consolidated metadata.
#   arr = list(xr.open_zarr(arr_path).values())[0]
# 4
# C:\Users\Manip2\SCRIPTS\Code python audrey\code python aurelie\interfaceJupyter\minian\minian\utilities.py:342: RuntimeWarning: Failed to open Zarr store with consolidated metadata, but successfully read with non-consolidated metadata. This is typically much slower for opening a dataset. To silence this warning, consider:
# 1. Consolidating metadata in this existing store with zarr.consolidate_metadata().
# 2. Explicitly setting consolidated=False, to avoid trying to read consolidate metadata, or
# 3. Explicitly setting consolidated=True, to raise an error in this case instead of falling back to try reading non-consolidated metadata.
#   arr = list(xr.open_zarr(arr_path).values())[0]
# C:\Users\Manip2\SCRIPTS\Code python audrey\code python aurelie\interfaceJupyter\minian\minian\utilities.py:342: RuntimeWarning: Failed to open Zarr store with consolidated metadata, but successfully read with non-consolidated metadata. This is typically much slower for opening a dataset. To silence this warning, consider:
# 1. Consolidating metadata in this existing store with zarr.consolidate_metadata().
# 2. Explicitly setting consolidated=False, to avoid trying to read consolidate metadata, or
# 3. Explicitly setting consolidated=True, to raise an error in this case instead of falling back to try reading non-consolidated metadata.
#   arr = list(xr.open_zarr(arr_path).values())[0]
# 5
# C:\Users\Manip2\SCRIPTS\Code python audrey\code python aurelie\interfaceJupyter\minian\minian\utilities.py:342: RuntimeWarning: Failed to open Zarr store with consolidated metadata, but successfully read with non-consolidated metadata. This is typically much slower for opening a dataset. To silence this warning, consider:
# 1. Consolidating metadata in this existing store with zarr.consolidate_metadata().
# 2. Explicitly setting consolidated=False, to avoid trying to read consolidate metadata, or
# 3. Explicitly setting consolidated=True, to raise an error in this case instead of falling back to try reading non-consolidated metadata.
#   arr = list(xr.open_zarr(arr_path).values())[0]
# C:\Users\Manip2\SCRIPTS\Code python audrey\code python aurelie\interfaceJupyter\minian\minian\utilities.py:342: RuntimeWarning: Failed to open Zarr store with consolidated metadata, but successfully read with non-consolidated metadata. This is typically much slower for opening a dataset. To silence this warning, consider:
# 1. Consolidating metadata in this existing store with zarr.consolidate_metadata().
# 2. Explicitly setting consolidated=False, to avoid trying to read consolidate metadata, or
# 3. Explicitly setting consolidated=True, to raise an error in this case instead of falling back to try reading non-consolidated metadata.
#   arr = list(xr.open_zarr(arr_path).values())[0]
# 6

# %% [markdown]
# Cross registration results

# %%
B = mapping['session']
for c in range(len(B)):
    print('unit n°', c)
    for sess in B.keys(): #list(dict_Stamps.keys()):
        print('= unit', int(B[sess][c]), 'in', sess) if math.isnan (float(B[sess][c])) == False else None
# Out:
# unit n° 0
# = unit 275 in part1
# = unit 181 in part3
# unit n° 1
# = unit 119 in part1
# = unit 78 in part2
# = unit 68 in part3
# unit n° 2
# = unit 37 in part1
# = unit 22 in part2
# = unit 34 in session12
# = unit 31 in session13
# unit n° 3
# = unit 85 in part1
# = unit 44 in part2
# = unit 44 in part3
# = unit 48 in session11
# = unit 54 in session12
# = unit 43 in session13
# unit n° 4
# = unit 0 in part1
# = unit 5 in part2
# = unit 1 in part3
# unit n° 5
# = unit 34 in part1
# = unit 13 in part2
# = unit 11 in part3
# = unit 27 in session11
# = unit 30 in session12
# unit n° 6
# = unit 123 in part1
# = unit 71 in part2
# = unit 61 in part3
# = unit 82 in session11
# = unit 91 in session12
# unit n° 7
# = unit 4 in part1
# = unit 2 in part2
# = unit 10 in session11
# = unit 6 in session12
# = unit 9 in session13
# unit n° 8
# = unit 186 in part1
# = unit 117 in part3
# unit n° 9
# = unit 178 in part1
# = unit 116 in part2
# = unit 118 in part3
# = unit 106 in session11
# unit n° 10
# = unit 188 in part3
# = unit 189 in session11
# = unit 209 in session12
# unit n° 11
# = unit 260 in part1
# = unit 173 in part3
# = unit 156 in session11
# = unit 184 in session12
# unit n° 12
# = unit 0 in part3
# = unit 7 in session11
# unit n° 13
# = unit 183 in session11
# = unit 207 in session12
# unit n° 14
# = unit 116 in part1
# = unit 72 in part2
# = unit 78 in session12
# unit n° 15
# = unit 233 in part2
# = unit 212 in part3
# unit n° 16
# = unit 157 in part1
# = unit 100 in part2
# = unit 97 in part3
# unit n° 17
# = unit 231 in part1
# = unit 152 in part2
# = unit 136 in session11
# = unit 113 in session13
# unit n° 18
# = unit 127 in part1
# = unit 75 in part3
# = unit 76 in session11
# = unit 86 in session12
# = unit 61 in session13
# unit n° 19
# = unit 150 in session12
# = unit 111 in session13
# unit n° 20
# = unit 29 in part1
# = unit 12 in part3
# unit n° 21
# = unit 219 in part2
# = unit 196 in part3
# = unit 191 in session11
# = unit 216 in session12
# = unit 174 in session13
# unit n° 22
# = unit 289 in part1
# = unit 222 in part2
# = unit 201 in part3
# unit n° 23
# = unit 44 in part1
# = unit 19 in part2
# = unit 17 in part3
# = unit 32 in session11
# = unit 30 in session13
# unit n° 24
# = unit 101 in part1
# = unit 57 in session11
# = unit 62 in session12
# unit n° 25
# = unit 164 in part2
# = unit 133 in session11
# unit n° 26
# = unit 208 in part1
# = unit 101 in session13
# unit n° 27
# = unit 304 in part1
# = unit 227 in part2
# = unit 232 in session12
# unit n° 28
# = unit 229 in part2
# = unit 208 in session11
# unit n° 29
# = unit 224 in part1
# = unit 151 in part2
# = unit 135 in session11
# unit n° 30
# = unit 51 in part3
# = unit 56 in session11
# unit n° 31
# = unit 135 in session12
# = unit 89 in session13
# unit n° 32
# = unit 96 in part2
# = unit 98 in part3
# unit n° 33
# = unit 195 in part1
# = unit 87 in session13
# unit n° 34
# = unit 58 in part2
# = unit 68 in session11
# = unit 66 in session12
# unit n° 35
# = unit 81 in part2
# = unit 72 in part3
# unit n° 36
# = unit 58 in part1
# = unit 31 in part2
# = unit 28 in part3
# = unit 40 in session11
# = unit 43 in session12
# unit n° 37
# = unit 165 in part2
# = unit 152 in part3
# = unit 126 in session13
# unit n° 38
# = unit 228 in part2
# = unit 207 in part3
# = unit 206 in session11
# = unit 235 in session12
# = unit 189 in session13
# unit n° 39
# = unit 120 in part1
# = unit 76 in part2
# = unit 69 in part3
# unit n° 40
# = unit 13 in part1
# = unit 8 in part2
# = unit 17 in session11
# = unit 16 in session12
# unit n° 41
# = unit 172 in part3
# = unit 160 in session11
# unit n° 42
# = unit 176 in part1
# = unit 121 in part2
# = unit 113 in part3
# = unit 105 in session11
# = unit 117 in session12
# unit n° 43
# = unit 274 in part1
# = unit 193 in part2
# = unit 180 in part3
# unit n° 44
# = unit 271 in part1
# = unit 199 in part2
# = unit 175 in session11
# unit n° 45
# = unit 89 in part1
# = unit 39 in part2
# = unit 43 in part3
# unit n° 46
# = unit 155 in part3
# = unit 140 in session11
# unit n° 47
# = unit 136 in part3
# = unit 126 in session11
# unit n° 48
# = unit 162 in part2
# = unit 159 in part3
# unit n° 49
# = unit 140 in part1
# = unit 84 in part3
# unit n° 50
# = unit 132 in part1
# = unit 80 in part3
# unit n° 51
# = unit 79 in session12
# = unit 58 in session13
# unit n° 52
# = unit 177 in part1
# = unit 111 in part2
# unit n° 53
# = unit 7 in part1
# = unit 11 in session12
# = unit 12 in session13
# unit n° 54
# = unit 243 in part1
# = unit 174 in session12
# unit n° 55
# = unit 38 in session11
# = unit 38 in session12
# unit n° 56
# = unit 118 in part1
# = unit 70 in part2
# = unit 67 in part3
# unit n° 57
# = unit 65 in part1
# = unit 31 in part3
# = unit 45 in session12
# = unit 36 in session13
# unit n° 58
# = unit 128 in part1
# = unit 78 in part3
# unit n° 59
# = unit 207 in part2
# = unit 160 in session13
# unit n° 60
# = unit 130 in part2
# = unit 90 in session13
# unit n° 61
# = unit 230 in part2
# = unit 186 in session13
# unit n° 62
# = unit 150 in part2
# = unit 148 in part3
# unit n° 63
# = unit 22 in part1
# = unit 10 in part2
# = unit 6 in part3
# = unit 19 in session13
# unit n° 64
# = unit 99 in part3
# = unit 71 in session13
# unit n° 65
# = unit 96 in part1
# = unit 48 in part3
# = unit 52 in session11
# = unit 60 in session12
# = unit 48 in session13
# unit n° 66
# = unit 32 in part2
# = unit 30 in part3
# = unit 47 in session12
# unit n° 67
# = unit 87 in part2
# = unit 82 in part3
# = unit 96 in session12
# unit n° 68
# = unit 145 in part1
# = unit 91 in session11
# unit n° 69
# = unit 249 in part1
# = unit 175 in part2
# = unit 181 in session12
# = unit 133 in session13
# unit n° 70
# = unit 59 in session11
# = unit 65 in session12
# = unit 51 in session13
# unit n° 71
# = unit 164 in part3
# = unit 155 in session11
# unit n° 72
# = unit 40 in part1
# = unit 15 in part3
# = unit 28 in session11
# unit n° 73
# = unit 101 in part2
# = unit 101 in part3
# unit n° 74
# = unit 186 in part2
# = unit 138 in session13
# unit n° 75
# = unit 91 in part1
# = unit 47 in part3
# unit n° 76
# = unit 106 in part3
# = unit 100 in session11
# = unit 111 in session12
# = unit 73 in session13
# unit n° 77
# = unit 169 in session11
# = unit 201 in session12
# unit n° 78
# = unit 162 in session11
# = unit 189 in session12
# = unit 142 in session13
# unit n° 79
# = unit 103 in part1
# = unit 54 in part2
# unit n° 80
# = unit 285 in part1
# = unit 210 in part2
# unit n° 81
# = unit 293 in part1
# = unit 185 in session11
# = unit 217 in session12
# unit n° 82
# = unit 173 in part1
# = unit 102 in session11
# = unit 114 in session12
# unit n° 83
# = unit 258 in part1
# = unit 183 in part2
# = unit 185 in session12
# unit n° 84
# = unit 175 in part3
# = unit 164 in session11
# unit n° 85
# = unit 94 in part2
# = unit 93 in part3
# = unit 94 in session11
# = unit 72 in session13
# unit n° 86
# = unit 295 in part1
# = unit 223 in part2
# unit n° 87
# = unit 76 in part3
# = unit 59 in session13
# unit n° 88
# = unit 187 in part1
# = unit 131 in part3
# unit n° 89
# = unit 74 in session12
# = unit 53 in session13
# unit n° 90
# = unit 46 in part1
# = unit 21 in part3
# unit n° 91
# = unit 23 in part1
# = unit 8 in part3
# = unit 21 in session11
# = unit 21 in session12
# unit n° 92
# = unit 220 in part1
# = unit 148 in part2
# = unit 149 in part3
# unit n° 93
# = unit 40 in part2
# = unit 42 in part3
# = unit 44 in session13
# unit n° 94
# = unit 221 in session12
# = unit 179 in session13
# unit n° 95
# = unit 85 in part3
# = unit 88 in session11
# = unit 102 in session12
# = unit 69 in session13
# unit n° 96
# = unit 127 in part3
# = unit 133 in session12
# = unit 84 in session13
# unit n° 97
# = unit 210 in session11
# = unit 236 in session12
# = unit 185 in session13
# unit n° 98
# = unit 299 in part1
# = unit 220 in part2
# unit n° 99
# = unit 311 in part1
# = unit 220 in session11
# unit n° 100
# = unit 139 in part1
# = unit 91 in part2
# unit n° 101
# = unit 166 in session12
# = unit 117 in session13
# unit n° 102
# = unit 159 in session12
# = unit 114 in session13
# unit n° 103
# = unit 102 in part1
# = unit 64 in part2
# = unit 58 in part3
# = unit 58 in session11
# unit n° 104
# = unit 14 in session11
# = unit 10 in session13
# unit n° 105
# = unit 235 in part1
# = unit 170 in part3
# unit n° 106
# = unit 239 in session12
# = unit 193 in session13
# unit n° 107
# = unit 8 in part1
# = unit 2 in part3
# unit n° 108
# = unit 198 in part1
# = unit 96 in session13
# unit n° 109
# = unit 42 in session12
# = unit 35 in session13
# unit n° 110
# = unit 132 in part2
# = unit 134 in part3
# = unit 137 in session12
# unit n° 111
# = unit 208 in part3
# = unit 234 in session12
# unit n° 112
# = unit 198 in part2
# = unit 151 in session13
# unit n° 113
# = unit 110 in part1
# = unit 73 in part2
# = unit 62 in part3
# unit n° 114
# = unit 191 in part2
# = unit 139 in session13
# unit n° 115
# = unit 202 in part2
# = unit 205 in session12
# unit n° 116
# = unit 253 in session12
# = unit 208 in session13
# unit n° 117
# = unit 120 in part3
# = unit 125 in session12
# unit n° 118
# = unit 110 in part2
# = unit 119 in part3
# unit n° 119
# = unit 26 in part1
# = unit 12 in part2
# = unit 24 in session13
# unit n° 120
# = unit 323 in part1
# = unit 237 in part2
# unit n° 121
# = unit 146 in session11
# = unit 121 in session13
# unit n° 122
# = unit 180 in session11
# = unit 210 in session12
# = unit 162 in session13
# unit n° 123
# = unit 129 in part1
# = unit 84 in session11
# = unit 66 in session13
# unit n° 124
# = unit 309 in part1
# = unit 231 in part2
# unit n° 125
# = unit 172 in part2
# = unit 171 in session12
# unit n° 126
# = unit 128 in session11
# = unit 163 in session12
# unit n° 127
# = unit 46 in part2
# = unit 46 in session11
# = unit 49 in session12
# = unit 42 in session13
# unit n° 128
# = unit 139 in part2
# = unit 93 in session13
# unit n° 129
# = unit 206 in part1
# = unit 139 in part3
# unit n° 130
# = unit 24 in session11
# = unit 26 in session13
# unit n° 131
# = unit 86 in part2
# = unit 86 in part3
# = unit 100 in session12
# unit n° 132
# = unit 201 in part1
# = unit 126 in part2
# unit n° 133
# = unit 2 in session11
# = unit 4 in session13
# unit n° 134
# = unit 193 in part1
# = unit 117 in part2
# unit n° 135
# = unit 259 in part1
# = unit 184 in part2
# unit n° 136
# = unit 206 in part3
# = unit 229 in session12
# unit n° 137
# = unit 245 in part1
# = unit 177 in part2
# unit n° 138
# = unit 154 in part1
# = unit 92 in part3
# unit n° 139
# = unit 60 in part2
# = unit 57 in part3
# unit n° 140
# = unit 176 in session11
# = unit 159 in session13
# unit n° 141
# = unit 278 in part1
# = unit 208 in session12
# unit n° 142
# = unit 45 in part2
# = unit 41 in part3
# unit n° 143
# = unit 103 in part3
# = unit 101 in session11
# = unit 107 in session12
# unit n° 144
# = unit 98 in part1
# = unit 52 in part2
# = unit 52 in part3
# unit n° 145
# = unit 27 in part1
# = unit 10 in part3
# unit n° 146
# = unit 188 in part1
# = unit 130 in session12
# = unit 82 in session13
# unit n° 147
# = unit 189 in part2
# = unit 144 in session13
# unit n° 148
# = unit 99 in part1
# = unit 61 in session12
# unit n° 149
# = unit 149 in session11
# = unit 170 in session12
# unit n° 150
# = unit 19 in session11
# = unit 17 in session13
# unit n° 151
# = unit 240 in part1
# = unit 123 in session13
# unit n° 152
# = unit 26 in part2
# = unit 39 in session11
# = unit 33 in session12
# unit n° 153
# = unit 203 in part1
# = unit 83 in session13
# unit n° 154
# = unit 84 in part1
# = unit 43 in part2
# unit n° 155
# = unit 204 in session11
# = unit 184 in session13
# unit n° 156
# = unit 25 in part3
# = unit 40 in session12
# unit n° 157
# = unit 196 in session11
# = unit 227 in session12
# unit n° 158
# = unit 136 in part2
# = unit 156 in session12
# unit n° 159
# = unit 247 in part1
# = unit 179 in session12
# unit n° 160
# = unit 320 in part1
# = unit 204 in session13
# unit n° 161
# = unit 183 in part3
# = unit 203 in session12
# unit n° 162
# = unit 59 in part2
# = unit 75 in session12
# unit n° 163
# = unit 242 in part1
# = unit 127 in session13
# unit n° 164
# = unit 158 in part3
# = unit 164 in session12
# unit n° 165
# = unit 197 in session11
# = unit 219 in session12
# = unit 173 in session13
# unit n° 166
# = unit 13 in session11
# = unit 7 in session12
# unit n° 167
# = unit 0 in session11
# = unit 3 in session13
# unit n° 168
# = unit 193 in session11
# = unit 220 in session12
# unit n° 169
# = unit 290 in part1
# = unit 170 in session13
# unit n° 170
# = unit 128 in part3
# = unit 115 in session11
# unit n° 171
# = unit 116 in part3
# = unit 116 in session12
# unit n° 172
# = unit 249 in session12
# = unit 201 in session13
# unit n° 173
# = unit 111 in session11
# = unit 127 in session12
# unit n° 174
# = unit 205 in part3
# = unit 200 in session11
# unit n° 175
# = unit 108 in part3
# = unit 95 in session11
# unit n° 176
# = unit 81 in session11
# = unit 94 in session12
# unit n° 177
# = unit 300 in part1
# = unit 195 in session11
# unit n° 178
# = unit 297 in part1
# = unit 231 in session12
# unit n° 179
# = unit 79 in part2
# = unit 95 in session12
# unit n° 180
# = unit 41 in session11
# = unit 44 in session12
# unit n° 181
# = unit 137 in part1
# = unit 81 in part3
# unit n° 182
# = unit 105 in part3
# = unit 105 in session12
# unit n° 183
# = unit 136 in session12
# = unit 92 in session13
# unit n° 184
# = unit 97 in part2
# = unit 106 in session12
# unit n° 185
# unit n° 506
# = unit 8 in session11
# unit n° 507
# = unit 9 in session11
# unit n° 508
# = unit 25 in session11
# unit n° 509
# = unit 26 in session11
# unit n° 510
# = unit 31 in session11
# unit n° 511
# = unit 37 in session11
# unit n° 512
# = unit 47 in session11
# unit n° 513
# = unit 49 in session11
# unit n° 514
# = unit 50 in session11
# unit n° 515
# = unit 51 in session11
# unit n° 516
# = unit 54 in session11
# unit n° 517
# = unit 60 in session11
# unit n° 518
# = unit 61 in session11
# unit n° 519
# = unit 62 in session11
# unit n° 520
# = unit 67 in session11
# unit n° 521
# = unit 70 in session11
# unit n° 522
# = unit 71 in session11
# unit n° 523
# = unit 74 in session11
# unit n° 524
# = unit 75 in session11
# unit n° 525
# = unit 79 in session11
# unit n° 526
# = unit 85 in session11
# unit n° 527
# = unit 90 in session11
# unit n° 528
# = unit 92 in session11
# unit n° 529
# = unit 96 in session11
# unit n° 530
# = unit 99 in session11
# unit n° 531
# = unit 103 in session11
# unit n° 532
# = unit 104 in session11
# unit n° 533
# = unit 110 in session11
# unit n° 534
# = unit 112 in session11
# unit n° 535
# = unit 113 in session11
# unit n° 536
# = unit 117 in session11
# unit n° 537
# = unit 118 in session11
# unit n° 538
# = unit 119 in session11
# unit n° 539
# = unit 120 in session11
# unit n° 540
# = unit 122 in session11
# unit n° 541
# = unit 123 in session11
# unit n° 542
# = unit 125 in session11
# unit n° 543
# = unit 127 in session11
# unit n° 544
# = unit 129 in session11
# unit n° 545
# = unit 130 in session11
# unit n° 546
# = unit 131 in session11
# unit n° 547
# = unit 132 in session11
# unit n° 548
# = unit 134 in session11
# unit n° 549
# = unit 137 in session11
# unit n° 550
# = unit 139 in session11
# unit n° 551
# = unit 141 in session11
# unit n° 552
# = unit 142 in session11
# unit n° 553
# = unit 143 in session11
# unit n° 554
# = unit 144 in session11
# unit n° 555
# = unit 147 in session11
# unit n° 556
# = unit 150 in session11
# unit n° 557
# = unit 151 in session11
# unit n° 558
# = unit 152 in session11
# unit n° 559
# = unit 153 in session11
# unit n° 560
# = unit 157 in session11
# unit n° 561
# = unit 158 in session11
# unit n° 562
# = unit 163 in session11
# unit n° 563
# = unit 167 in session11
# unit n° 564
# = unit 168 in session11
# unit n° 565
# = unit 170 in session11
# unit n° 566
# = unit 171 in session11
# unit n° 567
# = unit 174 in session11
# unit n° 568
# = unit 177 in session11
# unit n° 569
# = unit 178 in session11
# unit n° 570
# = unit 182 in session11
# unit n° 571
# = unit 184 in session11
# unit n° 572
# = unit 186 in session11
# unit n° 573
# = unit 187 in session11
# unit n° 574
# = unit 188 in session11
# unit n° 575
# = unit 190 in session11
# unit n° 576
# = unit 192 in session11
# unit n° 577
# = unit 194 in session11
# unit n° 578
# = unit 198 in session11
# unit n° 579
# = unit 199 in session11
# unit n° 580
# = unit 201 in session11
# unit n° 581
# = unit 203 in session11
# unit n° 582
# = unit 207 in session11
# unit n° 583
# = unit 209 in session11
# unit n° 584
# = unit 211 in session11
# unit n° 585
# = unit 212 in session11
# unit n° 586
# = unit 213 in session11
# unit n° 587
# = unit 214 in session11
# unit n° 588
# = unit 215 in session11
# unit n° 589
# = unit 217 in session11
# unit n° 590
# = unit 221 in session11
# unit n° 591
# = unit 223 in session11
# unit n° 592
# = unit 226 in session11
# unit n° 593
# = unit 2 in session12
# unit n° 594
# = unit 3 in session12
# unit n° 595
# = unit 5 in session12
# unit n° 596
# = unit 8 in session12
# unit n° 597
# = unit 10 in session12
# unit n° 598
# = unit 12 in session12
# unit n° 599
# = unit 18 in session12
# unit n° 600
# = unit 20 in session12
# unit n° 601
# = unit 23 in session12
# unit n° 602
# = unit 24 in session12
# unit n° 603
# = unit 25 in session12
# unit n° 604
# = unit 28 in session12
# unit n° 605
# = unit 29 in session12
# unit n° 606
# = unit 31 in session12
# unit n° 607
# = unit 36 in session12
# unit n° 608
# = unit 46 in session12
# unit n° 609
# = unit 50 in session12
# unit n° 610
# = unit 52 in session12
# unit n° 611
# = unit 56 in session12
# unit n° 612
# = unit 57 in session12
# unit n° 613
# = unit 59 in session12
# unit n° 614
# = unit 64 in session12
# unit n° 615
# = unit 67 in session12
# unit n° 616
# = unit 68 in session12
# unit n° 617
# = unit 69 in session12
# unit n° 618
# = unit 70 in session12
# unit n° 619
# = unit 73 in session12
# unit n° 620
# = unit 76 in session12
# unit n° 621
# = unit 81 in session12
# unit n° 622
# = unit 83 in session12
# unit n° 623
# = unit 87 in session12
# unit n° 624
# = unit 88 in session12
# unit n° 625
# = unit 89 in session12
# unit n° 626
# = unit 90 in session12
# unit n° 627
# = unit 92 in session12
# unit n° 628
# = unit 97 in session12
# unit n° 629
# = unit 98 in session12
# unit n° 630
# = unit 101 in session12
# unit n° 631
# = unit 103 in session12
# unit n° 632
# = unit 108 in session12
# unit n° 633
# = unit 109 in session12
# unit n° 634
# = unit 112 in session12
# unit n° 635
# = unit 113 in session12
# unit n° 636
# = unit 115 in session12
# unit n° 637
# = unit 119 in session12
# unit n° 638
# = unit 120 in session12
# unit n° 639
# = unit 121 in session12
# unit n° 640
# = unit 124 in session12
# unit n° 641
# = unit 126 in session12
# unit n° 642
# = unit 128 in session12
# unit n° 643
# = unit 131 in session12
# unit n° 644
# = unit 132 in session12
# unit n° 645
# = unit 134 in session12
# unit n° 646
# = unit 138 in session12
# unit n° 647
# = unit 141 in session12
# unit n° 648
# = unit 142 in session12
# unit n° 649
# = unit 143 in session12
# unit n° 650
# = unit 144 in session12
# unit n° 651
# = unit 146 in session12
# unit n° 652
# = unit 149 in session12
# unit n° 653
# = unit 151 in session12
# unit n° 654
# = unit 152 in session12
# unit n° 655
# = unit 155 in session12
# unit n° 656
# = unit 157 in session12
# unit n° 657
# = unit 158 in session12
# unit n° 658
# = unit 160 in session12
# unit n° 659
# = unit 162 in session12
# unit n° 660
# = unit 165 in session12
# unit n° 661
# = unit 168 in session12
# unit n° 662
# = unit 169 in session12
# unit n° 663
# = unit 172 in session12
# unit n° 664
# = unit 173 in session12
# unit n° 665
# = unit 175 in session12
# unit n° 666
# = unit 176 in session12
# unit n° 667
# = unit 178 in session12
# unit n° 668
# = unit 182 in session12
# unit n° 669
# = unit 183 in session12
# unit n° 670
# = unit 186 in session12
# unit n° 671
# = unit 187 in session12
# unit n° 672
# = unit 190 in session12
# unit n° 673
# = unit 191 in session12
# unit n° 674
# = unit 193 in session12
# unit n° 675
# = unit 195 in session12
# unit n° 676
# = unit 196 in session12
# unit n° 677
# = unit 197 in session12
# unit n° 678
# = unit 198 in session12
# unit n° 679
# = unit 202 in session12
# unit n° 680
# = unit 204 in session12
# unit n° 681
# = unit 206 in session12
# unit n° 682
# = unit 211 in session12
# unit n° 683
# = unit 212 in session12
# unit n° 684
# = unit 213 in session12
# unit n° 685
# = unit 214 in session12
# unit n° 686
# = unit 215 in session12
# unit n° 687
# = unit 223 in session12
# unit n° 688
# = unit 225 in session12
# unit n° 689
# = unit 226 in session12
# unit n° 690
# = unit 228 in session12
# unit n° 691
# = unit 230 in session12
# unit n° 692
# = unit 233 in session12
# unit n° 693
# = unit 237 in session12
# unit n° 694
# = unit 238 in session12
# unit n° 695
# = unit 240 in session12
# unit n° 696
# = unit 241 in session12
# unit n° 697
# = unit 242 in session12
# unit n° 698
# = unit 244 in session12
# unit n° 699
# = unit 245 in session12
# unit n° 700
# = unit 246 in session12
# unit n° 701
# = unit 247 in session12
# unit n° 702
# = unit 248 in session12
# unit n° 703
# = unit 250 in session12
# unit n° 704
# = unit 251 in session12
# unit n° 705
# = unit 252 in session12
# unit n° 706
# = unit 254 in session12
# unit n° 707
# = unit 255 in session12
# unit n° 708
# = unit 257 in session12
# unit n° 709
# = unit 258 in session12
# unit n° 710
# = unit 1 in session13
# unit n° 711
# = unit 5 in session13
# unit n° 712
# = unit 8 in session13
# unit n° 713
# = unit 11 in session13
# unit n° 714
# = unit 15 in session13
# unit n° 715
# = unit 18 in session13
# unit n° 716
# = unit 21 in session13
# unit n° 717
# = unit 22 in session13
# unit n° 718
# = unit 23 in session13
# unit n° 719
# = unit 25 in session13
# unit n° 720
# = unit 28 in session13
# unit n° 721
# = unit 29 in session13
# unit n° 722
# = unit 32 in session13
# unit n° 723
# = unit 34 in session13
# unit n° 724
# = unit 46 in session13
# unit n° 725
# = unit 54 in session13
# unit n° 726
# = unit 56 in session13
# unit n° 727
# = unit 60 in session13
# unit n° 728
# = unit 62 in session13
# unit n° 729
# = unit 65 in session13
# unit n° 730
# = unit 67 in session13
# unit n° 731
# = unit 68 in session13
# unit n° 732
# = unit 74 in session13
# unit n° 733
# = unit 75 in session13
# unit n° 734
# = unit 77 in session13
# unit n° 735
# = unit 79 in session13
# unit n° 736
# = unit 81 in session13
# unit n° 737
# = unit 88 in session13
# unit n° 738
# = unit 91 in session13
# unit n° 739
# = unit 95 in session13
# unit n° 740
# = unit 99 in session13
# unit n° 741
# = unit 100 in session13
# unit n° 742
# = unit 104 in session13
# unit n° 743
# = unit 105 in session13
# unit n° 744
# = unit 106 in session13
# unit n° 745
# = unit 108 in session13
# unit n° 746
# = unit 109 in session13
# unit n° 747
# = unit 110 in session13
# unit n° 748
# = unit 112 in session13
# unit n° 749
# = unit 118 in session13
# unit n° 750
# = unit 124 in session13
# unit n° 751
# = unit 125 in session13
# unit n° 752
# = unit 128 in session13
# unit n° 753
# = unit 129 in session13
# unit n° 754
# = unit 130 in session13
# unit n° 755
# = unit 131 in session13
# unit n° 756
# = unit 132 in session13
# unit n° 757
# = unit 135 in session13
# unit n° 758
# = unit 140 in session13
# unit n° 759
# = unit 141 in session13
# unit n° 760
# = unit 143 in session13
# unit n° 761
# = unit 145 in session13
# unit n° 762
# = unit 146 in session13
# unit n° 763
# = unit 148 in session13
# unit n° 764
# = unit 149 in session13
# unit n° 765
# = unit 152 in session13
# unit n° 766
# = unit 154 in session13
# unit n° 767
# = unit 156 in session13
# unit n° 768
# = unit 157 in session13
# unit n° 769
# = unit 158 in session13
# unit n° 770
# = unit 161 in session13
# unit n° 771
# = unit 163 in session13
# unit n° 772
# = unit 164 in session13
# unit n° 773
# = unit 165 in session13
# unit n° 774
# = unit 166 in session13
# unit n° 775
# = unit 169 in session13
# unit n° 776
# = unit 171 in session13
# unit n° 777
# = unit 175 in session13
# unit n° 778
# = unit 178 in session13
# unit n° 779
# = unit 181 in session13
# unit n° 780
# = unit 182 in session13
# unit n° 781
# = unit 183 in session13
# unit n° 782
# = unit 187 in session13
# unit n° 783
# = unit 188 in session13
# unit n° 784
# = unit 190 in session13
# unit n° 785
# = unit 191 in session13
# unit n° 786
# = unit 192 in session13
# unit n° 787
# = unit 194 in session13
# unit n° 788
# = unit 195 in session13
# unit n° 789
# = unit 196 in session13
# unit n° 790
# = unit 197 in session13
# unit n° 791
# = unit 198 in session13
# unit n° 792
# = unit 199 in session13
# unit n° 793
# = unit 202 in session13
# unit n° 794
# = unit 203 in session13
# unit n° 795
# = unit 205 in session13
# unit n° 796
# = unit 209 in session13
# unit n° 797
# = unit 210 in session13
# unit n° 798
# = unit 211 in session13

# %% [markdown]
# Distribute Ca2+ intensity & spikes to vigilance state for each sessions/subsessions

# %%
data = {}
counter=0
VigilanceState_GlobalResults= pd.DataFrame(data, columns=['Mice','Session', 'Session_Time', 'Unique_Unit','UnitNumber','UnitValue', 'Substate','SubstateNumber','DurationSubstate', 'CalciumActivity', 'AUC_calcium', 'Avg_CalciumActivity','Avg_AUC_calcium','SpikeActivity', 'AUC_spike','Avg_SpikeActivity','Avg_AUC_spike'])

for i in list(dict_Stamps.keys()):

    # Start time & freq miniscope
    StartTime = list(dict_Stamps[i][0])[0]
    minian_freq=list(dict_Stamps[i][0])[2]

    First_frame = StartTime*minian_freq
    C=dict_Calcium[i]
    Cupd = C.loc[:, :] #C.loc[:, First_frame:]
    nb_unit = Cupd.shape[0]
    rec_dur = Cupd.shape[1]
    S=dict_Spike[i] 
    Supd = S.loc[:, :] #S.loc[:, First_frame:]

    # Upscale scoring to miniscope frequency
    scale_factor=minian_freq/0.2  #cause scoring was done in 5 seconds bin, ie 0.2 Hz
    SleepScoredTS=dict_Scoring[i]
    SleepScoredTS_upscaled = np.repeat(SleepScoredTS, scale_factor, axis=0)
    StartTime_frame=int(StartTime*minian_freq)
    SleepScoredTS_upscaled_ministart=SleepScoredTS_upscaled[int(StartTime_frame):int(StartTime_frame)+rec_dur]

    # Identify start time and upscale scoring to miniscope acquisition frequency
    unit_to_drop=dict_TodropFile[i]
    D = C['unit_id']
    copyD = list(D.copy())
    for r in range(len(unit_to_drop)):
        elem = unit_to_drop[r]
        copyD.remove(elem)
    unit_to_keep = copyD

    C_upd = Cupd.loc[unit_to_keep,:]
    S_upd = Supd.loc[unit_to_keep,:]
    nb_unit = C_upd.shape[0]
    print(len(C_upd.unit_id), 'selected units in', i)

        
    # Determine each substate identity and duration
    array=SleepScoredTS_upscaled_ministart
    substates_duration = [len(list(group)) for key, group in groupby(array)]
    substates_identity = [key for key, _ in groupby(array)]
    substates_end = np.array(substates_duration).cumsum()
    substates_start =np.append([1],substates_end+1)
    mapp = {0: 'NREM', 0.5: 'N2', 1: 'REM', 1.5: 'Wake'}
    substates_identity = [mapp[num] for num in substates_identity]
    substates = pd.DataFrame(list(zip(substates_identity, substates_duration, substates_start, substates_end)), columns=['Identity', 'Duration', 'Start','End'])

    C_upd_unit_id = C_upd['unit_id'].values #added by AB
    calciumtraces_all = C_upd.to_series()
    spikestraces_all = S_upd.to_series()

    for unit in range(nb_unit): # nb_unit):
        ca_input = np.array(calciumtraces_all)[(unit)*rec_dur:(unit+1)*rec_dur]
        sp_input = np.array(spikestraces_all)[(unit)*rec_dur:(unit+1)*rec_dur]
        for index in range(len(substates)):
            ca_input_sub=ca_input[substates.Start[index]:substates.End[index]]
            sp_input_sub=sp_input[substates.Start[index]:substates.End[index]]
            VigilanceState_GlobalResults.loc[counter, 'Mice'] = os.path.basename(folder_base)
            VigilanceState_GlobalResults.loc[counter, 'Session'] = i 
            VigilanceState_GlobalResults.loc[counter, 'Session_Time'] = None 
            
            keys_list = list(dict_Stamps.keys())
            key_to_find = i
            position = keys_list.index(key_to_find)
            keys_list2 = list(B.keys())
            key_at_position = keys_list2[position]
            indexMapp = np.where(B[key_at_position] == C_upd_unit_id[unit])[0]

            VigilanceState_GlobalResults.loc[counter, 'Unique_Unit'] = indexMapp
            VigilanceState_GlobalResults.loc[counter, 'UnitNumber'] = unit
            VigilanceState_GlobalResults.loc[counter, 'UnitValue'] = C_upd_unit_id[unit]
            VigilanceState_GlobalResults.loc[counter, 'Substate'] = substates.Identity[index]
            VigilanceState_GlobalResults.loc[counter, 'SubstateNumber'] = substates.index[index]
            VigilanceState_GlobalResults.loc[counter, 'DurationSubstate'] = substates.Duration[index]
            VigilanceState_GlobalResults.loc[counter, 'CalciumActivity'] = ca_input_sub.mean()
            VigilanceState_GlobalResults.loc[counter, 'AUC_calcium'] = np.trapz(ca_input_sub,np.arange(0,len(ca_input_sub),1))
            VigilanceState_GlobalResults.loc[counter, 'Avg_CalciumActivity'] = ca_input.mean()
            VigilanceState_GlobalResults.loc[counter, 'Avg_AUC_calcium'] = np.trapz(ca_input,np.arange(0,len(ca_input),1))
            VigilanceState_GlobalResults.loc[counter, 'SpikeActivity'] = sp_input_sub.mean()
            VigilanceState_GlobalResults.loc[counter, 'AUC_spike'] = np.trapz(sp_input_sub,np.arange(0,len(sp_input_sub),1))
            VigilanceState_GlobalResults.loc[counter, 'Avg_SpikeActivity'] = sp_input.mean()
            VigilanceState_GlobalResults.loc[counter, 'Avg_AUC_spike'] = np.trapz(sp_input,np.arange(0,len(sp_input),1))
            counter+=1
# Out:
# 49 selected units in session11
# 18 selected units in session12
# 25 selected units in session13
# 36 selected units in session21
# 19 selected units in session22
# 36 selected units in session23

# %%
VigilanceState_GlobalResults
# Out:
#         Mice    Session Session_Time Unique_Unit UnitNumber UnitValue  \
# 0     Purple  session11         None           4          0         0
# 1     Purple  session11         None           4          0         0
# 2     Purple  session11         None           4          0         0
# 3     Purple  session11         None           4          0         0
# 4     Purple  session11         None           4          0         0
# ...      ...        ...          ...         ...        ...       ...
# 3993  Purple  session23         None         744         35       106
# 3994  Purple  session23         None         744         35       106
# 3995  Purple  session23         None         744         35       106
# 3996  Purple  session23         None         744         35       106
# 3997  Purple  session23         None         744         35       106
#
#      Substate SubstateNumber DurationSubstate CalciumActivity  AUC_calcium  \
# 0        NREM              0             1017        2.246678  2281.178575
# 1        Wake              1              100        2.831403   277.537833
# 2        NREM              2              400        2.484344   988.561705
# 3        Wake              3              100        2.872802   281.685946
# 4        NREM              4              300        2.739895   816.298818
# ...       ...            ...              ...             ...          ...
# 3993       N2             27              450             0.0          0.0
# 3994      REM             28              600             0.0          0.0
# 3995     Wake             29             1500             0.0          0.0
# 3996     NREM             30              900             0.0          0.0
# 3997     Wake             31              208             0.0          0.0
#
#      Avg_CalciumActivity Avg_AUC_calcium SpikeActivity  AUC_spike  \
# 0               0.982022    20539.835565      0.010364  10.517748
# 1               0.982022    20539.835565       0.01372   1.344034
# 2               0.982022    20539.835565      0.007826   3.122411
# 3               0.982022    20539.835565       0.01572   1.556321
# 4               0.982022    20539.835565       0.00958   2.856783
# ...                  ...             ...           ...        ...
# 3993            0.039446      874.270963           0.0        0.0
# 3994            0.039446      874.270963           0.0        0.0
# 3995            0.039446      874.270963           0.0        0.0
# 3996            0.039446      874.270963           0.0        0.0
# 3997            0.039446      874.270963           0.0        0.0
#
#      Avg_SpikeActivity Avg_AUC_spike
# 0              0.00353      73.83471
# 1              0.00353      73.83471
# 2              0.00353      73.83471
# 3              0.00353      73.83471
# 4              0.00353      73.83471
# ...                ...           ...
# 3993          0.000744      16.49278
# 3994          0.000744      16.49278
# 3995          0.000744      16.49278
# 3996          0.000744      16.49278
# 3997          0.000744      16.49278
#
# [3998 rows x 17 columns]

# %% [markdown]
# Save to Excel

# %%
mice=os.path.basename(folder_base) 
filenameOut = folder_base / f'VigilanceState_GlobalResultsAB_{mice}.xlsx'
writer = pd.ExcelWriter(filenameOut)
VigilanceState_GlobalResults.to_excel(writer)
writer.close()
