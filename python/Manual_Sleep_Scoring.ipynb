# %% [markdown]
# # Visualisation of LFP & Sleep scoring

# %% [markdown]
# ### Load LFP and packages

# %%
import numpy as np
import pandas as pd
from pathlib import Path
import os
from IPython.display import display
from ipyfilechooser import FileChooser
from ephyviewer import mkQApp, MainViewer, TraceViewer
import ephyviewer
from scipy.stats import zscore
from itertools import groupby
from ephyviewer import mkQApp, MainViewer, TraceViewer, TimeFreqViewer
from ephyviewer import InMemoryAnalogSignalSource
from ephyviewer import mkQApp, MainViewer, TraceViewer, CsvEpochSource, EpochEncoder
import json

# %matplotlib widget

# %%
try: # tries to retrieve dpath either from a previous run or from a previous notebook
    # %store -r dpath
    dpath=Path(dpath).parent
except:
    print("the path was not defined in store")
    #dpath = "/Users/mb/Documents/Syntuitio/AudreyHay/PlanB/ExampleRedLines/2022_08_06/13_30_01/My_V4_Miniscope/"
dpath = "//10.69.168.1/crnldata/forgetting/Carla/"


fc1 = FileChooser(dpath,select_default=True, show_only_dirs = True, title = "<b>Open Ephys folder</b>")
display(fc1)

# Sample callback function
def update_my_folder(chooser):
    global dpath
    dpath = chooser.selected
    # %store dpath
    return 

# Register callback function
fc1.register_callback(update_my_folder)
# Out:
# FileChooser(path='\\10.69.168.1\crnldata\forgetting\Carla', filename='', title='<b>Open Ephys folder</b>', sho…

# %% [markdown]
# Load LFPs data

# %%
folder_base = Path(dpath) 
file=Path(f'{folder_base}\continuous.dat')
DataRec = np.fromfile(file, dtype="int16")

filepath = os.path.join(folder_base.parent.parent, f'structure.oebin')
with open(filepath) as f:
    metadata = json.load(f)
samplerate=metadata['continuous'][0]['sample_rate']  
numchannel=metadata['continuous'][0]['num_channels']  
All = DataRec.reshape(-1,numchannel)

print('sample rate = ', samplerate, 'Hz')
print(numchannel, 'channels recorded')
print(round(All.shape[0]/samplerate/60), 'min of recording')

# %% [markdown]
# Load LFPs channels

# %%
Channels = '//10.69.168.1/crnldata/forgetting/Carla/OpenEphysData/LFPChannels_perMice_selectedchannels.xlsx'
mice=file.parts[-1].split('_')[0]
#print(mice)

mice='Vert'
allchannels = pd.read_excel(Channels)

PFCch1=int(allchannels[mice][0].split('_')[0])
PFCch2=int(allchannels[mice][0].split('_')[1])

CA1ch1=int(allchannels[mice][2].split('_')[0])
CA1ch2=int(allchannels[mice][2].split('_')[1])

S1ch1=int(allchannels[mice][0])
#S1ch1=int(allchannels[mice][1].split('_')[0])
#S1ch2=int(allchannels[mice][1].split('_')[1])

EMGch1=int(allchannels[mice][3])

oPFCch1=int(allchannels[mice][4])
#oPFCch1=int(allchannels[mice][4].split('_')[0])
#oPFCch2=int(allchannels[mice][4].split('_')[1])

EnthCch1=int(allchannels[mice][5].split('_')[0])
EnthCch2=int(allchannels[mice][5].split('_')[1])

RHch1=int(allchannels[mice][6])
#RHch1=int(allchannels[mice][6].split('_')[0])
#RHch2=int(allchannels[mice][6].split('_')[1])

# %%
PFC  =  All[:, (PFCch1)]-All[:, (PFCch2)] 
CA1  =  All[:, (CA1ch1)]-All[:, (CA1ch2)]
#S1  =  All[:, (S1ch1)]#-All[:, (S1ch2)] 
EMG  =  All[:, (EMGch1)]
oPFC  =  All[:, (oPFCch1)]#-All[:, (oPFCch2)] 
EnthC  =  All[:, (EnthCch1)]-All[:, (EnthCch2)] 
RH  =  All[:, (RHch1)]#-All[:, (RHch2)] 


combined = np.stack([zscore(S1)*3,zscore(PFC), zscore(CA1), zscore(EMG)*2, zscore(oPFC), zscore(EnthC), zscore(RH)], axis = 1)
#combined = np.stack([zscore(S1),zscore(PFC), zscore(EMG), zscore(oPFC), zscore(EnthC), zscore(RH)], axis = 1)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[34], line 10
#       6 EnthC  =  All[:, (EnthCch1)]-All[:, (EnthCch2)]
#       7 RH  =  All[:, (RHch1)]#-All[:, (RHch2)]
# ---> 10 combined = np.stack([zscore(S1)*3,zscore(PFC), zscore(CA1), zscore(EMG)*2, zscore(oPFC), zscore(EnthC), zscore(RH)], axis = 1)
#      11 #combined = np.stack([zscore(S1),zscore(PFC), zscore(EMG), zscore(oPFC), zscore(EnthC), zscore(RH)], axis = 1)
#
# File c:\Users\AudreyHay\anaconda3\envs\SleepRec2\Lib\site-packages\scipy\stats\_stats_py.py:2992, in zscore(a, axis, ddof, nan_policy)
#    2910 def zscore(a, axis=0, ddof=0, nan_policy='propagate'):
#    2911     """
#    2912     Compute the z score.
#    2913
#    (...)
#    2990            [-0.91611681, -0.89090508,  1.4983032 ,  0.88731639, -0.5785977 ]])
#    2991     """
# -> 2992     return zmap(a, a, axis=axis, ddof=ddof, nan_policy=nan_policy)
#
# File c:\Users\AudreyHay\anaconda3\envs\SleepRec2\Lib\site-packages\scipy\stats\_stats_py.py:3163, in zmap(scores, compare, axis, ddof, nan_policy)
#    3157     std = a.std(axis=axis, ddof=ddof, keepdims=True)
#    3158     # The intent is to check whether all elements of `a` along `axis` are
#    3159     # identical. Due to finite precision arithmetic, comparing elements
#    3160     # against `mn` doesn't work. Previously, this compared elements to
#    3161     # `_first`, but that extracts the element at index 0 regardless of
#    3162     # whether it is masked. As a simple fix, compare against `min`.
# -> 3163     a0 = a.min(axis=axis, keepdims=True)
#    3164     isconst = (a == a0).all(axis=axis, keepdims=True)
#    3166 # Set std deviations that are 0 to 1 to avoid division by 0.
#
# File c:\Users\AudreyHay\anaconda3\envs\SleepRec2\Lib\site-packages\numpy\core\_methods.py:45, in _amin(a, axis, out, keepdims, initial, where)
#      43 def _amin(a, axis=None, out=None, keepdims=False,
#      44           initial=_NoValue, where=True):
# ---> 45     return umr_minimum(a, axis, None, out, keepdims, initial, where)
#
# KeyboardInterrupt:

# %% [markdown]
# ### Score sleep manually with ephyviewer

# %% [markdown]
# 4 stages : Wake, NREM, REM, undefined

# %%
possible_labels = ['Wake_1', 'NREM_2', 'REM_3', 'undefined_4'] # Wake, NREM sleep, REM sleep, undefined states
epoch_dur = 10 # define epoch duration in sec

filename = f'{dpath}\Sleep_Scoring_{len(possible_labels)}Stages_{epoch_dur}sEpoch.csv'
source_epoch = CsvEpochSource(filename, possible_labels)

#you must first create a main Qt application (for event loop)
app = mkQApp()

t_start = 0.

#Create the main window that can contain several viewers
win = MainViewer(debug=True, show_auto_scale=True)

#create a viewer for signal
#source =InMemoryAnalogSignalSource(combined, samplerate, t_start, channel_names=['S1','PFC', 'CA1', 'EMG'])
source =InMemoryAnalogSignalSource(combined[:,:], samplerate, t_start, channel_names=['S1','PFC', 'CA1', 'EMG','oPFC', 'EnthC', 'RH'])
view1 = TraceViewer(source=source)

view1.params['xsize']= 60
view1.params['display_labels'] = True
view1.params['scale_mode'] = 'same_for_all'
view1.auto_scale()
view1.by_channel_params['ch0', 'color'] = '#88FF88' #FF0000 red, #00FF00 green, and #0000FF blue
view1.by_channel_params['ch1', 'color'] = '#8888FF'
view1.by_channel_params['ch2', 'color'] = '#FF8888'
view1.by_channel_params['ch3', 'color'] = '#FFFFFF'

win.add_view(view1)

#create a viewer for the encoder itself
view2 = EpochEncoder(source=source_epoch, name='Sleep Scoring')
view2.params['xsize']= 60
view2.params['new_epoch_step']= epoch_dur

view2.by_label_params['label0', 'color']= '#ffcd69' #AW
view2.by_label_params['label1', 'color']= '#69cfff' #NREM
view2.by_label_params['label2', 'color']= '#ff69cd' #REM
view2.by_label_params['label3', 'color']= '#8f8f8f' #undefined

# FFT
view3 = TimeFreqViewer(source=source, name='FFT')

view3.params['show_axis'] = True
view3.params['timefreq', 'f_start'] = 1
view3.params['timefreq', 'f_stop'] = 50
view3.params['timefreq', 'deltafreq'] = 1 #interval in Hz
view3.params['xsize']= 60
view3.by_channel_params['ch0', 'clim'] = 1
view3.by_channel_params['ch1', 'clim'] = 1
view3.by_channel_params['ch2', 'clim'] = 1
view3.by_channel_params['ch0', 'visible'] = True
view3.by_channel_params['ch1', 'visible'] = True
view3.by_channel_params['ch2', 'visible'] = True
view3.by_channel_params['ch3', 'visible'] = False

win.add_view(view3)
win.add_view(view2)

#show main window and run Qapp
win.show()

app.exec()

# press '1', '2', '3', '4' etc, to encode state.
# or toggle 'Time range selector' and then use 'Insert within range'
# Out:
# debug True
# QT_MODE PyQt5
# refresh duration for  0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.01258707046508789 s
# refresh duration for  0.0009963512420654297 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0009996891021728516 s
# refresh duration for Sleep Scoring 0.0010001659393310547 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.010684728622436523 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0009965896606445312 s
# refresh duration for FFT 0.0020003318786621094 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0010006427764892578 s
# refresh duration for Sleep Scoring 0.0009996891021728516 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0009968280792236328 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0010058879852294922 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.002527952194213867 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0009999275207519531 s
# refresh duration for FFT 0.001003265380859375 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0030019283294677734 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0019998550415039062 s
# refresh duration for Sleep Scoring 0.0010001659393310547 s
# refresh duration for  0.00099945068359375 s
# refresh duration for FFT 0.0029990673065185547 s
# refresh duration for Sleep Scoring 0.0010039806365966797 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0030012130737304688 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0049991607666015625 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0009975433349609375 s
# refresh duration for Sleep Scoring 0.000997304916381836 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0009975433349609375 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.004509925842285156 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0009992122650146484 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.005000114440917969 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0020051002502441406 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.006494998931884766 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.005380868911743164 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0019998550415039062 s
# refresh duration for Sleep Scoring 0.0010008811950683594 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.001997709274291992 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.001999378204345703 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.005995512008666992 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0019974708557128906 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0010042190551757812 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.004096031188964844 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0009999275207519531 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0014989376068115234 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0021359920501708984 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0010068416595458984 s
# refresh duration for FFT 0.0019941329956054688 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.001995086669921875 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0009984970092773438 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.004016876220703125 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.002004384994506836 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0020055770874023438 s
# refresh duration for Sleep Scoring 0.0020058155059814453 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.003751039505004883 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0020055770874023438 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0020067691802978516 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0020093917846679688 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.00401616096496582 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0020155906677246094 s
# refresh duration for Sleep Scoring 0.0020987987518310547 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.004015445709228516 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.002003908157348633 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0019731521606445312 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.00400996208190918 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.002008676528930664 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0015096664428710938 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.002010345458984375 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.008022069931030273 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0020148754119873047 s
# refresh duration for Sleep Scoring 0.0020089149475097656 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.002007722854614258 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0020051002502441406 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.002010345458984375 s
# refresh duration for Sleep Scoring 0.003398418426513672 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0015532970428466797 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.006073951721191406 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0020072460174560547 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.00104522705078125 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.002005338668823242 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.005210161209106445 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.002006053924560547 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.006848573684692383 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.00695037841796875 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0020051002502441406 s
# refresh duration for Sleep Scoring 0.0020046234130859375 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0020046234130859375 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0020155906677246094 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0020134449005126953 s
# refresh duration for Sleep Scoring 0.002011537551879883 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0020058155059814453 s
# refresh duration for Sleep Scoring 0.002004384994506836 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0020112991333007812 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.002010345458984375 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0020046234130859375 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0020148754119873047 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0020105838775634766 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.006013393402099609 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.002878427505493164 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0020074844360351562 s
# refresh duration for Sleep Scoring 0.0005090236663818359 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.00228118896484375 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.001505136489868164 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0017392635345458984 s
# refresh duration for Sleep Scoring 0.0020062923431396484 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.005674123764038086 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.002009153366088867 s
# refresh duration for FFT 0.00174713134765625 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.002005338668823242 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.004008054733276367 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0020036697387695312 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.002007722854614258 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.002003908157348633 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0020067691802978516 s
# refresh duration for FFT 0.0015048980712890625 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0017387866973876953 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0020062923431396484 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.002002716064453125 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.002006053924560547 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.002004861831665039 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.004015922546386719 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.010282754898071289 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.004012107849121094 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0020074844360351562 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0020067691802978516 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0020101070404052734 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.002007007598876953 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0037555694580078125 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.002008676528930664 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0020062923431396484 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.002013683319091797 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.00200653076171875 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.002006053924560547 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.004010200500488281 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.002020597457885742 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.002004861831665039 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0061070919036865234 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0020062923431396484 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.002009153366088867 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0040130615234375 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.002004861831665039 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0015833377838134766 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0020093917846679688 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.002009868621826172 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0020084381103515625 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0017468929290771484 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.002061605453491211 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.002006053924560547 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0020089149475097656 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.004012107849121094 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0027043819427490234 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.004010438919067383 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0020058155059814453 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0020051002502441406 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.002008199691772461 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0020067691802978516 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0020055770874023438 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.008797407150268555 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.003871917724609375 s
# refresh duration for FFT 0.006014823913574219 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0020072460174560547 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0043489933013916016 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.002201557159423828 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.00379180908203125 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.002010345458984375 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.002007007598876953 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0020074844360351562 s
# refresh duration for Sleep Scoring 0.0020096302032470703 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.015862703323364258 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.005391836166381836 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.006081342697143555 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.00200653076171875 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0015103816986083984 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0035085678100585938 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0020046234130859375 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.003417491912841797 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0010082721710205078 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0010063648223876953 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.002008676528930664 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.002007722854614258 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.006025552749633789 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0040132999420166016 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.005839824676513672 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.00401759147644043 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.004821300506591797 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.002004861831665039 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.002025604248046875 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0021376609802246094 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0019063949584960938 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0020051002502441406 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0020062923431396484 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0038712024688720703 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.002006053924560547 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.002006053924560547 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.010135889053344727 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0020122528076171875 s
# refresh duration for Sleep Scoring 0.0015113353729248047 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0040090084075927734 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0010035037994384766 s
# refresh duration for FFT 0.006011009216308594 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0020074844360351562 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0020055770874023438 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0020134449005126953 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.006013393402099609 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0015075206756591797 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0020062923431396484 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0020051002502441406 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0020067691802978516 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0020058155059814453 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.002006053924560547 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0020046234130859375 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0020058155059814453 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0020055770874023438 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.002005338668823242 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0020046234130859375 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.002004861831665039 s
# refresh duration for FFT 0.0020117759704589844 s
# refresh duration for Sleep Scoring 0.0020067691802978516 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.005224943161010742 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0020072460174560547 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.004491090774536133 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.003055095672607422 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.016243457794189453 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.015744686126708984 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.015653610229492188 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.015738964080810547 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.016054391860961914 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0020189285278320312 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# refresh duration for  0.0 s
# refresh duration for FFT 0.0 s
# refresh duration for Sleep Scoring 0.0 s
# save_all_settings
# 0

# %% [markdown]
# 6 stages : AW, QW, NREM, IS, REM, undefined

# %%
possible_labels = ['AW_1', 'QW_2', 'NREM_3', 'IS_4',  'REM_5', 'undefined_6'] # Active wake, Quiet wake, NREM sleep, Intermediate sleep, REM sleep, undefined states
epoch_dur = 10 # define epoch duration in sec

filename = f'{dpath}\Sleep_Scoring_{len(possible_labels)}Stages_{epoch_dur}sEpoch.csv'
source_epoch = CsvEpochSource(filename, possible_labels)

#you must first create a main Qt application (for event loop)
app = mkQApp()

t_start = 0.

#Create the main window that can contain several viewers
win = MainViewer(debug=True, show_auto_scale=True)

#create a viewer for signal
source =InMemoryAnalogSignalSource(combined, samplerate, t_start, channel_names=['S1','PFC', 'CA1', 'EMG'])
view1 = TraceViewer(source=source)

view1.params['xsize']= 60
view1.params['display_labels'] = True
view1.params['scale_mode'] = 'same_for_all'
view1.auto_scale()
view1.by_channel_params['ch0', 'color'] = '#88FF88' #FF0000 red, #00FF00 green, and #0000FF blue
view1.by_channel_params['ch1', 'color'] = '#8888FF'
view1.by_channel_params['ch2', 'color'] = '#FF8888'
view1.by_channel_params['ch3', 'color'] = '#FFFFFF'

win.add_view(view1)

#create a viewer for the encoder itself
view2 = EpochEncoder(source=source_epoch, name='Sleep Scoring')
view2.params['xsize']= 60
view2.params['new_epoch_step']= epoch_dur

view2.by_label_params['label0', 'color']= '#ffcd69' #AW
view2.by_label_params['label1', 'color']= '#69ffe6' #QW
view2.by_label_params['label2', 'color']= '#69cfff' #NREM
view2.by_label_params['label3', 'color']= '#cd69ff' #IS
view2.by_label_params['label4', 'color']= '#ff69cd' #REM
view2.by_label_params['label5', 'color']= '#8f8f8f' #undefined

# FFT
view3 = TimeFreqViewer(source=source, name='FFT')

view3.params['show_axis'] = True
view3.params['timefreq', 'f_start'] = 1
view3.params['timefreq', 'f_stop'] = 50
view3.params['timefreq', 'deltafreq'] = 1 #interval in Hz
view3.params['xsize']= 60
view3.by_channel_params['ch0', 'clim'] = 1
view3.by_channel_params['ch1', 'clim'] = 1
view3.by_channel_params['ch2', 'clim'] = 1
view3.by_channel_params['ch0', 'visible'] = True
view3.by_channel_params['ch1', 'visible'] = True
view3.by_channel_params['ch2', 'visible'] = True
view3.by_channel_params['ch3', 'visible'] = False



win.add_view(view3)
win.add_view(view2)


#show main window and run Qapp
win.show()

app.exec()

# press '1', '2', '3', '4' etc, to encode state.
# or toggle 'Time range selector' and then use 'Insert within range'
# Out:
# debug True
# QT_MODE PyQt5
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[17], line 17
#      15 #create a viewer for signal
#      16 source =InMemoryAnalogSignalSource(combined, samplerate, t_start, channel_names=['S1','PFC', 'CA1', 'EMG'])
# ---> 17 view1 = TraceViewer(source=source)
#      19 view1.params['xsize']= 60
#      20 view1.params['display_labels'] = True
#
# File c:\Users\AudreyHay\anaconda3\envs\SleepRec2\Lib\site-packages\ephyviewer\traceviewer.py:431, in TraceViewer.__init__(self, useOpenGL, **kargs)
#     428 def __init__(self, useOpenGL=None, **kargs):
#     429     BaseMultiChannelViewer.__init__(self, **kargs)
# --> 431     self.make_params()
#     433     # useOpenGL=True eliminates the extremely poor performance associated
#     434     # with TraceViewer's line_width > 1.0, but it also degrades overall
#     435     # performance somewhat and is reportedly unstable
#     436     self.set_layout(useOpenGL=useOpenGL)
#
# File c:\Users\AudreyHay\anaconda3\envs\SleepRec2\Lib\site-packages\ephyviewer\base.py:92, in BaseMultiChannelViewer.make_params(self)
#      89 for i in range(self.source.nb_channel):
#      90     #TODO add name, hadrware index, id
#      91     name = 'ch{}'.format(i)
# ---> 92     children =[{'name': 'name', 'type': 'str', 'value': self.source.get_channel_name(i), 'readonly':True}]
#      93     children += self._default_by_channel_params
#      94     all.append({'name': name, 'type': 'group', 'children': children})
#
# File c:\Users\AudreyHay\anaconda3\envs\SleepRec2\Lib\site-packages\ephyviewer\datasource\signals.py:54, in InMemoryAnalogSignalSource.get_channel_name(self, chan)
#      53 def get_channel_name(self, chan=0):
# ---> 54     return self.channel_names[chan]
#
# IndexError: list index out of range
